# %%
import pandas as pd
data = pd.read_csv('../data_acquisition/clean_data_check0.csv')
data = data.rename(columns={'number of leakage': 'number_of_leakage'})
data = data[(data.number_of_leakage == 1)]
# data= data.dropna()
data = data.drop(columns=['sample_number', 'x2','y2','Comments', 'Day', 'number_of_leakage', 'quality'])
y = data[['x1', 'y1']]
X = data.drop(['x1', 'y1'], axis=1)

# %%
data.head()
# Out:
#         x1      y1    MFC6    MFC7    MFC8    MFC9   MFC10    MFC1    MFC2  \
# 0  11930.0  3100.0  0.0000  0.0169  0.0350  0.0995  0.0812  0.0000  0.0129
# 2    930.0   100.0  0.0549  0.0412  0.0213  0.0124  0.0292  0.1815  0.0516
# 4   9930.0   850.0  0.0187  0.0370  0.0554  0.0622  0.0574  0.0187  0.0404
# 6   4930.0  2350.0  0.1090  0.1293  0.0684  0.0312  0.0367  0.1228  0.1433
# 8   9180.0  4600.0  0.0235  0.0437  0.1338  0.0626  0.0442  0.0223  0.0292
#
#      MFC3  ...  mfc6_residual  mfc7_residual  mfc8_residual  mfc9_residual  \
# 0  0.0306  ...              0            0.0            0.0            0.0
# 2  0.0213  ...              0            0.0            0.0            0.0
# 4  0.1504  ...              0            0.0            0.0            0.0
# 6  0.0692  ...              0            0.0            0.0            0.0
# 8  0.0363  ...              0            0.0            0.0            0.0
#
# ...

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define dataset
# define the model
model = LinearRegression()
# fit the model
model.fit(X, y)
# get importance
importance = model.coef_
importance = importance[0]
# summarize feature importance
for i,v in enumerate(importance):
 print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       6 model = LinearRegression()
#       7 # fit the model
# ----> 8 model.fit(X, y)
#       9 # get importance
#      10 importance = model.coef_
#
# File ~/miniconda3/envs/studiarbeit/lib/python3.9/site-packages/sklearn/linear_model/_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...
