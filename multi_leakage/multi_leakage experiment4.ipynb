# %%
# NN 4 outputs and with and without sorting of outputs
model_path = 'saved_model/Multi_leak/experiment4/Mask/'
project_name='Multi_leak_experiment4_Mask_withSwap'

# %%
# Experiment 2 - 1 output layer with 1 loss function - mse. and do hyper parameter tuning.
from utils.data_preprocess import load_data
import pandas as pd 
import yaml
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras_tuner as kt
from keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from kerastuner import HyperModel, Hyperband
from keras import backend as backend

# %%
single_leakage, two_leakage = load_data()
# two_leakage["leak_1"] = 1
# two_leakage["leak_2"] = 1

# single_leakage["leak_1"] = 1
# single_leakage["leak_2"] = 0

data = pd.concat([single_leakage, two_leakage], axis=0)
data['x2'] = data['x2'].replace(np.nan, 0)
data['y2'] = data['y2'].replace(np.nan, 0)

data = data.drop(columns=['mfc6_residual',
       'mfc7_residual', 'mfc8_residual', 'mfc9_residual', 'mfc10_residual',
       'mfc1_residual', 'mfc2_residual', 'mfc3_residual', 'mfc4_residual',
       'mfc5_residual', 'total flow rate'
       ])

y = data[['x1', 'y1', 'x2', 'y2']]
x = data.drop(['x1', 'y1', 'x2', 'y2'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1) 


# sort x1, y1 and x2, y2. coordinates with lowest x will take the position of x1
def coords_swap(y1):
    s = y1['x2'] < y1['x1']
    y1.loc[s, ['x1','x2']] = y1.loc[s, ['x2','x1']].values
    y1.loc[s, ['y1','y2']] = y1.loc[s, ['y2','y1']].values
    return y1


y1_data = [y_train, y_val, y_test]
y1_data_types = ['y_train', 'y_val', 'y_test']
for y1_data_types, y1 in zip(y1_data_types, y1_data):
    y1_data_types = coords_swap(y1)

y1_train = y_train[['x1', 'y1']]
y1_test = y_test[['x1', 'y1']]
y1_val = y_val[['x1', 'y1']]

y2_train = y_train[['x2', 'y2']]
y2_test = y_test[['x2', 'y2']]
y2_val = y_val[['x2', 'y2']]

y1_columns = y1_train.columns
y2_columns = y2_train.columns
X_columns = X_train.columns

scaler_coords1 = StandardScaler()
y1_train = scaler_coords1.fit_transform(y1_train)
y1_test = scaler_coords1.transform(y1_test)
y1_val = scaler_coords1.transform(y1_val)

y1_train = pd.DataFrame(y1_train, columns=y1_columns)
y1_test = pd.DataFrame(y1_test, columns=y1_columns)
y1_val = pd.DataFrame(y1_val, columns=y1_columns)

scaler_coords2 = StandardScaler()
y2_train = scaler_coords2.fit_transform(y2_train)
y2_test = scaler_coords2.transform(y2_test)
y2_val = scaler_coords2.transform(y2_val)

y2_train = pd.DataFrame(y2_train, columns=y2_columns)
y2_test = pd.DataFrame(y2_test, columns=y2_columns)
y2_val = pd.DataFrame(y2_val, columns=y2_columns)

scaler_flows = StandardScaler()
X_train = scaler_flows.fit_transform(X_train)
X_test = scaler_flows.transform(X_test)
X_val = scaler_flows.transform(X_val)

X_train = pd.DataFrame(X_train, columns=X_columns)
X_test = pd.DataFrame(X_test, columns=X_columns)
X_val = pd.DataFrame(X_val, columns=X_columns)

# y_train = [y1_train, y2_train]
# y_val = [y1_val, y2_val]
# y_test = [y1_test, y2_test]

y_train_all = pd.concat([y1_train, y2_train], axis=1)
y_test_all = pd.concat([y1_test, y2_test], axis=1)
y_val_all = pd.concat([y1_val, y2_val], axis=1)

# %%
X_train_np, y1_train_np, y2_train_np = X_train.values, y1_train.values, y2_train.values
X_val_np, y1_val_np, y2_val_np = X_val.values, y1_val.values, y2_val.values
X_test_np, y1_test_np, y2_test_np = X_test.values, y1_test.values, y2_test.values

# Create TensorFlow datasets from NumPy arrays.
batch_size = 32
buffer_size = len(X_train)  # Set the buffer size to the number of training examples for full shuffling.

train_dataset = tf.data.Dataset.from_tensor_slices((X_train_np, y1_train_np, y2_train_np ))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val_np, y1_val_np, y2_val_np))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_np, y1_test_np, y2_test_np))

# Shuffle, batch, and prefetch the training dataset.
train_dataset_org = train_dataset.batch(batch_size)
train_dataset = train_dataset.shuffle(buffer_size).batch(batch_size).prefetch(tf.data.AUTOTUNE)


# Batch the validation and test datasets.
val_dataset = val_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)

# %%
def masked_mse(y_true, y_pred):
    mask = tf.keras.backend.cast(tf.keras.backend.not_equal(y_true, 0), tf.keras.backend.floatx())
    mse = tf.keras.backend.mean(tf.keras.backend.square(y_true - y_pred) * mask)
    return mse

losses = {
	"y1": "mse",
	"y2": masked_mse
    # "y2" : 'mse'
    }

metrics = {
    "y1": 'mae',
    "y2": 'mae'
    }

# %%
EPOCHS = 1000

# Define custom loss function


# Define model builder function for Keras Tuner
def model_builder(hp):
    tf.keras.backend.clear_session()
    # Tune the number of units in the first Dense layer
    # Define model
    inputs = tf.keras.Input(shape=(10,))
    shared_layer = inputs
    for i in range(hp.Int('num_layers', 1, 15)):
        shared_layer = layers.Dense(
            units=hp.Int("units_" + str(i), min_value=32, max_value=512, step=32),
            activation='relu',
            # add elu
            kernel_initializer='he_uniform'
        )(shared_layer)

    out1 = shared_layer
    out1 = layers.Dense(2, name='y1', activation = 'linear', kernel_initializer='he_uniform')(out1)

    out2 = shared_layer
    out2 = layers.Dense(2, name='y2', activation = 'linear', kernel_initializer='he_uniform')(out2)

    model = tf.keras.Model(inputs=inputs, outputs=[out1, out2])

    # Tune the learning rate for the optimizer
    hp_learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-1, sampling="log")

    # model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss=['mse', masked_mse])
    model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=hp_learning_rate),
                    loss=losses, metrics=metrics)
    
    return model

tuner = Hyperband(
    model_builder,
    objective =  kt.Objective("val_loss", direction="min"),
    max_epochs=EPOCHS+100,
    factor=2,
    directory="../../tensorflow_log_files/studienarbeit/",
    project_name=project_name,
    seed = 0
)

tuner.search_space_summary()
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Perform hyperparameter search
tuner.search(train_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})),
            #  X_train, y_train, 
            #  validation_data = (X_val, y_val), 
            validation_data = val_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})), 
             verbose = 1, callbacks=[stop_early],
             epochs=EPOCHS, shuffle = True)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps)

# Build the best model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the best model on the full dataset
history = best_model.fit(train_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})),
            #  X_train, y_train,
            #  validation_data = (X_val, y_val), 
            validation_data = val_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})),  
            # callbacks=[stop_early],
            verbose = 1, epochs=EPOCHS, shuffle = True)

print(f"""
    The hyperparameter search is complete. The optimal learning rate for the optimizer
    is {best_model.optimizer.lr.numpy()}.
    """)
# Out:
# INFO:tensorflow:Reloading Tuner from ../../tensorflow_log_files/studienarbeit/Multi_leak_experiment4_Mask_withSwap/tuner0.json
# Search space summary
# Default search space size: 17
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 15, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# INFO:tensorflow:Oracle triggered exit
# Best Hyperparameters: <keras_tuner.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7f7dace3f430>
# Epoch 1/1000
# 17/17 [==============================] - 2s 15ms/step - loss: 17.8314 - y1_loss: 9.4800 - y2_loss: 8.3514 - y1_mae: 1.2764 - y2_mae: 1.1612 - val_loss: 0.5005 - val_y1_loss: 0.2898 - val_y2_loss: 0.2108 - val_y1_mae: 0.3857 - val_y2_mae: 0.3534
# Epoch 2/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2536 - y1_loss: 0.1410 - y2_loss: 0.1126 - y1_mae: 0.2721 - y2_mae: 0.2299 - val_loss: 0.1550 - val_y1_loss: 0.0751 - val_y2_loss: 0.0799 - val_y1_mae: 0.2064 - val_y2_mae: 0.2029
# Epoch 3/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1440 - y1_loss: 0.0725 - y2_loss: 0.0716 - y1_mae: 0.1938 - y2_mae: 0.1869 - val_loss: 0.1411 - val_y1_loss: 0.0600 - val_y2_loss: 0.0812 - val_y1_mae: 0.1839 - val_y2_mae: 0.1982
# Epoch 4/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1196 - y1_loss: 0.0578 - y2_loss: 0.0619 - y1_mae: 0.1606 - y2_mae: 0.1677 - val_loss: 0.1253 - val_y1_loss: 0.0594 - val_y2_loss: 0.0659 - val_y1_mae: 0.1752 - val_y2_mae: 0.1732
# Epoch 5/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0974 - y1_loss: 0.0457 - y2_loss: 0.0517 - y1_mae: 0.1452 - y2_mae: 0.1610 - val_loss: 0.1244 - val_y1_loss: 0.0531 - val_y2_loss: 0.0713 - val_y1_mae: 0.1637 - val_y2_mae: 0.1883
# Epoch 6/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0936 - y1_loss: 0.0445 - y2_loss: 0.0490 - y1_mae: 0.1462 - y2_mae: 0.1524 - val_loss: 0.1085 - val_y1_loss: 0.0487 - val_y2_loss: 0.0598 - val_y1_mae: 0.1517 - val_y2_mae: 0.1741
# Epoch 7/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0830 - y1_loss: 0.0375 - y2_loss: 0.0455 - y1_mae: 0.1336 - y2_mae: 0.1445 - val_loss: 0.1344 - val_y1_loss: 0.0579 - val_y2_loss: 0.0766 - val_y1_mae: 0.1665 - val_y2_mae: 0.1821
# Epoch 8/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0796 - y1_loss: 0.0378 - y2_loss: 0.0418 - y1_mae: 0.1302 - y2_mae: 0.1388 - val_loss: 0.1201 - val_y1_loss: 0.0544 - val_y2_loss: 0.0657 - val_y1_mae: 0.1659 - val_y2_mae: 0.1677
# Epoch 9/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0718 - y1_loss: 0.0335 - y2_loss: 0.0382 - y1_mae: 0.1241 - y2_mae: 0.1343 - val_loss: 0.1051 - val_y1_loss: 0.0489 - val_y2_loss: 0.0562 - val_y1_mae: 0.1618 - val_y2_mae: 0.1561
# Epoch 10/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0595 - y1_loss: 0.0273 - y2_loss: 0.0323 - y1_mae: 0.1135 - y2_mae: 0.1239 - val_loss: 0.1127 - val_y1_loss: 0.0536 - val_y2_loss: 0.0591 - val_y1_mae: 0.1676 - val_y2_mae: 0.1625
# Epoch 11/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0662 - y1_loss: 0.0321 - y2_loss: 0.0341 - y1_mae: 0.1259 - y2_mae: 0.1248 - val_loss: 0.1190 - val_y1_loss: 0.0495 - val_y2_loss: 0.0696 - val_y1_mae: 0.1578 - val_y2_mae: 0.1786
# Epoch 12/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0639 - y1_loss: 0.0307 - y2_loss: 0.0332 - y1_mae: 0.1224 - y2_mae: 0.1256 - val_loss: 0.1088 - val_y1_loss: 0.0494 - val_y2_loss: 0.0595 - val_y1_mae: 0.1473 - val_y2_mae: 0.1619
# Epoch 13/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0575 - y1_loss: 0.0274 - y2_loss: 0.0301 - y1_mae: 0.1143 - y2_mae: 0.1198 - val_loss: 0.1113 - val_y1_loss: 0.0493 - val_y2_loss: 0.0621 - val_y1_mae: 0.1583 - val_y2_mae: 0.1816
# Epoch 14/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0602 - y1_loss: 0.0285 - y2_loss: 0.0317 - y1_mae: 0.1124 - y2_mae: 0.1202 - val_loss: 0.1370 - val_y1_loss: 0.0628 - val_y2_loss: 0.0742 - val_y1_mae: 0.1679 - val_y2_mae: 0.1776
# Epoch 15/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0622 - y1_loss: 0.0308 - y2_loss: 0.0314 - y1_mae: 0.1157 - y2_mae: 0.1186 - val_loss: 0.1015 - val_y1_loss: 0.0474 - val_y2_loss: 0.0542 - val_y1_mae: 0.1479 - val_y2_mae: 0.1590
# Epoch 16/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0599 - y1_loss: 0.0298 - y2_loss: 0.0302 - y1_mae: 0.1167 - y2_mae: 0.1231 - val_loss: 0.1023 - val_y1_loss: 0.0447 - val_y2_loss: 0.0576 - val_y1_mae: 0.1393 - val_y2_mae: 0.1559
# Epoch 17/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0485 - y1_loss: 0.0220 - y2_loss: 0.0265 - y1_mae: 0.1009 - y2_mae: 0.1144 - val_loss: 0.1165 - val_y1_loss: 0.0501 - val_y2_loss: 0.0665 - val_y1_mae: 0.1478 - val_y2_mae: 0.1757
# Epoch 18/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0512 - y1_loss: 0.0235 - y2_loss: 0.0277 - y1_mae: 0.1056 - y2_mae: 0.1157 - val_loss: 0.0931 - val_y1_loss: 0.0425 - val_y2_loss: 0.0506 - val_y1_mae: 0.1432 - val_y2_mae: 0.1527
# Epoch 19/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0508 - y1_loss: 0.0258 - y2_loss: 0.0250 - y1_mae: 0.1102 - y2_mae: 0.1129 - val_loss: 0.1146 - val_y1_loss: 0.0430 - val_y2_loss: 0.0716 - val_y1_mae: 0.1403 - val_y2_mae: 0.1798
# Epoch 20/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0479 - y1_loss: 0.0224 - y2_loss: 0.0255 - y1_mae: 0.1047 - y2_mae: 0.1123 - val_loss: 0.1018 - val_y1_loss: 0.0474 - val_y2_loss: 0.0544 - val_y1_mae: 0.1454 - val_y2_mae: 0.1535
# Epoch 21/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0438 - y1_loss: 0.0190 - y2_loss: 0.0248 - y1_mae: 0.0955 - y2_mae: 0.1056 - val_loss: 0.0979 - val_y1_loss: 0.0475 - val_y2_loss: 0.0504 - val_y1_mae: 0.1442 - val_y2_mae: 0.1564
# Epoch 22/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0434 - y1_loss: 0.0200 - y2_loss: 0.0234 - y1_mae: 0.0960 - y2_mae: 0.1051 - val_loss: 0.0910 - val_y1_loss: 0.0413 - val_y2_loss: 0.0497 - val_y1_mae: 0.1384 - val_y2_mae: 0.1461
# Epoch 23/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0372 - y1_loss: 0.0175 - y2_loss: 0.0197 - y1_mae: 0.0921 - y2_mae: 0.0940 - val_loss: 0.1070 - val_y1_loss: 0.0489 - val_y2_loss: 0.0580 - val_y1_mae: 0.1472 - val_y2_mae: 0.1529
# Epoch 24/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0411 - y1_loss: 0.0195 - y2_loss: 0.0216 - y1_mae: 0.0927 - y2_mae: 0.0998 - val_loss: 0.1133 - val_y1_loss: 0.0565 - val_y2_loss: 0.0569 - val_y1_mae: 0.1541 - val_y2_mae: 0.1542
# Epoch 25/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0533 - y1_loss: 0.0273 - y2_loss: 0.0259 - y1_mae: 0.1077 - y2_mae: 0.1093 - val_loss: 0.0900 - val_y1_loss: 0.0400 - val_y2_loss: 0.0500 - val_y1_mae: 0.1333 - val_y2_mae: 0.1521
# Epoch 26/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0434 - y1_loss: 0.0202 - y2_loss: 0.0232 - y1_mae: 0.0957 - y2_mae: 0.1042 - val_loss: 0.0974 - val_y1_loss: 0.0485 - val_y2_loss: 0.0489 - val_y1_mae: 0.1547 - val_y2_mae: 0.1491
# Epoch 27/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0426 - y1_loss: 0.0195 - y2_loss: 0.0230 - y1_mae: 0.0967 - y2_mae: 0.1036 - val_loss: 0.1068 - val_y1_loss: 0.0494 - val_y2_loss: 0.0574 - val_y1_mae: 0.1520 - val_y2_mae: 0.1568
# Epoch 28/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0415 - y1_loss: 0.0197 - y2_loss: 0.0218 - y1_mae: 0.0965 - y2_mae: 0.1047 - val_loss: 0.0816 - val_y1_loss: 0.0406 - val_y2_loss: 0.0410 - val_y1_mae: 0.1328 - val_y2_mae: 0.1368
# Epoch 29/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0386 - y1_loss: 0.0172 - y2_loss: 0.0214 - y1_mae: 0.0913 - y2_mae: 0.0996 - val_loss: 0.0934 - val_y1_loss: 0.0422 - val_y2_loss: 0.0513 - val_y1_mae: 0.1370 - val_y2_mae: 0.1443
# Epoch 30/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0338 - y1_loss: 0.0149 - y2_loss: 0.0189 - y1_mae: 0.0854 - y2_mae: 0.0964 - val_loss: 0.0974 - val_y1_loss: 0.0424 - val_y2_loss: 0.0550 - val_y1_mae: 0.1385 - val_y2_mae: 0.1607
# Epoch 31/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0312 - y1_loss: 0.0135 - y2_loss: 0.0176 - y1_mae: 0.0806 - y2_mae: 0.0941 - val_loss: 0.0967 - val_y1_loss: 0.0457 - val_y2_loss: 0.0510 - val_y1_mae: 0.1407 - val_y2_mae: 0.1485
# Epoch 32/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0341 - y1_loss: 0.0157 - y2_loss: 0.0183 - y1_mae: 0.0878 - y2_mae: 0.0961 - val_loss: 0.0873 - val_y1_loss: 0.0393 - val_y2_loss: 0.0480 - val_y1_mae: 0.1276 - val_y2_mae: 0.1485
# Epoch 33/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0291 - y1_loss: 0.0130 - y2_loss: 0.0161 - y1_mae: 0.0802 - y2_mae: 0.0885 - val_loss: 0.0839 - val_y1_loss: 0.0366 - val_y2_loss: 0.0473 - val_y1_mae: 0.1267 - val_y2_mae: 0.1479
# Epoch 34/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0286 - y1_loss: 0.0126 - y2_loss: 0.0160 - y1_mae: 0.0788 - y2_mae: 0.0885 - val_loss: 0.0949 - val_y1_loss: 0.0414 - val_y2_loss: 0.0535 - val_y1_mae: 0.1343 - val_y2_mae: 0.1476
# Epoch 35/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0285 - y1_loss: 0.0135 - y2_loss: 0.0150 - y1_mae: 0.0801 - y2_mae: 0.0870 - val_loss: 0.0935 - val_y1_loss: 0.0427 - val_y2_loss: 0.0507 - val_y1_mae: 0.1390 - val_y2_mae: 0.1489
# Epoch 36/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0333 - y1_loss: 0.0170 - y2_loss: 0.0163 - y1_mae: 0.0865 - y2_mae: 0.0880 - val_loss: 0.1070 - val_y1_loss: 0.0466 - val_y2_loss: 0.0604 - val_y1_mae: 0.1474 - val_y2_mae: 0.1636
# Epoch 37/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0321 - y1_loss: 0.0154 - y2_loss: 0.0167 - y1_mae: 0.0870 - y2_mae: 0.0904 - val_loss: 0.0870 - val_y1_loss: 0.0375 - val_y2_loss: 0.0495 - val_y1_mae: 0.1250 - val_y2_mae: 0.1469
# Epoch 38/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0374 - y1_loss: 0.0180 - y2_loss: 0.0193 - y1_mae: 0.0937 - y2_mae: 0.0962 - val_loss: 0.0957 - val_y1_loss: 0.0434 - val_y2_loss: 0.0523 - val_y1_mae: 0.1333 - val_y2_mae: 0.1522
# Epoch 39/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0317 - y1_loss: 0.0140 - y2_loss: 0.0178 - y1_mae: 0.0831 - y2_mae: 0.0961 - val_loss: 0.0978 - val_y1_loss: 0.0397 - val_y2_loss: 0.0580 - val_y1_mae: 0.1361 - val_y2_mae: 0.1703
# Epoch 40/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0314 - y1_loss: 0.0149 - y2_loss: 0.0164 - y1_mae: 0.0866 - y2_mae: 0.0943 - val_loss: 0.0822 - val_y1_loss: 0.0393 - val_y2_loss: 0.0429 - val_y1_mae: 0.1327 - val_y2_mae: 0.1378
# Epoch 41/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0285 - y1_loss: 0.0143 - y2_loss: 0.0142 - y1_mae: 0.0840 - y2_mae: 0.0845 - val_loss: 0.0800 - val_y1_loss: 0.0343 - val_y2_loss: 0.0456 - val_y1_mae: 0.1193 - val_y2_mae: 0.1461
# Epoch 42/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0237 - y1_loss: 0.0107 - y2_loss: 0.0130 - y1_mae: 0.0704 - y2_mae: 0.0799 - val_loss: 0.1015 - val_y1_loss: 0.0409 - val_y2_loss: 0.0605 - val_y1_mae: 0.1314 - val_y2_mae: 0.1615
# Epoch 43/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0262 - y1_loss: 0.0110 - y2_loss: 0.0152 - y1_mae: 0.0732 - y2_mae: 0.0873 - val_loss: 0.0838 - val_y1_loss: 0.0387 - val_y2_loss: 0.0450 - val_y1_mae: 0.1260 - val_y2_mae: 0.1387
# Epoch 44/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0222 - y1_loss: 0.0098 - y2_loss: 0.0124 - y1_mae: 0.0696 - y2_mae: 0.0784 - val_loss: 0.0752 - val_y1_loss: 0.0351 - val_y2_loss: 0.0401 - val_y1_mae: 0.1218 - val_y2_mae: 0.1368
# Epoch 45/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0204 - y1_loss: 0.0089 - y2_loss: 0.0115 - y1_mae: 0.0670 - y2_mae: 0.0737 - val_loss: 0.0849 - val_y1_loss: 0.0381 - val_y2_loss: 0.0468 - val_y1_mae: 0.1193 - val_y2_mae: 0.1392
# Epoch 46/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0277 - y1_loss: 0.0138 - y2_loss: 0.0139 - y1_mae: 0.0795 - y2_mae: 0.0800 - val_loss: 0.1009 - val_y1_loss: 0.0534 - val_y2_loss: 0.0475 - val_y1_mae: 0.1492 - val_y2_mae: 0.1457
# Epoch 47/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0332 - y1_loss: 0.0159 - y2_loss: 0.0172 - y1_mae: 0.0854 - y2_mae: 0.0919 - val_loss: 0.0845 - val_y1_loss: 0.0348 - val_y2_loss: 0.0497 - val_y1_mae: 0.1221 - val_y2_mae: 0.1459
# Epoch 48/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0250 - y1_loss: 0.0113 - y2_loss: 0.0137 - y1_mae: 0.0740 - y2_mae: 0.0844 - val_loss: 0.1005 - val_y1_loss: 0.0419 - val_y2_loss: 0.0586 - val_y1_mae: 0.1307 - val_y2_mae: 0.1584
# Epoch 49/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0237 - y1_loss: 0.0106 - y2_loss: 0.0131 - y1_mae: 0.0725 - y2_mae: 0.0842 - val_loss: 0.0812 - val_y1_loss: 0.0367 - val_y2_loss: 0.0444 - val_y1_mae: 0.1227 - val_y2_mae: 0.1424
# Epoch 50/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0187 - y1_loss: 0.0078 - y2_loss: 0.0109 - y1_mae: 0.0623 - y2_mae: 0.0733 - val_loss: 0.0748 - val_y1_loss: 0.0312 - val_y2_loss: 0.0435 - val_y1_mae: 0.1118 - val_y2_mae: 0.1397
# Epoch 51/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0202 - y1_loss: 0.0085 - y2_loss: 0.0117 - y1_mae: 0.0650 - y2_mae: 0.0750 - val_loss: 0.1078 - val_y1_loss: 0.0519 - val_y2_loss: 0.0560 - val_y1_mae: 0.1336 - val_y2_mae: 0.1578
# Epoch 52/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0262 - y1_loss: 0.0127 - y2_loss: 0.0135 - y1_mae: 0.0780 - y2_mae: 0.0819 - val_loss: 0.0899 - val_y1_loss: 0.0403 - val_y2_loss: 0.0496 - val_y1_mae: 0.1326 - val_y2_mae: 0.1460
# Epoch 53/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0272 - y1_loss: 0.0129 - y2_loss: 0.0143 - y1_mae: 0.0789 - y2_mae: 0.0859 - val_loss: 0.0971 - val_y1_loss: 0.0418 - val_y2_loss: 0.0553 - val_y1_mae: 0.1323 - val_y2_mae: 0.1471
# Epoch 54/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0361 - y1_loss: 0.0176 - y2_loss: 0.0185 - y1_mae: 0.0862 - y2_mae: 0.0929 - val_loss: 0.1007 - val_y1_loss: 0.0429 - val_y2_loss: 0.0579 - val_y1_mae: 0.1416 - val_y2_mae: 0.1583
# Epoch 55/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0360 - y1_loss: 0.0171 - y2_loss: 0.0189 - y1_mae: 0.0908 - y2_mae: 0.0971 - val_loss: 0.0928 - val_y1_loss: 0.0435 - val_y2_loss: 0.0493 - val_y1_mae: 0.1310 - val_y2_mae: 0.1425
# Epoch 56/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0394 - y1_loss: 0.0195 - y2_loss: 0.0198 - y1_mae: 0.0913 - y2_mae: 0.0995 - val_loss: 0.0794 - val_y1_loss: 0.0392 - val_y2_loss: 0.0402 - val_y1_mae: 0.1344 - val_y2_mae: 0.1373
# Epoch 57/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0352 - y1_loss: 0.0175 - y2_loss: 0.0178 - y1_mae: 0.0878 - y2_mae: 0.0926 - val_loss: 0.0778 - val_y1_loss: 0.0353 - val_y2_loss: 0.0425 - val_y1_mae: 0.1279 - val_y2_mae: 0.1355
# Epoch 58/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0280 - y1_loss: 0.0134 - y2_loss: 0.0146 - y1_mae: 0.0839 - y2_mae: 0.0876 - val_loss: 0.0885 - val_y1_loss: 0.0383 - val_y2_loss: 0.0502 - val_y1_mae: 0.1281 - val_y2_mae: 0.1482
# Epoch 59/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0346 - y1_loss: 0.0164 - y2_loss: 0.0182 - y1_mae: 0.0894 - y2_mae: 0.0963 - val_loss: 0.1074 - val_y1_loss: 0.0506 - val_y2_loss: 0.0567 - val_y1_mae: 0.1518 - val_y2_mae: 0.1633
# Epoch 60/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0337 - y1_loss: 0.0153 - y2_loss: 0.0185 - y1_mae: 0.0867 - y2_mae: 0.0967 - val_loss: 0.0895 - val_y1_loss: 0.0452 - val_y2_loss: 0.0443 - val_y1_mae: 0.1372 - val_y2_mae: 0.1397
# Epoch 61/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0232 - y1_loss: 0.0106 - y2_loss: 0.0126 - y1_mae: 0.0732 - y2_mae: 0.0804 - val_loss: 0.0806 - val_y1_loss: 0.0331 - val_y2_loss: 0.0475 - val_y1_mae: 0.1174 - val_y2_mae: 0.1397
# Epoch 62/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0236 - y1_loss: 0.0105 - y2_loss: 0.0131 - y1_mae: 0.0735 - y2_mae: 0.0830 - val_loss: 0.0906 - val_y1_loss: 0.0430 - val_y2_loss: 0.0476 - val_y1_mae: 0.1272 - val_y2_mae: 0.1442
# Epoch 63/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0221 - y1_loss: 0.0108 - y2_loss: 0.0113 - y1_mae: 0.0715 - y2_mae: 0.0758 - val_loss: 0.0695 - val_y1_loss: 0.0298 - val_y2_loss: 0.0397 - val_y1_mae: 0.1124 - val_y2_mae: 0.1382
# Epoch 64/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0193 - y1_loss: 0.0079 - y2_loss: 0.0114 - y1_mae: 0.0644 - y2_mae: 0.0775 - val_loss: 0.0834 - val_y1_loss: 0.0371 - val_y2_loss: 0.0463 - val_y1_mae: 0.1294 - val_y2_mae: 0.1429
# Epoch 65/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0220 - y1_loss: 0.0091 - y2_loss: 0.0129 - y1_mae: 0.0662 - y2_mae: 0.0811 - val_loss: 0.0851 - val_y1_loss: 0.0418 - val_y2_loss: 0.0432 - val_y1_mae: 0.1263 - val_y2_mae: 0.1395
# Epoch 66/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0229 - y1_loss: 0.0102 - y2_loss: 0.0128 - y1_mae: 0.0671 - y2_mae: 0.0784 - val_loss: 0.0862 - val_y1_loss: 0.0389 - val_y2_loss: 0.0473 - val_y1_mae: 0.1350 - val_y2_mae: 0.1506
# Epoch 67/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0195 - y1_loss: 0.0083 - y2_loss: 0.0111 - y1_mae: 0.0658 - y2_mae: 0.0771 - val_loss: 0.0897 - val_y1_loss: 0.0381 - val_y2_loss: 0.0517 - val_y1_mae: 0.1207 - val_y2_mae: 0.1514
# Epoch 68/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0190 - y1_loss: 0.0085 - y2_loss: 0.0105 - y1_mae: 0.0659 - y2_mae: 0.0737 - val_loss: 0.0768 - val_y1_loss: 0.0343 - val_y2_loss: 0.0425 - val_y1_mae: 0.1193 - val_y2_mae: 0.1362
# Epoch 69/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0169 - y1_loss: 0.0082 - y2_loss: 0.0087 - y1_mae: 0.0644 - y2_mae: 0.0669 - val_loss: 0.0768 - val_y1_loss: 0.0346 - val_y2_loss: 0.0422 - val_y1_mae: 0.1178 - val_y2_mae: 0.1323
# Epoch 70/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0143 - y1_loss: 0.0066 - y2_loss: 0.0076 - y1_mae: 0.0563 - y2_mae: 0.0602 - val_loss: 0.0822 - val_y1_loss: 0.0332 - val_y2_loss: 0.0491 - val_y1_mae: 0.1194 - val_y2_mae: 0.1532
# Epoch 71/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0139 - y1_loss: 0.0056 - y2_loss: 0.0082 - y1_mae: 0.0535 - y2_mae: 0.0651 - val_loss: 0.0722 - val_y1_loss: 0.0327 - val_y2_loss: 0.0394 - val_y1_mae: 0.1164 - val_y2_mae: 0.1305
# Epoch 72/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0128 - y1_loss: 0.0059 - y2_loss: 0.0069 - y1_mae: 0.0549 - y2_mae: 0.0595 - val_loss: 0.0678 - val_y1_loss: 0.0304 - val_y2_loss: 0.0374 - val_y1_mae: 0.1177 - val_y2_mae: 0.1248
# Epoch 73/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0118 - y1_loss: 0.0052 - y2_loss: 0.0067 - y1_mae: 0.0510 - y2_mae: 0.0567 - val_loss: 0.0705 - val_y1_loss: 0.0313 - val_y2_loss: 0.0392 - val_y1_mae: 0.1103 - val_y2_mae: 0.1309
# Epoch 74/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0126 - y1_loss: 0.0049 - y2_loss: 0.0077 - y1_mae: 0.0496 - y2_mae: 0.0611 - val_loss: 0.0747 - val_y1_loss: 0.0323 - val_y2_loss: 0.0424 - val_y1_mae: 0.1105 - val_y2_mae: 0.1395
# Epoch 75/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0159 - y1_loss: 0.0072 - y2_loss: 0.0087 - y1_mae: 0.0579 - y2_mae: 0.0678 - val_loss: 0.0777 - val_y1_loss: 0.0351 - val_y2_loss: 0.0425 - val_y1_mae: 0.1267 - val_y2_mae: 0.1391
# Epoch 76/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0156 - y1_loss: 0.0073 - y2_loss: 0.0082 - y1_mae: 0.0611 - y2_mae: 0.0649 - val_loss: 0.0901 - val_y1_loss: 0.0471 - val_y2_loss: 0.0430 - val_y1_mae: 0.1314 - val_y2_mae: 0.1322
# Epoch 77/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0197 - y1_loss: 0.0094 - y2_loss: 0.0102 - y1_mae: 0.0623 - y2_mae: 0.0696 - val_loss: 0.0737 - val_y1_loss: 0.0301 - val_y2_loss: 0.0436 - val_y1_mae: 0.1066 - val_y2_mae: 0.1375
# Epoch 78/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0182 - y1_loss: 0.0079 - y2_loss: 0.0102 - y1_mae: 0.0595 - y2_mae: 0.0714 - val_loss: 0.0859 - val_y1_loss: 0.0391 - val_y2_loss: 0.0467 - val_y1_mae: 0.1200 - val_y2_mae: 0.1426
# Epoch 79/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0176 - y1_loss: 0.0083 - y2_loss: 0.0092 - y1_mae: 0.0629 - y2_mae: 0.0697 - val_loss: 0.0725 - val_y1_loss: 0.0312 - val_y2_loss: 0.0413 - val_y1_mae: 0.1139 - val_y2_mae: 0.1315
# Epoch 80/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0207 - y1_loss: 0.0088 - y2_loss: 0.0119 - y1_mae: 0.0636 - y2_mae: 0.0771 - val_loss: 0.0891 - val_y1_loss: 0.0402 - val_y2_loss: 0.0489 - val_y1_mae: 0.1190 - val_y2_mae: 0.1413
# Epoch 81/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0231 - y1_loss: 0.0105 - y2_loss: 0.0126 - y1_mae: 0.0708 - y2_mae: 0.0779 - val_loss: 0.0874 - val_y1_loss: 0.0376 - val_y2_loss: 0.0498 - val_y1_mae: 0.1189 - val_y2_mae: 0.1403
# Epoch 82/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0186 - y1_loss: 0.0086 - y2_loss: 0.0101 - y1_mae: 0.0647 - y2_mae: 0.0714 - val_loss: 0.0963 - val_y1_loss: 0.0412 - val_y2_loss: 0.0551 - val_y1_mae: 0.1240 - val_y2_mae: 0.1414
# Epoch 83/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0187 - y1_loss: 0.0075 - y2_loss: 0.0111 - y1_mae: 0.0624 - y2_mae: 0.0747 - val_loss: 0.0864 - val_y1_loss: 0.0344 - val_y2_loss: 0.0520 - val_y1_mae: 0.1256 - val_y2_mae: 0.1482
# Epoch 84/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0180 - y1_loss: 0.0077 - y2_loss: 0.0103 - y1_mae: 0.0612 - y2_mae: 0.0727 - val_loss: 0.0989 - val_y1_loss: 0.0480 - val_y2_loss: 0.0509 - val_y1_mae: 0.1496 - val_y2_mae: 0.1448
# Epoch 85/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0225 - y1_loss: 0.0098 - y2_loss: 0.0126 - y1_mae: 0.0698 - y2_mae: 0.0801 - val_loss: 0.0976 - val_y1_loss: 0.0416 - val_y2_loss: 0.0561 - val_y1_mae: 0.1236 - val_y2_mae: 0.1426
# Epoch 86/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0205 - y1_loss: 0.0085 - y2_loss: 0.0120 - y1_mae: 0.0652 - y2_mae: 0.0785 - val_loss: 0.0788 - val_y1_loss: 0.0421 - val_y2_loss: 0.0367 - val_y1_mae: 0.1318 - val_y2_mae: 0.1288
# Epoch 87/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0224 - y1_loss: 0.0095 - y2_loss: 0.0130 - y1_mae: 0.0688 - y2_mae: 0.0816 - val_loss: 0.0791 - val_y1_loss: 0.0370 - val_y2_loss: 0.0421 - val_y1_mae: 0.1176 - val_y2_mae: 0.1342
# Epoch 88/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0204 - y1_loss: 0.0095 - y2_loss: 0.0109 - y1_mae: 0.0694 - y2_mae: 0.0733 - val_loss: 0.0783 - val_y1_loss: 0.0355 - val_y2_loss: 0.0427 - val_y1_mae: 0.1188 - val_y2_mae: 0.1413
# Epoch 89/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0187 - y1_loss: 0.0094 - y2_loss: 0.0093 - y1_mae: 0.0686 - y2_mae: 0.0694 - val_loss: 0.0777 - val_y1_loss: 0.0369 - val_y2_loss: 0.0409 - val_y1_mae: 0.1292 - val_y2_mae: 0.1453
# Epoch 90/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0162 - y1_loss: 0.0072 - y2_loss: 0.0090 - y1_mae: 0.0612 - y2_mae: 0.0685 - val_loss: 0.0770 - val_y1_loss: 0.0351 - val_y2_loss: 0.0419 - val_y1_mae: 0.1220 - val_y2_mae: 0.1371
# Epoch 91/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0169 - y1_loss: 0.0072 - y2_loss: 0.0097 - y1_mae: 0.0608 - y2_mae: 0.0703 - val_loss: 0.0956 - val_y1_loss: 0.0501 - val_y2_loss: 0.0456 - val_y1_mae: 0.1323 - val_y2_mae: 0.1480
# Epoch 92/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0241 - y1_loss: 0.0125 - y2_loss: 0.0116 - y1_mae: 0.0744 - y2_mae: 0.0743 - val_loss: 0.0953 - val_y1_loss: 0.0435 - val_y2_loss: 0.0517 - val_y1_mae: 0.1312 - val_y2_mae: 0.1561
# Epoch 93/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0306 - y1_loss: 0.0145 - y2_loss: 0.0160 - y1_mae: 0.0793 - y2_mae: 0.0858 - val_loss: 0.0904 - val_y1_loss: 0.0410 - val_y2_loss: 0.0494 - val_y1_mae: 0.1284 - val_y2_mae: 0.1443
# Epoch 94/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0267 - y1_loss: 0.0121 - y2_loss: 0.0146 - y1_mae: 0.0777 - y2_mae: 0.0865 - val_loss: 0.0900 - val_y1_loss: 0.0396 - val_y2_loss: 0.0504 - val_y1_mae: 0.1260 - val_y2_mae: 0.1478
# Epoch 95/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0289 - y1_loss: 0.0128 - y2_loss: 0.0161 - y1_mae: 0.0746 - y2_mae: 0.0912 - val_loss: 0.0876 - val_y1_loss: 0.0396 - val_y2_loss: 0.0480 - val_y1_mae: 0.1292 - val_y2_mae: 0.1466
# Epoch 96/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0244 - y1_loss: 0.0117 - y2_loss: 0.0127 - y1_mae: 0.0751 - y2_mae: 0.0811 - val_loss: 0.0836 - val_y1_loss: 0.0391 - val_y2_loss: 0.0444 - val_y1_mae: 0.1183 - val_y2_mae: 0.1363
# Epoch 97/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0182 - y1_loss: 0.0091 - y2_loss: 0.0090 - y1_mae: 0.0670 - y2_mae: 0.0695 - val_loss: 0.0741 - val_y1_loss: 0.0353 - val_y2_loss: 0.0388 - val_y1_mae: 0.1207 - val_y2_mae: 0.1343
# Epoch 98/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0164 - y1_loss: 0.0073 - y2_loss: 0.0091 - y1_mae: 0.0594 - y2_mae: 0.0700 - val_loss: 0.0787 - val_y1_loss: 0.0374 - val_y2_loss: 0.0413 - val_y1_mae: 0.1120 - val_y2_mae: 0.1337
# Epoch 99/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0164 - y1_loss: 0.0067 - y2_loss: 0.0097 - y1_mae: 0.0578 - y2_mae: 0.0696 - val_loss: 0.0763 - val_y1_loss: 0.0339 - val_y2_loss: 0.0424 - val_y1_mae: 0.1158 - val_y2_mae: 0.1273
# Epoch 100/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0175 - y1_loss: 0.0079 - y2_loss: 0.0096 - y1_mae: 0.0618 - y2_mae: 0.0692 - val_loss: 0.0738 - val_y1_loss: 0.0334 - val_y2_loss: 0.0403 - val_y1_mae: 0.1170 - val_y2_mae: 0.1337
# Epoch 101/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0163 - y1_loss: 0.0069 - y2_loss: 0.0094 - y1_mae: 0.0590 - y2_mae: 0.0677 - val_loss: 0.0664 - val_y1_loss: 0.0316 - val_y2_loss: 0.0348 - val_y1_mae: 0.1114 - val_y2_mae: 0.1261
# Epoch 102/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0151 - y1_loss: 0.0066 - y2_loss: 0.0086 - y1_mae: 0.0564 - y2_mae: 0.0656 - val_loss: 0.0771 - val_y1_loss: 0.0358 - val_y2_loss: 0.0413 - val_y1_mae: 0.1127 - val_y2_mae: 0.1293
# Epoch 103/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0161 - y1_loss: 0.0078 - y2_loss: 0.0083 - y1_mae: 0.0609 - y2_mae: 0.0663 - val_loss: 0.0801 - val_y1_loss: 0.0368 - val_y2_loss: 0.0434 - val_y1_mae: 0.1145 - val_y2_mae: 0.1324
# Epoch 104/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0161 - y1_loss: 0.0077 - y2_loss: 0.0084 - y1_mae: 0.0597 - y2_mae: 0.0667 - val_loss: 0.0842 - val_y1_loss: 0.0393 - val_y2_loss: 0.0448 - val_y1_mae: 0.1214 - val_y2_mae: 0.1349
# Epoch 105/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0146 - y1_loss: 0.0064 - y2_loss: 0.0082 - y1_mae: 0.0567 - y2_mae: 0.0653 - val_loss: 0.0810 - val_y1_loss: 0.0370 - val_y2_loss: 0.0439 - val_y1_mae: 0.1195 - val_y2_mae: 0.1368
# Epoch 106/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0144 - y1_loss: 0.0054 - y2_loss: 0.0090 - y1_mae: 0.0531 - y2_mae: 0.0675 - val_loss: 0.0878 - val_y1_loss: 0.0372 - val_y2_loss: 0.0506 - val_y1_mae: 0.1186 - val_y2_mae: 0.1486
# Epoch 107/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0153 - y1_loss: 0.0066 - y2_loss: 0.0087 - y1_mae: 0.0564 - y2_mae: 0.0654 - val_loss: 0.0805 - val_y1_loss: 0.0354 - val_y2_loss: 0.0451 - val_y1_mae: 0.1151 - val_y2_mae: 0.1368
# Epoch 108/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0108 - y1_loss: 0.0043 - y2_loss: 0.0065 - y1_mae: 0.0464 - y2_mae: 0.0589 - val_loss: 0.0722 - val_y1_loss: 0.0368 - val_y2_loss: 0.0354 - val_y1_mae: 0.1188 - val_y2_mae: 0.1206
# Epoch 109/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0120 - y1_loss: 0.0053 - y2_loss: 0.0066 - y1_mae: 0.0516 - y2_mae: 0.0591 - val_loss: 0.0837 - val_y1_loss: 0.0347 - val_y2_loss: 0.0490 - val_y1_mae: 0.1176 - val_y2_mae: 0.1417
# Epoch 110/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0125 - y1_loss: 0.0050 - y2_loss: 0.0075 - y1_mae: 0.0488 - y2_mae: 0.0615 - val_loss: 0.0743 - val_y1_loss: 0.0342 - val_y2_loss: 0.0401 - val_y1_mae: 0.1133 - val_y2_mae: 0.1350
# Epoch 111/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0112 - y1_loss: 0.0044 - y2_loss: 0.0068 - y1_mae: 0.0467 - y2_mae: 0.0587 - val_loss: 0.0749 - val_y1_loss: 0.0352 - val_y2_loss: 0.0397 - val_y1_mae: 0.1140 - val_y2_mae: 0.1281
# Epoch 112/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0106 - y1_loss: 0.0047 - y2_loss: 0.0059 - y1_mae: 0.0478 - y2_mae: 0.0572 - val_loss: 0.0855 - val_y1_loss: 0.0417 - val_y2_loss: 0.0438 - val_y1_mae: 0.1209 - val_y2_mae: 0.1323
# Epoch 113/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0108 - y1_loss: 0.0045 - y2_loss: 0.0063 - y1_mae: 0.0458 - y2_mae: 0.0575 - val_loss: 0.0742 - val_y1_loss: 0.0340 - val_y2_loss: 0.0402 - val_y1_mae: 0.1114 - val_y2_mae: 0.1261
# Epoch 114/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0100 - y1_loss: 0.0037 - y2_loss: 0.0063 - y1_mae: 0.0431 - y2_mae: 0.0568 - val_loss: 0.0788 - val_y1_loss: 0.0346 - val_y2_loss: 0.0442 - val_y1_mae: 0.1170 - val_y2_mae: 0.1466
# Epoch 115/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0104 - y1_loss: 0.0042 - y2_loss: 0.0063 - y1_mae: 0.0458 - y2_mae: 0.0563 - val_loss: 0.0852 - val_y1_loss: 0.0401 - val_y2_loss: 0.0450 - val_y1_mae: 0.1228 - val_y2_mae: 0.1356
# Epoch 116/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0104 - y1_loss: 0.0044 - y2_loss: 0.0059 - y1_mae: 0.0470 - y2_mae: 0.0560 - val_loss: 0.0754 - val_y1_loss: 0.0345 - val_y2_loss: 0.0410 - val_y1_mae: 0.1111 - val_y2_mae: 0.1301
# Epoch 117/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0097 - y1_loss: 0.0036 - y2_loss: 0.0061 - y1_mae: 0.0439 - y2_mae: 0.0570 - val_loss: 0.0708 - val_y1_loss: 0.0315 - val_y2_loss: 0.0393 - val_y1_mae: 0.1081 - val_y2_mae: 0.1265
# Epoch 118/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0094 - y1_loss: 0.0038 - y2_loss: 0.0056 - y1_mae: 0.0427 - y2_mae: 0.0529 - val_loss: 0.0711 - val_y1_loss: 0.0341 - val_y2_loss: 0.0371 - val_y1_mae: 0.1087 - val_y2_mae: 0.1230
# Epoch 119/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0096 - y1_loss: 0.0039 - y2_loss: 0.0057 - y1_mae: 0.0432 - y2_mae: 0.0552 - val_loss: 0.0764 - val_y1_loss: 0.0382 - val_y2_loss: 0.0382 - val_y1_mae: 0.1171 - val_y2_mae: 0.1294
# Epoch 120/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0098 - y1_loss: 0.0039 - y2_loss: 0.0059 - y1_mae: 0.0442 - y2_mae: 0.0549 - val_loss: 0.0718 - val_y1_loss: 0.0324 - val_y2_loss: 0.0393 - val_y1_mae: 0.1108 - val_y2_mae: 0.1244
# Epoch 121/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0105 - y1_loss: 0.0044 - y2_loss: 0.0061 - y1_mae: 0.0448 - y2_mae: 0.0560 - val_loss: 0.0771 - val_y1_loss: 0.0374 - val_y2_loss: 0.0397 - val_y1_mae: 0.1173 - val_y2_mae: 0.1260
# Epoch 122/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0118 - y1_loss: 0.0052 - y2_loss: 0.0066 - y1_mae: 0.0509 - y2_mae: 0.0578 - val_loss: 0.0747 - val_y1_loss: 0.0365 - val_y2_loss: 0.0382 - val_y1_mae: 0.1172 - val_y2_mae: 0.1243
# Epoch 123/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0116 - y1_loss: 0.0050 - y2_loss: 0.0066 - y1_mae: 0.0517 - y2_mae: 0.0595 - val_loss: 0.0747 - val_y1_loss: 0.0347 - val_y2_loss: 0.0400 - val_y1_mae: 0.1190 - val_y2_mae: 0.1302
# Epoch 124/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0105 - y1_loss: 0.0043 - y2_loss: 0.0062 - y1_mae: 0.0450 - y2_mae: 0.0571 - val_loss: 0.0830 - val_y1_loss: 0.0374 - val_y2_loss: 0.0456 - val_y1_mae: 0.1213 - val_y2_mae: 0.1468
# Epoch 125/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0208 - y1_loss: 0.0099 - y2_loss: 0.0109 - y1_mae: 0.0630 - y2_mae: 0.0732 - val_loss: 0.0958 - val_y1_loss: 0.0501 - val_y2_loss: 0.0457 - val_y1_mae: 0.1371 - val_y2_mae: 0.1371
# Epoch 126/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0243 - y1_loss: 0.0112 - y2_loss: 0.0131 - y1_mae: 0.0711 - y2_mae: 0.0815 - val_loss: 0.1006 - val_y1_loss: 0.0428 - val_y2_loss: 0.0578 - val_y1_mae: 0.1342 - val_y2_mae: 0.1607
# Epoch 127/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0253 - y1_loss: 0.0117 - y2_loss: 0.0135 - y1_mae: 0.0738 - y2_mae: 0.0844 - val_loss: 0.0760 - val_y1_loss: 0.0360 - val_y2_loss: 0.0400 - val_y1_mae: 0.1224 - val_y2_mae: 0.1285
# Epoch 128/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0202 - y1_loss: 0.0100 - y2_loss: 0.0102 - y1_mae: 0.0710 - y2_mae: 0.0741 - val_loss: 0.0797 - val_y1_loss: 0.0397 - val_y2_loss: 0.0400 - val_y1_mae: 0.1237 - val_y2_mae: 0.1237
# Epoch 129/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0168 - y1_loss: 0.0073 - y2_loss: 0.0095 - y1_mae: 0.0606 - y2_mae: 0.0730 - val_loss: 0.0754 - val_y1_loss: 0.0345 - val_y2_loss: 0.0409 - val_y1_mae: 0.1196 - val_y2_mae: 0.1313
# Epoch 130/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0210 - y1_loss: 0.0087 - y2_loss: 0.0123 - y1_mae: 0.0649 - y2_mae: 0.0798 - val_loss: 0.0774 - val_y1_loss: 0.0357 - val_y2_loss: 0.0417 - val_y1_mae: 0.1217 - val_y2_mae: 0.1340
# Epoch 131/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0275 - y1_loss: 0.0134 - y2_loss: 0.0141 - y1_mae: 0.0759 - y2_mae: 0.0798 - val_loss: 0.1029 - val_y1_loss: 0.0429 - val_y2_loss: 0.0600 - val_y1_mae: 0.1334 - val_y2_mae: 0.1473
# Epoch 132/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0654 - y1_loss: 0.0283 - y2_loss: 0.0372 - y1_mae: 0.1044 - y2_mae: 0.1171 - val_loss: 0.1115 - val_y1_loss: 0.0631 - val_y2_loss: 0.0484 - val_y1_mae: 0.1618 - val_y2_mae: 0.1504
# Epoch 133/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0582 - y1_loss: 0.0304 - y2_loss: 0.0278 - y1_mae: 0.1178 - y2_mae: 0.1225 - val_loss: 0.1056 - val_y1_loss: 0.0468 - val_y2_loss: 0.0588 - val_y1_mae: 0.1374 - val_y2_mae: 0.1647
# Epoch 134/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0487 - y1_loss: 0.0215 - y2_loss: 0.0272 - y1_mae: 0.1007 - y2_mae: 0.1133 - val_loss: 0.1438 - val_y1_loss: 0.0744 - val_y2_loss: 0.0694 - val_y1_mae: 0.1634 - val_y2_mae: 0.1904
# Epoch 135/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0553 - y1_loss: 0.0239 - y2_loss: 0.0314 - y1_mae: 0.1065 - y2_mae: 0.1256 - val_loss: 0.1059 - val_y1_loss: 0.0516 - val_y2_loss: 0.0543 - val_y1_mae: 0.1553 - val_y2_mae: 0.1564
# Epoch 136/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0541 - y1_loss: 0.0285 - y2_loss: 0.0256 - y1_mae: 0.1147 - y2_mae: 0.1193 - val_loss: 0.1193 - val_y1_loss: 0.0595 - val_y2_loss: 0.0599 - val_y1_mae: 0.1587 - val_y2_mae: 0.1643
# Epoch 137/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0464 - y1_loss: 0.0218 - y2_loss: 0.0246 - y1_mae: 0.1021 - y2_mae: 0.1139 - val_loss: 0.1124 - val_y1_loss: 0.0506 - val_y2_loss: 0.0619 - val_y1_mae: 0.1423 - val_y2_mae: 0.1642
# Epoch 138/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0474 - y1_loss: 0.0220 - y2_loss: 0.0254 - y1_mae: 0.1018 - y2_mae: 0.1168 - val_loss: 0.1031 - val_y1_loss: 0.0331 - val_y2_loss: 0.0700 - val_y1_mae: 0.1121 - val_y2_mae: 0.1844
# Epoch 139/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0459 - y1_loss: 0.0186 - y2_loss: 0.0273 - y1_mae: 0.0945 - y2_mae: 0.1187 - val_loss: 0.1067 - val_y1_loss: 0.0495 - val_y2_loss: 0.0572 - val_y1_mae: 0.1645 - val_y2_mae: 0.1663
# Epoch 140/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0431 - y1_loss: 0.0184 - y2_loss: 0.0247 - y1_mae: 0.0936 - y2_mae: 0.1133 - val_loss: 0.0846 - val_y1_loss: 0.0319 - val_y2_loss: 0.0526 - val_y1_mae: 0.1079 - val_y2_mae: 0.1573
# Epoch 141/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0357 - y1_loss: 0.0150 - y2_loss: 0.0207 - y1_mae: 0.0857 - y2_mae: 0.1024 - val_loss: 0.0789 - val_y1_loss: 0.0354 - val_y2_loss: 0.0434 - val_y1_mae: 0.1172 - val_y2_mae: 0.1409
# Epoch 142/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0286 - y1_loss: 0.0119 - y2_loss: 0.0167 - y1_mae: 0.0766 - y2_mae: 0.0938 - val_loss: 0.1106 - val_y1_loss: 0.0411 - val_y2_loss: 0.0694 - val_y1_mae: 0.1261 - val_y2_mae: 0.1851
# Epoch 143/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0366 - y1_loss: 0.0160 - y2_loss: 0.0205 - y1_mae: 0.0801 - y2_mae: 0.0972 - val_loss: 0.0933 - val_y1_loss: 0.0389 - val_y2_loss: 0.0544 - val_y1_mae: 0.1310 - val_y2_mae: 0.1602
# Epoch 144/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0361 - y1_loss: 0.0153 - y2_loss: 0.0209 - y1_mae: 0.0810 - y2_mae: 0.1010 - val_loss: 0.0867 - val_y1_loss: 0.0400 - val_y2_loss: 0.0467 - val_y1_mae: 0.1315 - val_y2_mae: 0.1473
# Epoch 145/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0319 - y1_loss: 0.0144 - y2_loss: 0.0175 - y1_mae: 0.0798 - y2_mae: 0.0932 - val_loss: 0.0867 - val_y1_loss: 0.0391 - val_y2_loss: 0.0476 - val_y1_mae: 0.1238 - val_y2_mae: 0.1445
# Epoch 146/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0354 - y1_loss: 0.0165 - y2_loss: 0.0188 - y1_mae: 0.0826 - y2_mae: 0.0956 - val_loss: 0.0879 - val_y1_loss: 0.0390 - val_y2_loss: 0.0489 - val_y1_mae: 0.1244 - val_y2_mae: 0.1453
# Epoch 147/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0299 - y1_loss: 0.0122 - y2_loss: 0.0177 - y1_mae: 0.0762 - y2_mae: 0.0917 - val_loss: 0.0841 - val_y1_loss: 0.0398 - val_y2_loss: 0.0443 - val_y1_mae: 0.1182 - val_y2_mae: 0.1385
# Epoch 148/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0216 - y1_loss: 0.0097 - y2_loss: 0.0119 - y1_mae: 0.0688 - y2_mae: 0.0791 - val_loss: 0.1029 - val_y1_loss: 0.0411 - val_y2_loss: 0.0618 - val_y1_mae: 0.1219 - val_y2_mae: 0.1543
# Epoch 149/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0230 - y1_loss: 0.0094 - y2_loss: 0.0136 - y1_mae: 0.0693 - y2_mae: 0.0827 - val_loss: 0.0716 - val_y1_loss: 0.0335 - val_y2_loss: 0.0381 - val_y1_mae: 0.1150 - val_y2_mae: 0.1276
# Epoch 150/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0207 - y1_loss: 0.0096 - y2_loss: 0.0112 - y1_mae: 0.0673 - y2_mae: 0.0755 - val_loss: 0.0899 - val_y1_loss: 0.0397 - val_y2_loss: 0.0503 - val_y1_mae: 0.1275 - val_y2_mae: 0.1533
# Epoch 151/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0186 - y1_loss: 0.0076 - y2_loss: 0.0110 - y1_mae: 0.0633 - y2_mae: 0.0747 - val_loss: 0.0836 - val_y1_loss: 0.0403 - val_y2_loss: 0.0433 - val_y1_mae: 0.1193 - val_y2_mae: 0.1298
# Epoch 152/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0169 - y1_loss: 0.0064 - y2_loss: 0.0106 - y1_mae: 0.0554 - y2_mae: 0.0722 - val_loss: 0.0817 - val_y1_loss: 0.0380 - val_y2_loss: 0.0437 - val_y1_mae: 0.1249 - val_y2_mae: 0.1351
# Epoch 153/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0148 - y1_loss: 0.0059 - y2_loss: 0.0090 - y1_mae: 0.0540 - y2_mae: 0.0683 - val_loss: 0.0713 - val_y1_loss: 0.0329 - val_y2_loss: 0.0384 - val_y1_mae: 0.1066 - val_y2_mae: 0.1257
# Epoch 154/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0150 - y1_loss: 0.0061 - y2_loss: 0.0089 - y1_mae: 0.0530 - y2_mae: 0.0656 - val_loss: 0.0766 - val_y1_loss: 0.0356 - val_y2_loss: 0.0409 - val_y1_mae: 0.1103 - val_y2_mae: 0.1234
# Epoch 155/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0137 - y1_loss: 0.0053 - y2_loss: 0.0084 - y1_mae: 0.0498 - y2_mae: 0.0648 - val_loss: 0.0717 - val_y1_loss: 0.0343 - val_y2_loss: 0.0375 - val_y1_mae: 0.1116 - val_y2_mae: 0.1154
# Epoch 156/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0121 - y1_loss: 0.0050 - y2_loss: 0.0071 - y1_mae: 0.0491 - y2_mae: 0.0593 - val_loss: 0.0745 - val_y1_loss: 0.0332 - val_y2_loss: 0.0412 - val_y1_mae: 0.1094 - val_y2_mae: 0.1251
# Epoch 157/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0113 - y1_loss: 0.0044 - y2_loss: 0.0069 - y1_mae: 0.0462 - y2_mae: 0.0578 - val_loss: 0.0754 - val_y1_loss: 0.0352 - val_y2_loss: 0.0401 - val_y1_mae: 0.1091 - val_y2_mae: 0.1268
# Epoch 158/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0103 - y1_loss: 0.0042 - y2_loss: 0.0061 - y1_mae: 0.0459 - y2_mae: 0.0548 - val_loss: 0.0719 - val_y1_loss: 0.0336 - val_y2_loss: 0.0384 - val_y1_mae: 0.1062 - val_y2_mae: 0.1185
# Epoch 159/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0101 - y1_loss: 0.0039 - y2_loss: 0.0063 - y1_mae: 0.0441 - y2_mae: 0.0557 - val_loss: 0.0755 - val_y1_loss: 0.0357 - val_y2_loss: 0.0398 - val_y1_mae: 0.1138 - val_y2_mae: 0.1203
# Epoch 160/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0093 - y1_loss: 0.0034 - y2_loss: 0.0059 - y1_mae: 0.0419 - y2_mae: 0.0559 - val_loss: 0.0780 - val_y1_loss: 0.0379 - val_y2_loss: 0.0401 - val_y1_mae: 0.1160 - val_y2_mae: 0.1228
# Epoch 161/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0106 - y1_loss: 0.0043 - y2_loss: 0.0063 - y1_mae: 0.0451 - y2_mae: 0.0569 - val_loss: 0.0711 - val_y1_loss: 0.0328 - val_y2_loss: 0.0383 - val_y1_mae: 0.1076 - val_y2_mae: 0.1215
# Epoch 162/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0116 - y1_loss: 0.0045 - y2_loss: 0.0072 - y1_mae: 0.0456 - y2_mae: 0.0594 - val_loss: 0.0795 - val_y1_loss: 0.0390 - val_y2_loss: 0.0404 - val_y1_mae: 0.1168 - val_y2_mae: 0.1214
# Epoch 163/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0114 - y1_loss: 0.0042 - y2_loss: 0.0072 - y1_mae: 0.0444 - y2_mae: 0.0606 - val_loss: 0.0783 - val_y1_loss: 0.0383 - val_y2_loss: 0.0400 - val_y1_mae: 0.1204 - val_y2_mae: 0.1243
# Epoch 164/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0100 - y1_loss: 0.0038 - y2_loss: 0.0063 - y1_mae: 0.0427 - y2_mae: 0.0568 - val_loss: 0.0711 - val_y1_loss: 0.0298 - val_y2_loss: 0.0413 - val_y1_mae: 0.0981 - val_y2_mae: 0.1324
# Epoch 165/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0102 - y1_loss: 0.0040 - y2_loss: 0.0062 - y1_mae: 0.0437 - y2_mae: 0.0560 - val_loss: 0.0762 - val_y1_loss: 0.0341 - val_y2_loss: 0.0422 - val_y1_mae: 0.1060 - val_y2_mae: 0.1242
# Epoch 166/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0186 - y1_loss: 0.0081 - y2_loss: 0.0105 - y1_mae: 0.0541 - y2_mae: 0.0655 - val_loss: 0.0738 - val_y1_loss: 0.0353 - val_y2_loss: 0.0385 - val_y1_mae: 0.1084 - val_y2_mae: 0.1241
# Epoch 167/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0163 - y1_loss: 0.0069 - y2_loss: 0.0094 - y1_mae: 0.0563 - y2_mae: 0.0658 - val_loss: 0.1115 - val_y1_loss: 0.0558 - val_y2_loss: 0.0557 - val_y1_mae: 0.1510 - val_y2_mae: 0.1418
# Epoch 168/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0244 - y1_loss: 0.0101 - y2_loss: 0.0143 - y1_mae: 0.0687 - y2_mae: 0.0813 - val_loss: 0.0865 - val_y1_loss: 0.0429 - val_y2_loss: 0.0436 - val_y1_mae: 0.1239 - val_y2_mae: 0.1303
# Epoch 169/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0194 - y1_loss: 0.0079 - y2_loss: 0.0115 - y1_mae: 0.0621 - y2_mae: 0.0742 - val_loss: 0.0922 - val_y1_loss: 0.0424 - val_y2_loss: 0.0497 - val_y1_mae: 0.1189 - val_y2_mae: 0.1371
# Epoch 170/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0181 - y1_loss: 0.0073 - y2_loss: 0.0107 - y1_mae: 0.0585 - y2_mae: 0.0738 - val_loss: 0.0860 - val_y1_loss: 0.0394 - val_y2_loss: 0.0466 - val_y1_mae: 0.1178 - val_y2_mae: 0.1321
# Epoch 171/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0141 - y1_loss: 0.0057 - y2_loss: 0.0084 - y1_mae: 0.0533 - y2_mae: 0.0674 - val_loss: 0.0787 - val_y1_loss: 0.0378 - val_y2_loss: 0.0409 - val_y1_mae: 0.1133 - val_y2_mae: 0.1236
# Epoch 172/1000
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0121 - y1_loss: 0.0050 - y2_loss: 0.0072 - y1_mae: 0.0497 - y2_mae: 0.0602 - val_loss: 0.0793 - val_y1_loss: 0.0369 - val_y2_loss: 0.0425 - val_y1_mae: 0.1108 - val_y2_mae: 0.1236
# Epoch 173/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0107 - y1_loss: 0.0044 - y2_loss: 0.0063 - y1_mae: 0.0470 - y2_mae: 0.0575 - val_loss: 0.0793 - val_y1_loss: 0.0386 - val_y2_loss: 0.0407 - val_y1_mae: 0.1177 - val_y2_mae: 0.1203
# Epoch 174/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0103 - y1_loss: 0.0044 - y2_loss: 0.0059 - y1_mae: 0.0456 - y2_mae: 0.0545 - val_loss: 0.0717 - val_y1_loss: 0.0334 - val_y2_loss: 0.0383 - val_y1_mae: 0.1024 - val_y2_mae: 0.1199
# Epoch 175/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0094 - y1_loss: 0.0037 - y2_loss: 0.0057 - y1_mae: 0.0407 - y2_mae: 0.0529 - val_loss: 0.0777 - val_y1_loss: 0.0330 - val_y2_loss: 0.0447 - val_y1_mae: 0.1051 - val_y2_mae: 0.1269
# Epoch 176/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0088 - y1_loss: 0.0032 - y2_loss: 0.0056 - y1_mae: 0.0387 - y2_mae: 0.0528 - val_loss: 0.0760 - val_y1_loss: 0.0330 - val_y2_loss: 0.0430 - val_y1_mae: 0.1028 - val_y2_mae: 0.1221
# Epoch 177/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - y1_loss: 0.0029 - y2_loss: 0.0057 - y1_mae: 0.0387 - y2_mae: 0.0526 - val_loss: 0.0716 - val_y1_loss: 0.0342 - val_y2_loss: 0.0374 - val_y1_mae: 0.1060 - val_y2_mae: 0.1203
# Epoch 178/1000
# ...
# Epoch 940/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - y1_loss: 0.0016 - y2_loss: 0.0023 - y1_mae: 0.0279 - y2_mae: 0.0364 - val_loss: 0.0839 - val_y1_loss: 0.0354 - val_y2_loss: 0.0485 - val_y1_mae: 0.0976 - val_y2_mae: 0.1317
# Epoch 941/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0042 - y1_loss: 0.0016 - y2_loss: 0.0025 - y1_mae: 0.0284 - y2_mae: 0.0358 - val_loss: 0.0852 - val_y1_loss: 0.0360 - val_y2_loss: 0.0491 - val_y1_mae: 0.0979 - val_y2_mae: 0.1316
# Epoch 942/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - y1_loss: 0.0016 - y2_loss: 0.0025 - y1_mae: 0.0277 - y2_mae: 0.0363 - val_loss: 0.0802 - val_y1_loss: 0.0334 - val_y2_loss: 0.0468 - val_y1_mae: 0.0962 - val_y2_mae: 0.1293
# Epoch 943/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0044 - y1_loss: 0.0017 - y2_loss: 0.0027 - y1_mae: 0.0288 - y2_mae: 0.0392 - val_loss: 0.0849 - val_y1_loss: 0.0341 - val_y2_loss: 0.0508 - val_y1_mae: 0.0939 - val_y2_mae: 0.1397
# Epoch 944/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0042 - y1_loss: 0.0014 - y2_loss: 0.0029 - y1_mae: 0.0262 - y2_mae: 0.0402 - val_loss: 0.0839 - val_y1_loss: 0.0343 - val_y2_loss: 0.0495 - val_y1_mae: 0.0941 - val_y2_mae: 0.1350
# Epoch 945/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0037 - y1_loss: 0.0012 - y2_loss: 0.0025 - y1_mae: 0.0253 - y2_mae: 0.0369 - val_loss: 0.0816 - val_y1_loss: 0.0342 - val_y2_loss: 0.0474 - val_y1_mae: 0.0950 - val_y2_mae: 0.1307
# Epoch 946/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0038 - y1_loss: 0.0013 - y2_loss: 0.0025 - y1_mae: 0.0256 - y2_mae: 0.0361 - val_loss: 0.0827 - val_y1_loss: 0.0347 - val_y2_loss: 0.0480 - val_y1_mae: 0.0961 - val_y2_mae: 0.1336
# Epoch 947/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0038 - y1_loss: 0.0015 - y2_loss: 0.0023 - y1_mae: 0.0274 - y2_mae: 0.0355 - val_loss: 0.0801 - val_y1_loss: 0.0333 - val_y2_loss: 0.0468 - val_y1_mae: 0.0963 - val_y2_mae: 0.1296
# Epoch 948/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0044 - y1_loss: 0.0020 - y2_loss: 0.0024 - y1_mae: 0.0298 - y2_mae: 0.0358 - val_loss: 0.0796 - val_y1_loss: 0.0330 - val_y2_loss: 0.0466 - val_y1_mae: 0.0945 - val_y2_mae: 0.1305
# Epoch 949/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - y1_loss: 0.0020 - y2_loss: 0.0029 - y1_mae: 0.0296 - y2_mae: 0.0380 - val_loss: 0.0835 - val_y1_loss: 0.0344 - val_y2_loss: 0.0490 - val_y1_mae: 0.0992 - val_y2_mae: 0.1343
# Epoch 950/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0046 - y1_loss: 0.0018 - y2_loss: 0.0027 - y1_mae: 0.0295 - y2_mae: 0.0385 - val_loss: 0.0842 - val_y1_loss: 0.0358 - val_y2_loss: 0.0484 - val_y1_mae: 0.0984 - val_y2_mae: 0.1308
# Epoch 951/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0042 - y1_loss: 0.0015 - y2_loss: 0.0027 - y1_mae: 0.0274 - y2_mae: 0.0374 - val_loss: 0.0843 - val_y1_loss: 0.0357 - val_y2_loss: 0.0486 - val_y1_mae: 0.0990 - val_y2_mae: 0.1307
# Epoch 952/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0048 - y1_loss: 0.0016 - y2_loss: 0.0032 - y1_mae: 0.0285 - y2_mae: 0.0401 - val_loss: 0.0838 - val_y1_loss: 0.0323 - val_y2_loss: 0.0515 - val_y1_mae: 0.0942 - val_y2_mae: 0.1362
# Epoch 953/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - y1_loss: 0.0021 - y2_loss: 0.0032 - y1_mae: 0.0302 - y2_mae: 0.0403 - val_loss: 0.0919 - val_y1_loss: 0.0380 - val_y2_loss: 0.0539 - val_y1_mae: 0.1006 - val_y2_mae: 0.1359
# Epoch 954/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0061 - y1_loss: 0.0019 - y2_loss: 0.0041 - y1_mae: 0.0305 - y2_mae: 0.0448 - val_loss: 0.0856 - val_y1_loss: 0.0368 - val_y2_loss: 0.0488 - val_y1_mae: 0.1030 - val_y2_mae: 0.1335
# Epoch 955/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - y1_loss: 0.0017 - y2_loss: 0.0028 - y1_mae: 0.0300 - y2_mae: 0.0390 - val_loss: 0.0894 - val_y1_loss: 0.0371 - val_y2_loss: 0.0523 - val_y1_mae: 0.1004 - val_y2_mae: 0.1389
# Epoch 956/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - y1_loss: 0.0018 - y2_loss: 0.0028 - y1_mae: 0.0294 - y2_mae: 0.0396 - val_loss: 0.0831 - val_y1_loss: 0.0350 - val_y2_loss: 0.0481 - val_y1_mae: 0.0973 - val_y2_mae: 0.1336
# Epoch 957/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - y1_loss: 0.0016 - y2_loss: 0.0034 - y1_mae: 0.0276 - y2_mae: 0.0431 - val_loss: 0.0827 - val_y1_loss: 0.0319 - val_y2_loss: 0.0508 - val_y1_mae: 0.0935 - val_y2_mae: 0.1357
# Epoch 958/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0044 - y1_loss: 0.0014 - y2_loss: 0.0030 - y1_mae: 0.0269 - y2_mae: 0.0401 - val_loss: 0.0805 - val_y1_loss: 0.0336 - val_y2_loss: 0.0469 - val_y1_mae: 0.0951 - val_y2_mae: 0.1332
# Epoch 959/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0039 - y1_loss: 0.0015 - y2_loss: 0.0024 - y1_mae: 0.0268 - y2_mae: 0.0359 - val_loss: 0.0808 - val_y1_loss: 0.0337 - val_y2_loss: 0.0471 - val_y1_mae: 0.0935 - val_y2_mae: 0.1306
# Epoch 960/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0035 - y1_loss: 0.0011 - y2_loss: 0.0024 - y1_mae: 0.0231 - y2_mae: 0.0358 - val_loss: 0.0834 - val_y1_loss: 0.0357 - val_y2_loss: 0.0477 - val_y1_mae: 0.0990 - val_y2_mae: 0.1309
# Epoch 961/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0031 - y1_loss: 0.0011 - y2_loss: 0.0020 - y1_mae: 0.0243 - y2_mae: 0.0329 - val_loss: 0.0779 - val_y1_loss: 0.0324 - val_y2_loss: 0.0455 - val_y1_mae: 0.0931 - val_y2_mae: 0.1283
# Epoch 962/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0033 - y1_loss: 0.0011 - y2_loss: 0.0022 - y1_mae: 0.0233 - y2_mae: 0.0341 - val_loss: 0.0833 - val_y1_loss: 0.0363 - val_y2_loss: 0.0470 - val_y1_mae: 0.0978 - val_y2_mae: 0.1326
# Epoch 963/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0030 - y1_loss: 0.0011 - y2_loss: 0.0019 - y1_mae: 0.0235 - y2_mae: 0.0327 - val_loss: 0.0751 - val_y1_loss: 0.0312 - val_y2_loss: 0.0439 - val_y1_mae: 0.0908 - val_y2_mae: 0.1259
# Epoch 964/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0029 - y1_loss: 0.0011 - y2_loss: 0.0018 - y1_mae: 0.0230 - y2_mae: 0.0310 - val_loss: 0.0809 - val_y1_loss: 0.0334 - val_y2_loss: 0.0474 - val_y1_mae: 0.0968 - val_y2_mae: 0.1308
# Epoch 965/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0027 - y1_loss: 0.0010 - y2_loss: 0.0017 - y1_mae: 0.0229 - y2_mae: 0.0303 - val_loss: 0.0811 - val_y1_loss: 0.0350 - val_y2_loss: 0.0461 - val_y1_mae: 0.0973 - val_y2_mae: 0.1265
# Epoch 966/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0028 - y1_loss: 0.0011 - y2_loss: 0.0017 - y1_mae: 0.0239 - y2_mae: 0.0307 - val_loss: 0.0872 - val_y1_loss: 0.0378 - val_y2_loss: 0.0494 - val_y1_mae: 0.0953 - val_y2_mae: 0.1367
# Epoch 967/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0030 - y1_loss: 0.0011 - y2_loss: 0.0019 - y1_mae: 0.0231 - y2_mae: 0.0322 - val_loss: 0.0833 - val_y1_loss: 0.0350 - val_y2_loss: 0.0483 - val_y1_mae: 0.0968 - val_y2_mae: 0.1305
# Epoch 968/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030 - y1_loss: 9.9640e-04 - y2_loss: 0.0021 - y1_mae: 0.0225 - y2_mae: 0.0332 - val_loss: 0.0775 - val_y1_loss: 0.0330 - val_y2_loss: 0.0445 - val_y1_mae: 0.0980 - val_y2_mae: 0.1287
# Epoch 969/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0033 - y1_loss: 0.0011 - y2_loss: 0.0022 - y1_mae: 0.0240 - y2_mae: 0.0343 - val_loss: 0.0829 - val_y1_loss: 0.0350 - val_y2_loss: 0.0479 - val_y1_mae: 0.0972 - val_y2_mae: 0.1300
# Epoch 970/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0032 - y1_loss: 0.0010 - y2_loss: 0.0022 - y1_mae: 0.0230 - y2_mae: 0.0337 - val_loss: 0.0777 - val_y1_loss: 0.0324 - val_y2_loss: 0.0453 - val_y1_mae: 0.0931 - val_y2_mae: 0.1280
# Epoch 971/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0029 - y1_loss: 8.9716e-04 - y2_loss: 0.0020 - y1_mae: 0.0217 - y2_mae: 0.0322 - val_loss: 0.0811 - val_y1_loss: 0.0353 - val_y2_loss: 0.0458 - val_y1_mae: 0.0947 - val_y2_mae: 0.1277
# Epoch 972/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0029 - y1_loss: 9.7570e-04 - y2_loss: 0.0019 - y1_mae: 0.0228 - y2_mae: 0.0321 - val_loss: 0.0787 - val_y1_loss: 0.0323 - val_y2_loss: 0.0464 - val_y1_mae: 0.0943 - val_y2_mae: 0.1297
# Epoch 973/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0036 - y1_loss: 0.0013 - y2_loss: 0.0023 - y1_mae: 0.0256 - y2_mae: 0.0349 - val_loss: 0.0818 - val_y1_loss: 0.0335 - val_y2_loss: 0.0483 - val_y1_mae: 0.0915 - val_y2_mae: 0.1340
# Epoch 974/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0038 - y1_loss: 0.0013 - y2_loss: 0.0025 - y1_mae: 0.0255 - y2_mae: 0.0365 - val_loss: 0.0780 - val_y1_loss: 0.0313 - val_y2_loss: 0.0466 - val_y1_mae: 0.0920 - val_y2_mae: 0.1341
# Epoch 975/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0039 - y1_loss: 0.0014 - y2_loss: 0.0025 - y1_mae: 0.0267 - y2_mae: 0.0368 - val_loss: 0.0775 - val_y1_loss: 0.0311 - val_y2_loss: 0.0464 - val_y1_mae: 0.0940 - val_y2_mae: 0.1290
# Epoch 976/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - y1_loss: 0.0017 - y2_loss: 0.0028 - y1_mae: 0.0285 - y2_mae: 0.0381 - val_loss: 0.0806 - val_y1_loss: 0.0344 - val_y2_loss: 0.0462 - val_y1_mae: 0.0984 - val_y2_mae: 0.1296
# Epoch 977/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0042 - y1_loss: 0.0014 - y2_loss: 0.0028 - y1_mae: 0.0254 - y2_mae: 0.0387 - val_loss: 0.0789 - val_y1_loss: 0.0329 - val_y2_loss: 0.0460 - val_y1_mae: 0.0939 - val_y2_mae: 0.1290
# Epoch 978/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0037 - y1_loss: 0.0014 - y2_loss: 0.0023 - y1_mae: 0.0264 - y2_mae: 0.0354 - val_loss: 0.0780 - val_y1_loss: 0.0325 - val_y2_loss: 0.0455 - val_y1_mae: 0.0938 - val_y2_mae: 0.1293
# Epoch 979/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0047 - y1_loss: 0.0019 - y2_loss: 0.0027 - y1_mae: 0.0302 - y2_mae: 0.0378 - val_loss: 0.0873 - val_y1_loss: 0.0379 - val_y2_loss: 0.0494 - val_y1_mae: 0.1093 - val_y2_mae: 0.1307
# Epoch 980/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0046 - y1_loss: 0.0019 - y2_loss: 0.0027 - y1_mae: 0.0302 - y2_mae: 0.0383 - val_loss: 0.0787 - val_y1_loss: 0.0333 - val_y2_loss: 0.0454 - val_y1_mae: 0.0976 - val_y2_mae: 0.1315
# Epoch 981/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0054 - y1_loss: 0.0024 - y2_loss: 0.0030 - y1_mae: 0.0317 - y2_mae: 0.0407 - val_loss: 0.0821 - val_y1_loss: 0.0339 - val_y2_loss: 0.0482 - val_y1_mae: 0.0998 - val_y2_mae: 0.1296
# Epoch 982/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0055 - y1_loss: 0.0024 - y2_loss: 0.0031 - y1_mae: 0.0338 - y2_mae: 0.0415 - val_loss: 0.0834 - val_y1_loss: 0.0363 - val_y2_loss: 0.0470 - val_y1_mae: 0.1038 - val_y2_mae: 0.1326
# Epoch 983/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0049 - y1_loss: 0.0021 - y2_loss: 0.0028 - y1_mae: 0.0318 - y2_mae: 0.0394 - val_loss: 0.0860 - val_y1_loss: 0.0381 - val_y2_loss: 0.0479 - val_y1_mae: 0.1031 - val_y2_mae: 0.1316
# Epoch 984/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0058 - y1_loss: 0.0023 - y2_loss: 0.0035 - y1_mae: 0.0340 - y2_mae: 0.0408 - val_loss: 0.0842 - val_y1_loss: 0.0350 - val_y2_loss: 0.0493 - val_y1_mae: 0.0986 - val_y2_mae: 0.1364
# Epoch 985/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0051 - y1_loss: 0.0018 - y2_loss: 0.0033 - y1_mae: 0.0304 - y2_mae: 0.0425 - val_loss: 0.0812 - val_y1_loss: 0.0349 - val_y2_loss: 0.0463 - val_y1_mae: 0.1037 - val_y2_mae: 0.1282
# Epoch 986/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0051 - y1_loss: 0.0022 - y2_loss: 0.0029 - y1_mae: 0.0332 - y2_mae: 0.0387 - val_loss: 0.0772 - val_y1_loss: 0.0328 - val_y2_loss: 0.0444 - val_y1_mae: 0.1017 - val_y2_mae: 0.1254
# Epoch 987/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0041 - y1_loss: 0.0017 - y2_loss: 0.0023 - y1_mae: 0.0298 - y2_mae: 0.0359 - val_loss: 0.0813 - val_y1_loss: 0.0337 - val_y2_loss: 0.0475 - val_y1_mae: 0.0999 - val_y2_mae: 0.1367
# Epoch 988/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0054 - y1_loss: 0.0024 - y2_loss: 0.0030 - y1_mae: 0.0333 - y2_mae: 0.0406 - val_loss: 0.0868 - val_y1_loss: 0.0383 - val_y2_loss: 0.0485 - val_y1_mae: 0.1083 - val_y2_mae: 0.1285
# Epoch 989/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0070 - y1_loss: 0.0040 - y2_loss: 0.0031 - y1_mae: 0.0434 - y2_mae: 0.0420 - val_loss: 0.0790 - val_y1_loss: 0.0348 - val_y2_loss: 0.0442 - val_y1_mae: 0.1014 - val_y2_mae: 0.1296
# Epoch 990/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0068 - y1_loss: 0.0035 - y2_loss: 0.0034 - y1_mae: 0.0391 - y2_mae: 0.0424 - val_loss: 0.0811 - val_y1_loss: 0.0333 - val_y2_loss: 0.0478 - val_y1_mae: 0.0957 - val_y2_mae: 0.1310
# Epoch 991/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0062 - y1_loss: 0.0029 - y2_loss: 0.0033 - y1_mae: 0.0352 - y2_mae: 0.0416 - val_loss: 0.0881 - val_y1_loss: 0.0368 - val_y2_loss: 0.0512 - val_y1_mae: 0.1046 - val_y2_mae: 0.1402
# Epoch 992/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0066 - y1_loss: 0.0028 - y2_loss: 0.0038 - y1_mae: 0.0366 - y2_mae: 0.0437 - val_loss: 0.0827 - val_y1_loss: 0.0358 - val_y2_loss: 0.0470 - val_y1_mae: 0.1040 - val_y2_mae: 0.1301
# Epoch 993/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0053 - y1_loss: 0.0023 - y2_loss: 0.0031 - y1_mae: 0.0327 - y2_mae: 0.0410 - val_loss: 0.0856 - val_y1_loss: 0.0357 - val_y2_loss: 0.0499 - val_y1_mae: 0.0984 - val_y2_mae: 0.1335
# Epoch 994/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0050 - y1_loss: 0.0023 - y2_loss: 0.0027 - y1_mae: 0.0326 - y2_mae: 0.0382 - val_loss: 0.0854 - val_y1_loss: 0.0374 - val_y2_loss: 0.0480 - val_y1_mae: 0.1085 - val_y2_mae: 0.1300
# Epoch 995/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0065 - y1_loss: 0.0037 - y2_loss: 0.0028 - y1_mae: 0.0419 - y2_mae: 0.0384 - val_loss: 0.0832 - val_y1_loss: 0.0342 - val_y2_loss: 0.0490 - val_y1_mae: 0.1018 - val_y2_mae: 0.1329
# Epoch 996/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0051 - y1_loss: 0.0021 - y2_loss: 0.0030 - y1_mae: 0.0313 - y2_mae: 0.0398 - val_loss: 0.0808 - val_y1_loss: 0.0327 - val_y2_loss: 0.0481 - val_y1_mae: 0.0948 - val_y2_mae: 0.1315
# Epoch 997/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0052 - y1_loss: 0.0022 - y2_loss: 0.0029 - y1_mae: 0.0320 - y2_mae: 0.0393 - val_loss: 0.0843 - val_y1_loss: 0.0334 - val_y2_loss: 0.0508 - val_y1_mae: 0.1038 - val_y2_mae: 0.1370
# Epoch 998/1000
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0053 - y1_loss: 0.0023 - y2_loss: 0.0030 - y1_mae: 0.0331 - y2_mae: 0.0399 - val_loss: 0.0810 - val_y1_loss: 0.0335 - val_y2_loss: 0.0474 - val_y1_mae: 0.0959 - val_y2_mae: 0.1282
# Epoch 999/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0038 - y1_loss: 0.0015 - y2_loss: 0.0023 - y1_mae: 0.0269 - y2_mae: 0.0350 - val_loss: 0.0815 - val_y1_loss: 0.0333 - val_y2_loss: 0.0481 - val_y1_mae: 0.0971 - val_y2_mae: 0.1362
# Epoch 1000/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0045 - y1_loss: 0.0020 - y2_loss: 0.0025 - y1_mae: 0.0304 - y2_mae: 0.0367 - val_loss: 0.0809 - val_y1_loss: 0.0314 - val_y2_loss: 0.0495 - val_y1_mae: 0.0924 - val_y2_mae: 0.1324
#
#     The hyperparameter search is complete. The optimal learning rate for the optimizer
#     is 0.008202631026506424.

# %%
best_model.save(model_path)
# best_model = tf.keras.models.load_model(model_path)
best_model.summary()
# Out:
# INFO:tensorflow:Assets written to: saved_model/Multi_leak/experiment4/Mask/assets
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10)]         0           []
#
#  dense (Dense)                  (None, 512)          5632        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 448)          229824      ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 416)          186784      ['dense_1[0][0]']
#
#  y1 (Dense)                     (None, 2)            834         ['dense_2[0][0]']
#
#  y2 (Dense)                     (None, 2)            834         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 423,908
# Trainable params: 423,908
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
y_predictions_train = best_model.predict(train_dataset_org.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})))
# print("train", "{:10.4f}".format(mean_squared_error(y_train, y_predictions, squared=True)))
y_predictions_val = best_model.predict(val_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})))
# print("val", "{:10.4f}".format(mean_squared_error(y_val, y_predictions, squared=True)))
y_predictions = best_model.predict(test_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})))

y_predictions_train = np.concatenate((y_predictions_train[0], y_predictions_train[1]), axis=1)
y_predictions_val = np.concatenate((y_predictions_val[0], y_predictions_val[1]), axis=1)
y_predictions = np.concatenate((y_predictions[0], y_predictions[1]), axis=1)

loss_test = "{:10.4f}".format(mean_squared_error(y_test_all, y_predictions, squared=True))
metric_test = "{:10.4f}".format(mean_absolute_error(y_test_all, y_predictions))

loss_val = "{:10.4f}".format(mean_squared_error(y_val_all, y_predictions_val, squared=True))
metric_val = "{:10.4f}".format(mean_absolute_error(y_val_all, y_predictions_val))

loss_train = "{:10.4f}".format(mean_squared_error(y_train_all, y_predictions_train, squared=True))
metric_train = "{:10.4f}".format(mean_absolute_error(y_train_all, y_predictions_train))


print(metric_train, metric_val, metric_test )
# Out:
#  1/17 [>.............................] - ETA: 0s
# 17/17 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
#     0.0314     0.1124     0.1241

# %%
results_train = best_model.evaluate(train_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})), verbose=1)
results_val = best_model.evaluate(val_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})), verbose=1)
results_test = best_model.evaluate(test_dataset.map(lambda x, y1, y2: (x, {'y1': y1, 'y2': y2})), verbose=1)
# Out:
#  1/17 [>.............................] - ETA: 0s - loss: 0.0053 - y1_loss: 0.0016 - y2_loss: 0.0037 - y1_mae: 0.0289 - y2_mae: 0.0462
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0041 - y1_loss: 0.0014 - y2_loss: 0.0028 - y1_mae: 0.0256 - y2_mae: 0.0372
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0809 - y1_loss: 0.0314 - y2_loss: 0.0495 - y1_mae: 0.0924 - y2_mae: 0.1324
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0778 - y1_loss: 0.0272 - y2_loss: 0.0506 - y1_mae: 0.1014 - y2_mae: 0.1469

# %%
# 0.0278     0.1090     0.1215
#  0.0435     0.1084     0.1193
# 0.0319     0.1170     0.1183
#  0.0285     0.1099     0.1099

# 0.03262	0.11134	0.11862
