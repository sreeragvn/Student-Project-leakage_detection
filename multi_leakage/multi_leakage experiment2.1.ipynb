# %%
# NN 4 outputs and with and without sorting of outputs
model_path = 'saved_model/Multi_leak/experiment2/withoutswap/'
project_name='Multi_leak_experiment2_withoutSwap'

# %%
# Experiment 2 - 1 output layer with 1 loss function - mse. and do hyper parameter tuning.
from utils.data_preprocess import load_data, load_single_leakage_model_data
from utils.module import model_eval, hyper_model, model_comparison, linear_regression, numpy_to_tensor, benchmark_linear_model
import itertools
import pandas as pd 
import yaml
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Model
from keras.layers import Dense, Input
import keras_tuner as kt
from tensorflow import keras
from keras import layers
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
# Out:
# 2.12.1
# # GPUs Available:  1

# %%
single_leakage, two_leakage = load_data()
# two_leakage["leak_1"] = 1
# two_leakage["leak_2"] = 1

# single_leakage["leak_1"] = 1
# single_leakage["leak_2"] = 0

data = pd.concat([single_leakage, two_leakage], axis=0)
data['x2'] = data['x2'].replace(np.nan, 8024)
data['y2'] = data['y2'].replace(np.nan, 2616.5)

data = data.drop(columns=['mfc6_residual',
       'mfc7_residual', 'mfc8_residual', 'mfc9_residual', 'mfc10_residual',
       'mfc1_residual', 'mfc2_residual', 'mfc3_residual', 'mfc4_residual',
       'mfc5_residual', 'total flow rate'])

print(data.columns)
print(data.isna().sum())

y = data[['x1', 'y1', 'x2', 'y2']]
x = data.drop(['x1', 'y1', 'x2', 'y2'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1) 

y1_train = y_train[['x1', 'y1', 'x2', 'y2']]
# y2_train = y_train[['leak_1', 'leak_2']]
y1_test = y_test[['x1', 'y1', 'x2', 'y2']]
# y2_test = y_test[['leak_1', 'leak_2']]
y1_val = y_val[['x1', 'y1', 'x2', 'y2']]
# y2_val = y_val[['leak_1', 'leak_2']]

def coords_swap(y1):
    s = y1['x2'] < y1['x1']
    y1.loc[s, ['x1','x2']] = y1.loc[s, ['x2','x1']].values
    y1.loc[s, ['y1','y2']] = y1.loc[s, ['y2','y1']].values
    return y1

# y1_data = [y1_train, y1_val, y1_test]
# y1_data_types = ['y1_train', 'y1_val', 'y1_test']
# for y1_data_types, y1 in zip(y1_data_types, y1_data):
#     y1_data_types = coords_swap(y1)

y1_columns = y1_train.columns
# y2_columns = y2_train.columns
X_columns = X_train.columns

scaler_coords1 = StandardScaler()
y1_train = scaler_coords1.fit_transform(y1_train)
y1_test = scaler_coords1.transform(y1_test)
y1_val = scaler_coords1.transform(y1_val)

y_train_sc = pd.DataFrame(y1_train, columns=y1_columns)
y_test_sc = pd.DataFrame(y1_test, columns=y1_columns)
y_val_sc = pd.DataFrame(y1_val, columns=y1_columns)

# y1_train['x2'] = y1_train['x2'].replace(np.nan, -5)
# y1_train['y2'] = y1_train['y2'].replace(np.nan, -5)

# y1_test['x2'] = y1_test['x2'].replace(np.nan, -5)
# y1_test['y2'] = y1_test['y2'].replace(np.nan, -5)

# y1_val['x2'] = y1_val['x2'].replace(np.nan, -5)
# y1_val['y2'] = y1_val['y2'].replace(np.nan, -5)
# Not sure if 0 is good enough or try generating a random number

# scaler_coords2 = StandardScaler()
# y2_train = scaler_coords2.fit_transform(y2_train)
# y2_test = scaler_coords2.fit_transform(y2_test)
# y2_val = scaler_coords2.transform(y2_val)

# y2_train = pd.DataFrame(y2_train, columns=y2_columns)
# y2_test = pd.DataFrame(y2_test, columns=y2_columns)
# y2_val = pd.DataFrame(y2_val, columns=y2_columns)

# y2_train = y2_train.reset_index().drop(columns='sample_number')
# y2_val = y2_val.reset_index().drop(columns='sample_number')
# y2_test = y2_test.reset_index().drop(columns='sample_number')

# y_train_sc = pd.concat([y1_train, y2_train], axis=1)
# y_test_sc = pd.concat([y1_test, y2_test], axis=1)
# y_val_sc = pd.concat([y1_val, y2_val], axis=1)

scaler_flows = StandardScaler()
X_train = scaler_flows.fit_transform(X_train)
X_test = scaler_flows.transform(X_test)
X_val = scaler_flows.transform(X_val)
# Out:
# Index(['x1', 'y1', 'MFC6', 'MFC7', 'MFC8', 'MFC9', 'MFC10', 'MFC1', 'MFC2',
#        'MFC3', 'MFC4', 'MFC5', 'x2', 'y2'],
#       dtype='object')
# x1       0
# y1       0
# MFC6     0
# MFC7     0
# MFC8     0
# MFC9     0
# MFC10    0
# MFC1     0
# MFC2     0
# MFC3     0
# MFC4     0
# MFC5     0
# x2       0
# y2       0
# dtype: int64

# %%
#Define the model using model builder from keras tuner
def model_builder_single(hp):
    model = keras.Sequential()

    # Choose an optimal value between 32-512
    for i in range(hp.Int("num_layers", 1, 15)):
        l1_weight = hp.Choice('l1_weight', values=[0.0, 1e-1, 1e-2, 1e-3])
        l2_weight = hp.Choice('l2_weight', values=[0.0, 1e-1, 1e-2, 1e-3])
        kernel_regularizer=keras.regularizers.L1L2(l1 = l1_weight, l2 = l2_weight)
        model.add(
            keras.layers.Dense(
                units=hp.Int("units_" + str(i), min_value=32, max_value=512, step=32),
                activation=hp.Choice("activation", ["relu", "elu"]),
                kernel_initializer='he_uniform',
                kernel_regularizer=kernel_regularizer
            )
        )
        if hp.Boolean("dropout"):
            model.add(layers.Dropout(rate=0.25))
    model.add(keras.layers.Dense(units=4, activation= "linear", kernel_initializer='he_uniform'))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    # hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-1, sampling="log")

    # model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
    #             loss="mse",  metrics='mae')
    
    model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
                loss="mse",
                metrics='mae')

    return model


#search for the best hyperparameters and train the standard model with original training data
def hyper_model(X_train,Y_train, X_val, y_val, epoch, factor):
    folder_name = project_name
    tuner = kt.Hyperband(model_builder_single,
                         objective='val_loss',
                         max_epochs=epoch+100,
                         factor=factor,
                         hyperband_iterations = 1,
                        # Integer, at least 1, the number of times to iterate over the full Hyperband algorithm. One iteration will 
                        # run approximately max_epochs * (math.log(max_epochs, factor) ** 2) cumulative epochs across all trials. It is 
                        # recommended to set this to as high a value as is within your resource budget. Defaults to 1.
                         directory="../../tensorflow_log_files/studienarbeit/",
                         seed=0,    
                         project_name=str(folder_name))

    tuner.search_space_summary()
    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    tuner.search(X_train, Y_train, epochs=epoch, validation_data = (X_val, y_val), callbacks=[stop_early, 
                                                                                            #   keras.callbacks.TensorBoard("../tensorflow_log_files/studienarbeit/tb_logs"+str(folder_name))
                                                                                              ])
    #tuner.search(X_train, Y_train, epochs=50, validation_data=(X_test,Y_test), callbacks=[stop_early])
    # Get the optimal hyperparameters
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

    model = tuner.hypermodel.build(best_hps)
    history = model.fit(X_train, Y_train, epochs=epoch, validation_data = (X_val, y_val), shuffle= True)

    print(f"""
    The hyperparameter search is complete. The optimal learning rate for the optimizer
    is {model.optimizer.lr.numpy()}.
    """)

    return best_hps, model, tuner, history

# %%
best_hps, best_model, tuner, history = hyper_model(X_train,y_train_sc, X_val, y_val_sc,
                                                        epoch=1000,factor=2)
# Out:
# INFO:tensorflow:Reloading Tuner from ../../tensorflow_log_files/studienarbeit/Multi_leak_experiment2_withoutSwap/tuner0.json
# Search space summary
# Default search space size: 21
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 15, 'step': 1, 'sampling': 'linear'}
# l1_weight (Choice)
# {'default': 0.0, 'conditions': [], 'values': [0.0, 0.1, 0.01, 0.001], 'ordered': True}
# l2_weight (Choice)
# {'default': 0.0, 'conditions': [], 'values': [0.0, 0.1, 0.01, 0.001], 'ordered': True}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'elu'], 'ordered': False}
# dropout (Boolean)
# {'default': False, 'conditions': []}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/1000
# 17/17 [==============================] - 3s 16ms/step - loss: 8.1230 - mae: 1.2528 - val_loss: 0.4332 - val_mae: 0.4878
# Epoch 2/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4936 - mae: 0.5013 - val_loss: 0.3360 - val_mae: 0.3916
# Epoch 3/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.4205 - mae: 0.4402 - val_loss: 0.3433 - val_mae: 0.4015
# Epoch 4/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3972 - mae: 0.4281 - val_loss: 0.2772 - val_mae: 0.3517
# Epoch 5/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3942 - mae: 0.4151 - val_loss: 0.3012 - val_mae: 0.3620
# Epoch 6/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3777 - mae: 0.4081 - val_loss: 0.3164 - val_mae: 0.3813
# Epoch 7/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3615 - mae: 0.4001 - val_loss: 0.3279 - val_mae: 0.3791
# Epoch 8/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3545 - mae: 0.3905 - val_loss: 0.3228 - val_mae: 0.3682
# Epoch 9/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3631 - mae: 0.3991 - val_loss: 0.3184 - val_mae: 0.3845
# Epoch 10/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3620 - mae: 0.4003 - val_loss: 0.3313 - val_mae: 0.3762
# Epoch 11/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3397 - mae: 0.3847 - val_loss: 0.2910 - val_mae: 0.3573
# Epoch 12/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3385 - mae: 0.3851 - val_loss: 0.3068 - val_mae: 0.3579
# Epoch 13/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.3258 - mae: 0.3760 - val_loss: 0.2801 - val_mae: 0.3478
# Epoch 14/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3239 - mae: 0.3699 - val_loss: 0.2809 - val_mae: 0.3390
# Epoch 15/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3131 - mae: 0.3633 - val_loss: 0.2755 - val_mae: 0.3417
# Epoch 16/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3126 - mae: 0.3574 - val_loss: 0.3156 - val_mae: 0.3714
# Epoch 17/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3453 - mae: 0.3880 - val_loss: 0.3169 - val_mae: 0.3851
# Epoch 18/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3266 - mae: 0.3753 - val_loss: 0.2895 - val_mae: 0.3614
# Epoch 19/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3277 - mae: 0.3729 - val_loss: 0.3186 - val_mae: 0.3673
# Epoch 20/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3002 - mae: 0.3555 - val_loss: 0.3317 - val_mae: 0.3667
# Epoch 21/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3113 - mae: 0.3602 - val_loss: 0.2989 - val_mae: 0.3564
# Epoch 22/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3281 - mae: 0.3748 - val_loss: 0.2871 - val_mae: 0.3609
# Epoch 23/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2755 - mae: 0.3385 - val_loss: 0.2571 - val_mae: 0.3233
# Epoch 24/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2699 - mae: 0.3336 - val_loss: 0.3361 - val_mae: 0.3543
# Epoch 25/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2820 - mae: 0.3389 - val_loss: 0.3121 - val_mae: 0.3656
# Epoch 26/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3331 - mae: 0.3765 - val_loss: 0.3631 - val_mae: 0.3879
# Epoch 27/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3411 - mae: 0.3847 - val_loss: 0.2897 - val_mae: 0.3570
# Epoch 28/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3118 - mae: 0.3664 - val_loss: 0.3034 - val_mae: 0.3611
# Epoch 29/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2781 - mae: 0.3406 - val_loss: 0.3280 - val_mae: 0.3488
# Epoch 30/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2768 - mae: 0.3421 - val_loss: 0.2712 - val_mae: 0.3430
# Epoch 31/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2788 - mae: 0.3469 - val_loss: 0.2781 - val_mae: 0.3372
# Epoch 32/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2458 - mae: 0.3202 - val_loss: 0.2585 - val_mae: 0.3336
# Epoch 33/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2334 - mae: 0.3163 - val_loss: 0.3087 - val_mae: 0.3556
# Epoch 34/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2118 - mae: 0.2945 - val_loss: 0.3322 - val_mae: 0.3532
# Epoch 35/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2140 - mae: 0.3056 - val_loss: 0.3196 - val_mae: 0.3464
# Epoch 36/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2181 - mae: 0.2983 - val_loss: 0.2778 - val_mae: 0.3358
# Epoch 37/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2291 - mae: 0.3113 - val_loss: 0.3301 - val_mae: 0.3775
# Epoch 38/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2205 - mae: 0.3073 - val_loss: 0.3070 - val_mae: 0.3446
# Epoch 39/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2329 - mae: 0.3106 - val_loss: 0.2938 - val_mae: 0.3366
# Epoch 40/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2223 - mae: 0.3024 - val_loss: 0.3014 - val_mae: 0.3438
# Epoch 41/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1965 - mae: 0.2849 - val_loss: 0.3139 - val_mae: 0.3513
# Epoch 42/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1996 - mae: 0.2787 - val_loss: 0.3464 - val_mae: 0.3545
# Epoch 43/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2181 - mae: 0.3042 - val_loss: 0.2982 - val_mae: 0.3339
# Epoch 44/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1615 - mae: 0.2557 - val_loss: 0.3137 - val_mae: 0.3212
# Epoch 45/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1526 - mae: 0.2516 - val_loss: 0.3104 - val_mae: 0.3380
# Epoch 46/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1515 - mae: 0.2543 - val_loss: 0.2926 - val_mae: 0.3284
# Epoch 47/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1700 - mae: 0.2679 - val_loss: 0.3281 - val_mae: 0.3510
# Epoch 48/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1584 - mae: 0.2546 - val_loss: 0.2997 - val_mae: 0.3179
# Epoch 49/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1435 - mae: 0.2417 - val_loss: 0.3253 - val_mae: 0.3385
# Epoch 50/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2062 - mae: 0.2840 - val_loss: 0.3021 - val_mae: 0.3322
# Epoch 51/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2019 - mae: 0.2806 - val_loss: 0.3132 - val_mae: 0.3433
# Epoch 52/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2031 - mae: 0.2800 - val_loss: 0.3059 - val_mae: 0.3388
# Epoch 53/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1775 - mae: 0.2701 - val_loss: 0.3286 - val_mae: 0.3486
# Epoch 54/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1482 - mae: 0.2421 - val_loss: 0.3966 - val_mae: 0.4008
# Epoch 55/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1804 - mae: 0.2744 - val_loss: 0.3503 - val_mae: 0.3667
# Epoch 56/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1702 - mae: 0.2645 - val_loss: 0.3601 - val_mae: 0.3664
# Epoch 57/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1662 - mae: 0.2637 - val_loss: 0.3231 - val_mae: 0.3419
# Epoch 58/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1701 - mae: 0.2606 - val_loss: 0.3188 - val_mae: 0.3397
# Epoch 59/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1708 - mae: 0.2621 - val_loss: 0.3255 - val_mae: 0.3338
# Epoch 60/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1244 - mae: 0.2172 - val_loss: 0.2979 - val_mae: 0.3200
# Epoch 61/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1132 - mae: 0.2108 - val_loss: 0.3607 - val_mae: 0.3326
# Epoch 62/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1291 - mae: 0.2252 - val_loss: 0.2954 - val_mae: 0.3331
# Epoch 63/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1328 - mae: 0.2263 - val_loss: 0.3171 - val_mae: 0.3205
# Epoch 64/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1182 - mae: 0.2140 - val_loss: 0.3456 - val_mae: 0.3350
# Epoch 65/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1171 - mae: 0.2133 - val_loss: 0.3239 - val_mae: 0.3259
# Epoch 66/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1173 - mae: 0.2124 - val_loss: 0.3215 - val_mae: 0.3287
# Epoch 67/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1487 - mae: 0.2379 - val_loss: 0.3330 - val_mae: 0.3269
# Epoch 68/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1280 - mae: 0.2230 - val_loss: 0.2972 - val_mae: 0.3204
# Epoch 69/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1177 - mae: 0.2190 - val_loss: 0.3677 - val_mae: 0.3446
# Epoch 70/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1005 - mae: 0.2065 - val_loss: 0.2850 - val_mae: 0.3039
# Epoch 71/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1065 - mae: 0.1974 - val_loss: 0.2981 - val_mae: 0.3148
# Epoch 72/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1213 - mae: 0.2096 - val_loss: 0.3272 - val_mae: 0.3400
# Epoch 73/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1380 - mae: 0.2210 - val_loss: 0.2835 - val_mae: 0.3118
# Epoch 74/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1323 - mae: 0.2217 - val_loss: 0.3636 - val_mae: 0.3474
# Epoch 75/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1269 - mae: 0.2192 - val_loss: 0.3471 - val_mae: 0.3324
# Epoch 76/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1194 - mae: 0.2100 - val_loss: 0.3043 - val_mae: 0.3201
# Epoch 77/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0972 - mae: 0.1902 - val_loss: 0.3829 - val_mae: 0.3484
# Epoch 78/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1072 - mae: 0.1965 - val_loss: 0.2926 - val_mae: 0.3028
# Epoch 79/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1019 - mae: 0.1948 - val_loss: 0.3165 - val_mae: 0.3294
# Epoch 80/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1119 - mae: 0.1981 - val_loss: 0.3301 - val_mae: 0.3186
# Epoch 81/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1906 - mae: 0.2618 - val_loss: 0.3452 - val_mae: 0.3686
# Epoch 82/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1796 - mae: 0.2740 - val_loss: 0.3642 - val_mae: 0.3601
# Epoch 83/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1698 - mae: 0.2484 - val_loss: 0.3315 - val_mae: 0.3402
# Epoch 84/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1711 - mae: 0.2481 - val_loss: 0.3506 - val_mae: 0.3353
# Epoch 85/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1460 - mae: 0.2364 - val_loss: 0.3223 - val_mae: 0.3452
# Epoch 86/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1388 - mae: 0.2303 - val_loss: 0.3225 - val_mae: 0.3320
# Epoch 87/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1190 - mae: 0.2099 - val_loss: 0.3066 - val_mae: 0.3195
# Epoch 88/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1103 - mae: 0.1992 - val_loss: 0.3227 - val_mae: 0.3287
# Epoch 89/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0925 - mae: 0.1843 - val_loss: 0.3233 - val_mae: 0.3231
# Epoch 90/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0952 - mae: 0.1869 - val_loss: 0.3315 - val_mae: 0.3240
# Epoch 91/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1082 - mae: 0.1981 - val_loss: 0.3079 - val_mae: 0.3094
# Epoch 92/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0835 - mae: 0.1754 - val_loss: 0.3595 - val_mae: 0.3291
# Epoch 93/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0853 - mae: 0.1743 - val_loss: 0.3823 - val_mae: 0.3507
# Epoch 94/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0810 - mae: 0.1732 - val_loss: 0.3343 - val_mae: 0.3257
# Epoch 95/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0746 - mae: 0.1658 - val_loss: 0.3372 - val_mae: 0.3232
# Epoch 96/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0836 - mae: 0.1725 - val_loss: 0.3025 - val_mae: 0.3055
# Epoch 97/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0777 - mae: 0.1749 - val_loss: 0.3165 - val_mae: 0.3125
# Epoch 98/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0732 - mae: 0.1689 - val_loss: 0.3455 - val_mae: 0.3409
# Epoch 99/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0712 - mae: 0.1664 - val_loss: 0.3187 - val_mae: 0.3107
# Epoch 100/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0710 - mae: 0.1643 - val_loss: 0.3368 - val_mae: 0.3283
# Epoch 101/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0890 - mae: 0.1817 - val_loss: 0.3376 - val_mae: 0.3334
# Epoch 102/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0833 - mae: 0.1811 - val_loss: 0.3440 - val_mae: 0.3459
# Epoch 103/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0832 - mae: 0.1829 - val_loss: 0.3351 - val_mae: 0.3306
# Epoch 104/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0816 - mae: 0.1837 - val_loss: 0.3195 - val_mae: 0.3216
# Epoch 105/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0622 - mae: 0.1621 - val_loss: 0.3222 - val_mae: 0.3348
# Epoch 106/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0702 - mae: 0.1701 - val_loss: 0.3069 - val_mae: 0.3120
# Epoch 107/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0642 - mae: 0.1662 - val_loss: 0.3397 - val_mae: 0.3316
# Epoch 108/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0663 - mae: 0.1623 - val_loss: 0.3220 - val_mae: 0.3333
# Epoch 109/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0587 - mae: 0.1516 - val_loss: 0.3424 - val_mae: 0.3292
# Epoch 110/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0618 - mae: 0.1544 - val_loss: 0.3467 - val_mae: 0.3405
# Epoch 111/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0584 - mae: 0.1520 - val_loss: 0.2890 - val_mae: 0.3066
# Epoch 112/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0484 - mae: 0.1415 - val_loss: 0.3432 - val_mae: 0.3213
# Epoch 113/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0401 - mae: 0.1304 - val_loss: 0.3527 - val_mae: 0.3230
# Epoch 114/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0396 - mae: 0.1233 - val_loss: 0.3202 - val_mae: 0.3106
# Epoch 115/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0478 - mae: 0.1344 - val_loss: 0.3344 - val_mae: 0.3263
# Epoch 116/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0464 - mae: 0.1353 - val_loss: 0.3345 - val_mae: 0.3340
# Epoch 117/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0525 - mae: 0.1386 - val_loss: 0.3415 - val_mae: 0.3260
# Epoch 118/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0533 - mae: 0.1427 - val_loss: 0.3661 - val_mae: 0.3311
# Epoch 119/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0527 - mae: 0.1413 - val_loss: 0.3559 - val_mae: 0.3443
# Epoch 120/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0684 - mae: 0.1536 - val_loss: 0.3855 - val_mae: 0.3502
# Epoch 121/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1165 - mae: 0.1999 - val_loss: 0.3146 - val_mae: 0.3251
# Epoch 122/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1320 - mae: 0.2259 - val_loss: 0.3318 - val_mae: 0.3368
# Epoch 123/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1917 - mae: 0.2539 - val_loss: 0.3876 - val_mae: 0.3560
# Epoch 124/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1450 - mae: 0.2390 - val_loss: 0.3880 - val_mae: 0.3636
# Epoch 125/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1516 - mae: 0.2438 - val_loss: 0.6010 - val_mae: 0.4138
# Epoch 126/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2131 - mae: 0.2942 - val_loss: 0.3692 - val_mae: 0.3600
# Epoch 127/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2450 - mae: 0.3039 - val_loss: 0.3596 - val_mae: 0.3598
# Epoch 128/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.2248 - mae: 0.3054 - val_loss: 0.3847 - val_mae: 0.3794
# Epoch 129/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1930 - mae: 0.2778 - val_loss: 0.2925 - val_mae: 0.3177
# Epoch 130/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2044 - mae: 0.2812 - val_loss: 0.3562 - val_mae: 0.3425
# Epoch 131/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1788 - mae: 0.2688 - val_loss: 0.3153 - val_mae: 0.3554
# Epoch 132/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1843 - mae: 0.2755 - val_loss: 0.3591 - val_mae: 0.3392
# Epoch 133/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2042 - mae: 0.2751 - val_loss: 0.3514 - val_mae: 0.3636
# Epoch 134/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1936 - mae: 0.2823 - val_loss: 0.3844 - val_mae: 0.3769
# Epoch 135/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1703 - mae: 0.2746 - val_loss: 0.3238 - val_mae: 0.3485
# Epoch 136/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1954 - mae: 0.2908 - val_loss: 0.3708 - val_mae: 0.3785
# Epoch 137/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1825 - mae: 0.2778 - val_loss: 0.3750 - val_mae: 0.3606
# Epoch 138/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1628 - mae: 0.2562 - val_loss: 0.3221 - val_mae: 0.3406
# Epoch 139/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1297 - mae: 0.2309 - val_loss: 0.3130 - val_mae: 0.3559
# Epoch 140/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1208 - mae: 0.2278 - val_loss: 0.2947 - val_mae: 0.3387
# Epoch 141/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1201 - mae: 0.2240 - val_loss: 0.3431 - val_mae: 0.3478
# Epoch 142/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1056 - mae: 0.2086 - val_loss: 0.3230 - val_mae: 0.3327
# Epoch 143/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1447 - mae: 0.2322 - val_loss: 0.3246 - val_mae: 0.3452
# Epoch 144/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1259 - mae: 0.2289 - val_loss: 0.2585 - val_mae: 0.3236
# Epoch 145/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1088 - mae: 0.2122 - val_loss: 0.3437 - val_mae: 0.3554
# Epoch 146/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1134 - mae: 0.2141 - val_loss: 0.3081 - val_mae: 0.3375
# Epoch 147/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1144 - mae: 0.2133 - val_loss: 0.3484 - val_mae: 0.3465
# Epoch 148/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1295 - mae: 0.2202 - val_loss: 0.3303 - val_mae: 0.3417
# Epoch 149/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0971 - mae: 0.2022 - val_loss: 0.3570 - val_mae: 0.3425
# Epoch 150/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0909 - mae: 0.1971 - val_loss: 0.3505 - val_mae: 0.3329
# Epoch 151/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0810 - mae: 0.1869 - val_loss: 0.3556 - val_mae: 0.3415
# Epoch 152/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0934 - mae: 0.1977 - val_loss: 0.3581 - val_mae: 0.3479
# Epoch 153/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0928 - mae: 0.1969 - val_loss: 0.3760 - val_mae: 0.3443
# Epoch 154/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1309 - mae: 0.2261 - val_loss: 0.3554 - val_mae: 0.3522
# Epoch 155/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1364 - mae: 0.2311 - val_loss: 0.3513 - val_mae: 0.3455
# Epoch 156/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1222 - mae: 0.2230 - val_loss: 0.3270 - val_mae: 0.3261
# Epoch 157/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1024 - mae: 0.2029 - val_loss: 0.3346 - val_mae: 0.3272
# Epoch 158/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.1009 - mae: 0.1974 - val_loss: 0.2662 - val_mae: 0.3065
# Epoch 159/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1090 - mae: 0.2011 - val_loss: 0.3502 - val_mae: 0.3410
# Epoch 160/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1298 - mae: 0.2220 - val_loss: 0.2735 - val_mae: 0.3215
# Epoch 161/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1617 - mae: 0.2504 - val_loss: 0.3129 - val_mae: 0.3401
# Epoch 162/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1555 - mae: 0.2403 - val_loss: 0.3688 - val_mae: 0.3470
# Epoch 163/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1381 - mae: 0.2238 - val_loss: 0.3045 - val_mae: 0.3164
# Epoch 164/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1261 - mae: 0.2140 - val_loss: 0.3332 - val_mae: 0.3329
# Epoch 165/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1443 - mae: 0.2336 - val_loss: 0.3512 - val_mae: 0.3449
# Epoch 166/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2072 - mae: 0.2785 - val_loss: 0.3219 - val_mae: 0.3649
# Epoch 167/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1553 - mae: 0.2571 - val_loss: 0.3471 - val_mae: 0.3495
# Epoch 168/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1196 - mae: 0.2210 - val_loss: 0.3355 - val_mae: 0.3392
# Epoch 169/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1148 - mae: 0.2071 - val_loss: 0.3269 - val_mae: 0.3383
# Epoch 170/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1115 - mae: 0.2089 - val_loss: 0.3398 - val_mae: 0.3432
# Epoch 171/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1154 - mae: 0.2108 - val_loss: 0.3145 - val_mae: 0.3302
# Epoch 172/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0938 - mae: 0.1917 - val_loss: 0.3281 - val_mae: 0.3270
# Epoch 173/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1260 - mae: 0.2181 - val_loss: 0.3255 - val_mae: 0.3492
# Epoch 174/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0997 - mae: 0.2076 - val_loss: 0.3170 - val_mae: 0.3384
# Epoch 175/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0972 - mae: 0.1890 - val_loss: 0.3318 - val_mae: 0.3321
# Epoch 176/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0928 - mae: 0.1888 - val_loss: 0.3094 - val_mae: 0.3196
# Epoch 177/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0924 - mae: 0.1865 - val_loss: 0.3229 - val_mae: 0.3274
# Epoch 178/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0925 - mae: 0.1827 - val_loss: 0.3137 - val_mae: 0.3267
# Epoch 179/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1063 - mae: 0.1978 - val_loss: 0.3802 - val_mae: 0.3899
# Epoch 180/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1042 - mae: 0.2073 - val_loss: 0.3198 - val_mae: 0.3336
# Epoch 181/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0824 - mae: 0.1848 - val_loss: 0.3337 - val_mae: 0.3326
# Epoch 182/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0866 - mae: 0.1808 - val_loss: 0.3175 - val_mae: 0.3291
# Epoch 183/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0981 - mae: 0.1886 - val_loss: 0.3342 - val_mae: 0.3340
# Epoch 184/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0812 - mae: 0.1755 - val_loss: 0.3303 - val_mae: 0.3258
# Epoch 185/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0752 - mae: 0.1697 - val_loss: 0.3126 - val_mae: 0.3147
# Epoch 186/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0653 - mae: 0.1495 - val_loss: 0.3346 - val_mae: 0.3397
# Epoch 187/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0745 - mae: 0.1586 - val_loss: 0.3150 - val_mae: 0.3167
# Epoch 188/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0588 - mae: 0.1483 - val_loss: 0.3027 - val_mae: 0.3120
# Epoch 189/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0593 - mae: 0.1523 - val_loss: 0.3070 - val_mae: 0.3078
# Epoch 190/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0574 - mae: 0.1488 - val_loss: 0.3258 - val_mae: 0.3204
# Epoch 191/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0578 - mae: 0.1459 - val_loss: 0.3016 - val_mae: 0.3195
# Epoch 192/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0452 - mae: 0.1327 - val_loss: 0.2943 - val_mae: 0.3079
# Epoch 193/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0417 - mae: 0.1272 - val_loss: 0.2844 - val_mae: 0.3004
# Epoch 194/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0350 - mae: 0.1167 - val_loss: 0.3054 - val_mae: 0.3160
# Epoch 195/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0387 - mae: 0.1237 - val_loss: 0.2970 - val_mae: 0.3040
# Epoch 196/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0342 - mae: 0.1126 - val_loss: 0.2848 - val_mae: 0.2959
# Epoch 197/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0325 - mae: 0.1120 - val_loss: 0.3115 - val_mae: 0.3013
# Epoch 198/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0287 - mae: 0.1061 - val_loss: 0.3007 - val_mae: 0.3038
# Epoch 199/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0299 - mae: 0.1105 - val_loss: 0.3105 - val_mae: 0.3131
# Epoch 200/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0302 - mae: 0.1079 - val_loss: 0.3214 - val_mae: 0.3098
# Epoch 201/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0335 - mae: 0.1083 - val_loss: 0.2796 - val_mae: 0.2887
# Epoch 202/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0343 - mae: 0.1072 - val_loss: 0.2899 - val_mae: 0.2892
# Epoch 203/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0280 - mae: 0.0998 - val_loss: 0.2888 - val_mae: 0.2926
# Epoch 204/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0318 - mae: 0.1019 - val_loss: 0.2956 - val_mae: 0.3010
# Epoch 205/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0220 - mae: 0.0942 - val_loss: 0.2926 - val_mae: 0.2893
# Epoch 206/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0188 - mae: 0.0852 - val_loss: 0.2998 - val_mae: 0.2959
# Epoch 207/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0212 - mae: 0.0906 - val_loss: 0.3026 - val_mae: 0.2938
# Epoch 208/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0197 - mae: 0.0885 - val_loss: 0.2907 - val_mae: 0.2895
# Epoch 209/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0186 - mae: 0.0877 - val_loss: 0.2823 - val_mae: 0.2878
# Epoch 210/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0188 - mae: 0.0852 - val_loss: 0.2953 - val_mae: 0.2957
# Epoch 211/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0163 - mae: 0.0835 - val_loss: 0.2948 - val_mae: 0.2946
# Epoch 212/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0215 - mae: 0.0905 - val_loss: 0.3042 - val_mae: 0.3012
# Epoch 213/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0217 - mae: 0.0916 - val_loss: 0.2840 - val_mae: 0.2909
# Epoch 214/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0218 - mae: 0.0925 - val_loss: 0.2873 - val_mae: 0.3005
# Epoch 215/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0221 - mae: 0.0938 - val_loss: 0.3048 - val_mae: 0.3118
# Epoch 216/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0193 - mae: 0.0899 - val_loss: 0.3055 - val_mae: 0.3044
# Epoch 217/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0181 - mae: 0.0873 - val_loss: 0.3058 - val_mae: 0.3072
# Epoch 218/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0365 - mae: 0.1022 - val_loss: 0.3349 - val_mae: 0.3274
# Epoch 219/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1160 - mae: 0.1840 - val_loss: 0.3364 - val_mae: 0.3498
# Epoch 220/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1347 - mae: 0.2169 - val_loss: 0.3753 - val_mae: 0.3762
# Epoch 221/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2060 - mae: 0.2768 - val_loss: 0.3683 - val_mae: 0.3791
# Epoch 222/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2278 - mae: 0.2947 - val_loss: 0.3547 - val_mae: 0.3576
# Epoch 223/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2809 - mae: 0.3326 - val_loss: 0.4101 - val_mae: 0.4100
# Epoch 224/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.3334 - mae: 0.3958 - val_loss: 0.4013 - val_mae: 0.4245
# Epoch 225/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2917 - mae: 0.3578 - val_loss: 0.3249 - val_mae: 0.3820
# Epoch 226/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2689 - mae: 0.3377 - val_loss: 0.3552 - val_mae: 0.3935
# Epoch 227/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.3033 - mae: 0.3595 - val_loss: 0.4118 - val_mae: 0.4276
# Epoch 228/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.3219 - mae: 0.3808 - val_loss: 0.4275 - val_mae: 0.4099
# Epoch 229/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2843 - mae: 0.3497 - val_loss: 0.3921 - val_mae: 0.3937
# Epoch 230/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2751 - mae: 0.3447 - val_loss: 0.3685 - val_mae: 0.3717
# Epoch 231/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2295 - mae: 0.3119 - val_loss: 0.3466 - val_mae: 0.3519
# Epoch 232/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.2232 - mae: 0.3025 - val_loss: 0.4195 - val_mae: 0.3766
# Epoch 233/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1678 - mae: 0.2671 - val_loss: 0.3290 - val_mae: 0.3454
# Epoch 234/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1807 - mae: 0.2808 - val_loss: 0.3799 - val_mae: 0.3667
# Epoch 235/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1814 - mae: 0.2743 - val_loss: 0.3402 - val_mae: 0.3473
# Epoch 236/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1651 - mae: 0.2621 - val_loss: 0.3840 - val_mae: 0.3410
# Epoch 237/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1501 - mae: 0.2492 - val_loss: 0.3497 - val_mae: 0.3342
# Epoch 238/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1277 - mae: 0.2300 - val_loss: 0.2642 - val_mae: 0.3170
# Epoch 239/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1299 - mae: 0.2305 - val_loss: 0.3275 - val_mae: 0.3621
# Epoch 240/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1023 - mae: 0.2113 - val_loss: 0.2951 - val_mae: 0.3118
# Epoch 241/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1153 - mae: 0.2102 - val_loss: 0.3948 - val_mae: 0.3402
# Epoch 242/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1226 - mae: 0.2178 - val_loss: 0.3322 - val_mae: 0.3142
# Epoch 243/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.1024 - mae: 0.2065 - val_loss: 0.3086 - val_mae: 0.3233
# Epoch 244/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0904 - mae: 0.1987 - val_loss: 0.3550 - val_mae: 0.3449
# Epoch 245/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0978 - mae: 0.1995 - val_loss: 0.3357 - val_mae: 0.3343
# Epoch 246/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0968 - mae: 0.1944 - val_loss: 0.3175 - val_mae: 0.3175
# Epoch 247/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1017 - mae: 0.1942 - val_loss: 0.3138 - val_mae: 0.3303
# Epoch 248/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0913 - mae: 0.1887 - val_loss: 0.3141 - val_mae: 0.3192
# Epoch 249/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1161 - mae: 0.2062 - val_loss: 0.3319 - val_mae: 0.3295
# Epoch 250/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1183 - mae: 0.2131 - val_loss: 0.3596 - val_mae: 0.3705
# Epoch 251/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1287 - mae: 0.2342 - val_loss: 0.3358 - val_mae: 0.3478
# Epoch 252/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1045 - mae: 0.2091 - val_loss: 0.3654 - val_mae: 0.3467
# Epoch 253/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1164 - mae: 0.2169 - val_loss: 0.2916 - val_mae: 0.3193
# Epoch 254/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0954 - mae: 0.1981 - val_loss: 0.2926 - val_mae: 0.3088
# Epoch 255/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1017 - mae: 0.1910 - val_loss: 0.3365 - val_mae: 0.3393
# Epoch 256/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1079 - mae: 0.2011 - val_loss: 0.3643 - val_mae: 0.3430
# Epoch 257/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1365 - mae: 0.2149 - val_loss: 0.4146 - val_mae: 0.3518
# Epoch 258/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1149 - mae: 0.2062 - val_loss: 0.3121 - val_mae: 0.3208
# Epoch 259/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1048 - mae: 0.2032 - val_loss: 0.3448 - val_mae: 0.3350
# Epoch 260/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1049 - mae: 0.2019 - val_loss: 0.3448 - val_mae: 0.3386
# Epoch 261/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1145 - mae: 0.2088 - val_loss: 0.3476 - val_mae: 0.3299
# Epoch 262/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1468 - mae: 0.2209 - val_loss: 0.3663 - val_mae: 0.3629
# Epoch 263/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1715 - mae: 0.2436 - val_loss: 0.3251 - val_mae: 0.3289
# Epoch 264/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1360 - mae: 0.2284 - val_loss: 0.4587 - val_mae: 0.3675
# Epoch 265/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1548 - mae: 0.2422 - val_loss: 0.3864 - val_mae: 0.3720
# Epoch 266/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1487 - mae: 0.2412 - val_loss: 0.3345 - val_mae: 0.3374
# Epoch 267/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1597 - mae: 0.2372 - val_loss: 0.3233 - val_mae: 0.3360
# Epoch 268/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1261 - mae: 0.2235 - val_loss: 0.3757 - val_mae: 0.3471
# Epoch 269/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1538 - mae: 0.2169 - val_loss: 0.3182 - val_mae: 0.3404
# Epoch 270/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1442 - mae: 0.2395 - val_loss: 0.2822 - val_mae: 0.3241
# Epoch 271/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1332 - mae: 0.2307 - val_loss: 0.2573 - val_mae: 0.3114
# Epoch 272/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1419 - mae: 0.2297 - val_loss: 0.3143 - val_mae: 0.3333
# Epoch 273/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1309 - mae: 0.2221 - val_loss: 0.3059 - val_mae: 0.3091
# Epoch 274/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1216 - mae: 0.2118 - val_loss: 0.3092 - val_mae: 0.3166
# Epoch 275/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1314 - mae: 0.2165 - val_loss: 0.3076 - val_mae: 0.3247
# Epoch 276/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1372 - mae: 0.2242 - val_loss: 0.3262 - val_mae: 0.3420
# Epoch 277/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1333 - mae: 0.2273 - val_loss: 0.3717 - val_mae: 0.3392
# Epoch 278/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1418 - mae: 0.2335 - val_loss: 0.3512 - val_mae: 0.3419
# Epoch 279/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0919 - mae: 0.1989 - val_loss: 0.3101 - val_mae: 0.3253
# Epoch 280/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0959 - mae: 0.1885 - val_loss: 0.3365 - val_mae: 0.3533
# Epoch 281/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1042 - mae: 0.2055 - val_loss: 0.3404 - val_mae: 0.3353
# Epoch 282/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1159 - mae: 0.2113 - val_loss: 0.3569 - val_mae: 0.3383
# Epoch 283/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0895 - mae: 0.1941 - val_loss: 0.3373 - val_mae: 0.3198
# Epoch 284/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0873 - mae: 0.1855 - val_loss: 0.3554 - val_mae: 0.3434
# Epoch 285/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0712 - mae: 0.1685 - val_loss: 0.3136 - val_mae: 0.3331
# Epoch 286/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0630 - mae: 0.1596 - val_loss: 0.3434 - val_mae: 0.3316
# Epoch 287/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0636 - mae: 0.1587 - val_loss: 0.3665 - val_mae: 0.3371
# Epoch 288/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0686 - mae: 0.1634 - val_loss: 0.4347 - val_mae: 0.3630
# Epoch 289/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0871 - mae: 0.1739 - val_loss: 0.3659 - val_mae: 0.3317
# Epoch 290/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0829 - mae: 0.1684 - val_loss: 0.3736 - val_mae: 0.3439
# Epoch 291/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0797 - mae: 0.1818 - val_loss: 0.3157 - val_mae: 0.3222
# Epoch 292/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0755 - mae: 0.1785 - val_loss: 0.3565 - val_mae: 0.3493
# Epoch 293/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0649 - mae: 0.1696 - val_loss: 0.3550 - val_mae: 0.3352
# Epoch 294/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0664 - mae: 0.1666 - val_loss: 0.3237 - val_mae: 0.3337
# Epoch 295/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0739 - mae: 0.1714 - val_loss: 0.3550 - val_mae: 0.3461
# Epoch 296/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0844 - mae: 0.1817 - val_loss: 0.3738 - val_mae: 0.3536
# Epoch 297/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0857 - mae: 0.1864 - val_loss: 0.3646 - val_mae: 0.3538
# Epoch 298/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0839 - mae: 0.1792 - val_loss: 0.3833 - val_mae: 0.3813
# Epoch 299/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0894 - mae: 0.1902 - val_loss: 0.3308 - val_mae: 0.3427
# Epoch 300/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0749 - mae: 0.1718 - val_loss: 0.3400 - val_mae: 0.3370
# Epoch 301/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0632 - mae: 0.1580 - val_loss: 0.3362 - val_mae: 0.3299
# Epoch 302/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0648 - mae: 0.1575 - val_loss: 0.3241 - val_mae: 0.3254
# Epoch 303/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0562 - mae: 0.1428 - val_loss: 0.3343 - val_mae: 0.3222
# Epoch 304/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0551 - mae: 0.1397 - val_loss: 0.3148 - val_mae: 0.3218
# Epoch 305/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0670 - mae: 0.1525 - val_loss: 0.3190 - val_mae: 0.3364
# Epoch 306/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0728 - mae: 0.1579 - val_loss: 0.3424 - val_mae: 0.3367
# Epoch 307/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0692 - mae: 0.1601 - val_loss: 0.3231 - val_mae: 0.3250
# Epoch 308/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0783 - mae: 0.1645 - val_loss: 0.3572 - val_mae: 0.3315
# Epoch 309/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0714 - mae: 0.1535 - val_loss: 0.3872 - val_mae: 0.3598
# Epoch 310/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1082 - mae: 0.1981 - val_loss: 0.3867 - val_mae: 0.3650
# Epoch 311/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0864 - mae: 0.1879 - val_loss: 0.3228 - val_mae: 0.3228
# Epoch 312/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0742 - mae: 0.1688 - val_loss: 0.3484 - val_mae: 0.3302
# Epoch 313/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0741 - mae: 0.1662 - val_loss: 0.3397 - val_mae: 0.3277
# Epoch 314/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0692 - mae: 0.1534 - val_loss: 0.3711 - val_mae: 0.3464
# Epoch 315/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0639 - mae: 0.1543 - val_loss: 0.3407 - val_mae: 0.3407
# Epoch 316/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0597 - mae: 0.1493 - val_loss: 0.3662 - val_mae: 0.3358
# Epoch 317/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0545 - mae: 0.1373 - val_loss: 0.3209 - val_mae: 0.3322
# Epoch 318/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0460 - mae: 0.1269 - val_loss: 0.3411 - val_mae: 0.3323
# Epoch 319/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0406 - mae: 0.1192 - val_loss: 0.3494 - val_mae: 0.3159
# Epoch 320/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0382 - mae: 0.1125 - val_loss: 0.3400 - val_mae: 0.3208
# Epoch 321/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0389 - mae: 0.1107 - val_loss: 0.2912 - val_mae: 0.3094
# Epoch 322/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0365 - mae: 0.1034 - val_loss: 0.3006 - val_mae: 0.3146
# Epoch 323/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0341 - mae: 0.1072 - val_loss: 0.3096 - val_mae: 0.3185
# Epoch 324/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0369 - mae: 0.1073 - val_loss: 0.3319 - val_mae: 0.3215
# Epoch 325/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0599 - mae: 0.1206 - val_loss: 0.3172 - val_mae: 0.3132
# Epoch 326/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0419 - mae: 0.1205 - val_loss: 0.2851 - val_mae: 0.3007
# Epoch 327/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0438 - mae: 0.1237 - val_loss: 0.3085 - val_mae: 0.3156
# Epoch 328/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0402 - mae: 0.1217 - val_loss: 0.2815 - val_mae: 0.3079
# Epoch 329/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0376 - mae: 0.1144 - val_loss: 0.3050 - val_mae: 0.3083
# Epoch 330/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0372 - mae: 0.1133 - val_loss: 0.3135 - val_mae: 0.3115
# Epoch 331/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0406 - mae: 0.1226 - val_loss: 0.3198 - val_mae: 0.3305
# Epoch 332/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0471 - mae: 0.1275 - val_loss: 0.2981 - val_mae: 0.3159
# Epoch 333/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0443 - mae: 0.1256 - val_loss: 0.3397 - val_mae: 0.3321
# Epoch 334/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0470 - mae: 0.1290 - val_loss: 0.3439 - val_mae: 0.3233
# Epoch 335/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0557 - mae: 0.1424 - val_loss: 0.3370 - val_mae: 0.3344
# Epoch 336/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0792 - mae: 0.1680 - val_loss: 0.3479 - val_mae: 0.3365
# Epoch 337/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0643 - mae: 0.1615 - val_loss: 0.2927 - val_mae: 0.3058
# Epoch 338/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0552 - mae: 0.1483 - val_loss: 0.2925 - val_mae: 0.3040
# Epoch 339/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0504 - mae: 0.1437 - val_loss: 0.3110 - val_mae: 0.3287
# Epoch 340/1000
# ...
# Epoch 883/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1418 - mae: 0.2393 - val_loss: 0.3420 - val_mae: 0.3459
# Epoch 884/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1893 - mae: 0.2457 - val_loss: 0.3460 - val_mae: 0.3698
# Epoch 885/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2179 - mae: 0.2973 - val_loss: 0.4122 - val_mae: 0.3978
# Epoch 886/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.2232 - mae: 0.3074 - val_loss: 0.3682 - val_mae: 0.3705
# Epoch 887/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1998 - mae: 0.2793 - val_loss: 0.3168 - val_mae: 0.3423
# Epoch 888/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1675 - mae: 0.2552 - val_loss: 0.3271 - val_mae: 0.3467
# Epoch 889/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1564 - mae: 0.2486 - val_loss: 0.3149 - val_mae: 0.3434
# Epoch 890/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1576 - mae: 0.2399 - val_loss: 0.3297 - val_mae: 0.3444
# Epoch 891/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1402 - mae: 0.2317 - val_loss: 0.3733 - val_mae: 0.3469
# Epoch 892/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1433 - mae: 0.2382 - val_loss: 0.3480 - val_mae: 0.3736
# Epoch 893/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1603 - mae: 0.2485 - val_loss: 0.3383 - val_mae: 0.3758
# Epoch 894/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1346 - mae: 0.2347 - val_loss: 0.3306 - val_mae: 0.3488
# Epoch 895/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1109 - mae: 0.2071 - val_loss: 0.3314 - val_mae: 0.3515
# Epoch 896/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1237 - mae: 0.2183 - val_loss: 0.3805 - val_mae: 0.3861
# Epoch 897/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1168 - mae: 0.2162 - val_loss: 0.3450 - val_mae: 0.3423
# Epoch 898/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1074 - mae: 0.2004 - val_loss: 0.3905 - val_mae: 0.3810
# Epoch 899/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.1074 - mae: 0.2090 - val_loss: 0.3465 - val_mae: 0.3562
# Epoch 900/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1007 - mae: 0.1945 - val_loss: 0.3865 - val_mae: 0.3633
# Epoch 901/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.1099 - mae: 0.1995 - val_loss: 0.3723 - val_mae: 0.3720
# Epoch 902/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1065 - mae: 0.1998 - val_loss: 0.3668 - val_mae: 0.3596
# Epoch 903/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0886 - mae: 0.1829 - val_loss: 0.3353 - val_mae: 0.3317
# Epoch 904/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0872 - mae: 0.1797 - val_loss: 0.3373 - val_mae: 0.3385
# Epoch 905/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0770 - mae: 0.1637 - val_loss: 0.3167 - val_mae: 0.3236
# Epoch 906/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0724 - mae: 0.1603 - val_loss: 0.3442 - val_mae: 0.3371
# Epoch 907/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0678 - mae: 0.1502 - val_loss: 0.3488 - val_mae: 0.3329
# Epoch 908/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0659 - mae: 0.1472 - val_loss: 0.3363 - val_mae: 0.3362
# Epoch 909/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0643 - mae: 0.1479 - val_loss: 0.3434 - val_mae: 0.3391
# Epoch 910/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0626 - mae: 0.1422 - val_loss: 0.3421 - val_mae: 0.3301
# Epoch 911/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0617 - mae: 0.1464 - val_loss: 0.3267 - val_mae: 0.3175
# Epoch 912/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0598 - mae: 0.1373 - val_loss: 0.3558 - val_mae: 0.3388
# Epoch 913/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0593 - mae: 0.1389 - val_loss: 0.3346 - val_mae: 0.3399
# Epoch 914/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0599 - mae: 0.1393 - val_loss: 0.3440 - val_mae: 0.3251
# Epoch 915/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0590 - mae: 0.1385 - val_loss: 0.3566 - val_mae: 0.3391
# Epoch 916/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0582 - mae: 0.1381 - val_loss: 0.3544 - val_mae: 0.3364
# Epoch 917/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0557 - mae: 0.1337 - val_loss: 0.3605 - val_mae: 0.3340
# Epoch 918/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0613 - mae: 0.1399 - val_loss: 0.3659 - val_mae: 0.3433
# Epoch 919/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0554 - mae: 0.1373 - val_loss: 0.3837 - val_mae: 0.3542
# Epoch 920/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0686 - mae: 0.1453 - val_loss: 0.3804 - val_mae: 0.3537
# Epoch 921/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0712 - mae: 0.1507 - val_loss: 0.3939 - val_mae: 0.3452
# Epoch 922/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0834 - mae: 0.1633 - val_loss: 0.3621 - val_mae: 0.3560
# Epoch 923/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0941 - mae: 0.1728 - val_loss: 0.3428 - val_mae: 0.3489
# Epoch 924/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0777 - mae: 0.1624 - val_loss: 0.3463 - val_mae: 0.3472
# Epoch 925/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0794 - mae: 0.1652 - val_loss: 0.3247 - val_mae: 0.3323
# Epoch 926/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0738 - mae: 0.1508 - val_loss: 0.3511 - val_mae: 0.3399
# Epoch 927/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0766 - mae: 0.1520 - val_loss: 0.3605 - val_mae: 0.3497
# Epoch 928/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0756 - mae: 0.1602 - val_loss: 0.3715 - val_mae: 0.3504
# Epoch 929/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0713 - mae: 0.1522 - val_loss: 0.3502 - val_mae: 0.3424
# Epoch 930/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0709 - mae: 0.1507 - val_loss: 0.3556 - val_mae: 0.3401
# Epoch 931/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0714 - mae: 0.1509 - val_loss: 0.3679 - val_mae: 0.3589
# Epoch 932/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0687 - mae: 0.1494 - val_loss: 0.3463 - val_mae: 0.3442
# Epoch 933/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0657 - mae: 0.1400 - val_loss: 0.3444 - val_mae: 0.3376
# Epoch 934/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0666 - mae: 0.1450 - val_loss: 0.3541 - val_mae: 0.3403
# Epoch 935/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0664 - mae: 0.1447 - val_loss: 0.3607 - val_mae: 0.3437
# Epoch 936/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0657 - mae: 0.1439 - val_loss: 0.3500 - val_mae: 0.3416
# Epoch 937/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0676 - mae: 0.1468 - val_loss: 0.3775 - val_mae: 0.3621
# Epoch 938/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0665 - mae: 0.1481 - val_loss: 0.3705 - val_mae: 0.3576
# Epoch 939/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0670 - mae: 0.1451 - val_loss: 0.3712 - val_mae: 0.3418
# Epoch 940/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0657 - mae: 0.1407 - val_loss: 0.3702 - val_mae: 0.3432
# Epoch 941/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0763 - mae: 0.1582 - val_loss: 0.3682 - val_mae: 0.3458
# Epoch 942/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0764 - mae: 0.1582 - val_loss: 0.3656 - val_mae: 0.3458
# Epoch 943/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0917 - mae: 0.1822 - val_loss: 0.3706 - val_mae: 0.3525
# Epoch 944/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0992 - mae: 0.1998 - val_loss: 0.3744 - val_mae: 0.3637
# Epoch 945/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0867 - mae: 0.1865 - val_loss: 0.3361 - val_mae: 0.3516
# Epoch 946/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0817 - mae: 0.1834 - val_loss: 0.3441 - val_mae: 0.3540
# Epoch 947/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0797 - mae: 0.1768 - val_loss: 0.3465 - val_mae: 0.3541
# Epoch 948/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0772 - mae: 0.1677 - val_loss: 0.3510 - val_mae: 0.3620
# Epoch 949/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0678 - mae: 0.1579 - val_loss: 0.3216 - val_mae: 0.3373
# Epoch 950/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0617 - mae: 0.1523 - val_loss: 0.3157 - val_mae: 0.3346
# Epoch 951/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0577 - mae: 0.1445 - val_loss: 0.3399 - val_mae: 0.3457
# Epoch 952/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0548 - mae: 0.1409 - val_loss: 0.3206 - val_mae: 0.3359
# Epoch 953/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0564 - mae: 0.1435 - val_loss: 0.3232 - val_mae: 0.3319
# Epoch 954/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0518 - mae: 0.1374 - val_loss: 0.3213 - val_mae: 0.3358
# Epoch 955/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0525 - mae: 0.1348 - val_loss: 0.3061 - val_mae: 0.3246
# Epoch 956/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0530 - mae: 0.1338 - val_loss: 0.3185 - val_mae: 0.3520
# Epoch 957/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0532 - mae: 0.1377 - val_loss: 0.3147 - val_mae: 0.3265
# Epoch 958/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0526 - mae: 0.1336 - val_loss: 0.3193 - val_mae: 0.3284
# Epoch 959/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0546 - mae: 0.1402 - val_loss: 0.3059 - val_mae: 0.3302
# Epoch 960/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0557 - mae: 0.1458 - val_loss: 0.3139 - val_mae: 0.3358
# Epoch 961/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0588 - mae: 0.1461 - val_loss: 0.3317 - val_mae: 0.3306
# Epoch 962/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0507 - mae: 0.1333 - val_loss: 0.3070 - val_mae: 0.3202
# Epoch 963/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0496 - mae: 0.1324 - val_loss: 0.3403 - val_mae: 0.3320
# Epoch 964/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0489 - mae: 0.1299 - val_loss: 0.3102 - val_mae: 0.3255
# Epoch 965/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0497 - mae: 0.1367 - val_loss: 0.3312 - val_mae: 0.3349
# Epoch 966/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0481 - mae: 0.1280 - val_loss: 0.3067 - val_mae: 0.3235
# Epoch 967/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0471 - mae: 0.1252 - val_loss: 0.3337 - val_mae: 0.3479
# Epoch 968/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0474 - mae: 0.1255 - val_loss: 0.3287 - val_mae: 0.3249
# Epoch 969/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0471 - mae: 0.1259 - val_loss: 0.3455 - val_mae: 0.3509
# Epoch 970/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0494 - mae: 0.1327 - val_loss: 0.3199 - val_mae: 0.3232
# Epoch 971/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0456 - mae: 0.1254 - val_loss: 0.3240 - val_mae: 0.3262
# Epoch 972/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0440 - mae: 0.1208 - val_loss: 0.3314 - val_mae: 0.3372
# Epoch 973/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0430 - mae: 0.1195 - val_loss: 0.3160 - val_mae: 0.3165
# Epoch 974/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0530 - mae: 0.1336 - val_loss: 0.3481 - val_mae: 0.3354
# Epoch 975/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0585 - mae: 0.1435 - val_loss: 0.3371 - val_mae: 0.3394
# Epoch 976/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0487 - mae: 0.1300 - val_loss: 0.3268 - val_mae: 0.3312
# Epoch 977/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0486 - mae: 0.1322 - val_loss: 0.3373 - val_mae: 0.3298
# Epoch 978/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0480 - mae: 0.1309 - val_loss: 0.3258 - val_mae: 0.3225
# Epoch 979/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0455 - mae: 0.1254 - val_loss: 0.3378 - val_mae: 0.3257
# Epoch 980/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0438 - mae: 0.1201 - val_loss: 0.3347 - val_mae: 0.3312
# Epoch 981/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0477 - mae: 0.1292 - val_loss: 0.3675 - val_mae: 0.3523
# Epoch 982/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0458 - mae: 0.1241 - val_loss: 0.3119 - val_mae: 0.3210
# Epoch 983/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0477 - mae: 0.1292 - val_loss: 0.3291 - val_mae: 0.3300
# Epoch 984/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0523 - mae: 0.1376 - val_loss: 0.3332 - val_mae: 0.3451
# Epoch 985/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0508 - mae: 0.1372 - val_loss: 0.3758 - val_mae: 0.3575
# Epoch 986/1000
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0521 - mae: 0.1323 - val_loss: 0.3364 - val_mae: 0.3417
# Epoch 987/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0515 - mae: 0.1370 - val_loss: 0.3377 - val_mae: 0.3451
# Epoch 988/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0476 - mae: 0.1323 - val_loss: 0.3188 - val_mae: 0.3298
# Epoch 989/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0465 - mae: 0.1269 - val_loss: 0.3465 - val_mae: 0.3429
# Epoch 990/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0438 - mae: 0.1215 - val_loss: 0.3293 - val_mae: 0.3291
# Epoch 991/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0462 - mae: 0.1267 - val_loss: 0.3785 - val_mae: 0.3481
# Epoch 992/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0469 - mae: 0.1266 - val_loss: 0.3091 - val_mae: 0.3279
# Epoch 993/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0459 - mae: 0.1258 - val_loss: 0.3544 - val_mae: 0.3534
# Epoch 994/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0456 - mae: 0.1258 - val_loss: 0.3477 - val_mae: 0.3414
# Epoch 995/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0477 - mae: 0.1280 - val_loss: 0.3306 - val_mae: 0.3277
# Epoch 996/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0518 - mae: 0.1346 - val_loss: 0.3315 - val_mae: 0.3379
# Epoch 997/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0498 - mae: 0.1337 - val_loss: 0.3602 - val_mae: 0.3461
# Epoch 998/1000
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0464 - mae: 0.1277 - val_loss: 0.3331 - val_mae: 0.3297
# Epoch 999/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0446 - mae: 0.1218 - val_loss: 0.3400 - val_mae: 0.3335
# Epoch 1000/1000
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0456 - mae: 0.1265 - val_loss: 0.3273 - val_mae: 0.3234
#
#     The hyperparameter search is complete. The optimal learning rate for the optimizer
#     is 0.014642198519011718.

# %%
best_model.save(model_path)
best_model = tf.keras.models.load_model(model_path)
# Out:
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 224), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555da0eb50>, 140007640827584), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(224,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d96b550>, 140004620411824), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(224, 288), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d92b400>, 140004620224192), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(288,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d955430>, 140004620225072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(288, 160), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8fe430>, 140004620223712), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(160,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8a6460>, 140004620249168), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(160, 416), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8d1460>, 140004620251504), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(416,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d87b490>, 140004620252384), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(416, 4), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d826490>, 140004620254624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d853520>, 140004620280016), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(10, 224), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555da0eb50>, 140007640827584), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(224,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d96b550>, 140004620411824), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(224, 288), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d92b400>, 140004620224192), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(288,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d955430>, 140004620225072), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(288, 160), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8fe430>, 140004620223712), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(160,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8a6460>, 140004620249168), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(160, 416), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d8d1460>, 140004620251504), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(416,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d87b490>, 140004620252384), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(416, 4), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d826490>, 140004620254624), {}).
# INFO:tensorflow:Unsupported signature for serialization: ((TensorSpec(shape=(4,), dtype=tf.float64, name='gradient'), <tensorflow.python.framework.func_graph.UnknownArgument object at 0x7f555d853520>, 140004620280016), {}).
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: saved_model/Multi_leak/experiment2/withoutswap/assets
# INFO:tensorflow:Assets written to: saved_model/Multi_leak/experiment2/withoutswap/assets

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
y_predictions_train = best_model.predict(X_train)
# print("train", "{:10.4f}".format(mean_squared_error(y_train, y_predictions, squared=True)))
y_predictions_val = best_model.predict(X_val)
# print("val", "{:10.4f}".format(mean_squared_error(y_val, y_predictions, squared=True)))
y_predictions = best_model.predict(X_test)

loss_test = "{:10.4f}".format(mean_squared_error(y_test_sc, y_predictions, squared=True))
metric_test = "{:10.4f}".format(mean_absolute_error(y_test_sc, y_predictions))

loss_val = "{:10.4f}".format(mean_squared_error(y_val_sc, y_predictions_val, squared=True))
metric_val = "{:10.4f}".format(mean_absolute_error(y_val_sc, y_predictions_val))

loss_train = "{:10.4f}".format(mean_squared_error(y_train_sc, y_predictions_train, squared=True))
metric_train = "{:10.4f}".format(mean_absolute_error(y_train_sc, y_predictions_train))

print(metric_test, metric_val, metric_train)
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 2ms/step
#     0.5438     0.3234     0.1127

# %%
best_model.evaluate(X_train, y_train_sc)
best_model.evaluate(X_test, y_test_sc)
best_model.evaluate(X_val, y_val_sc)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0424 - mae: 0.1127
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8111 - mae: 0.5438
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3273 - mae: 0.3234
# [0.32734631033016703, 0.32344308668290667]
