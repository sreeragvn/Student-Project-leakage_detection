# %%
from wing_leakage_data_acquisition_aux import plot_target, generate_target, meshgrid_to_coords

# %%
sample_number =1199
plot_target(sample_number, *generate_target(sample_number))
# Out:
# (21, 64)

# %%
meshgrid_to_coords(-7,4)
# Out:
# 6180 1850
