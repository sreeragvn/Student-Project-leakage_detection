# %%
# NN 4 outputs and with and without sorting of outputs
model_path = 'saved_model/Multi_leak/experiment5.2/Mask_MTL_sameLoss/'
project_name='Multi_leak_experiment5.2_Mask_MTL_withSwap_sameloss'

# %%
# Experiment 2 - 1 output layer with 1 loss function - mse. and do hyper parameter tuning.
from utils.data_preprocess import load_data
import pandas as pd 
import yaml
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras_tuner as kt
from keras import layers
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from kerastuner import HyperModel, Hyperband
from keras import backend as backend

# %%
single_leakage, two_leakage = load_data()
# two_leakage["leak_1"] = 1
two_leakage["leak_2"] = 1

# single_leakage["leak_1"] = 1
single_leakage["leak_2"] = 0

data = pd.concat([single_leakage, two_leakage], axis=0)
data['x2'] = data['x2'].replace(np.nan, 0)
data['y2'] = data['y2'].replace(np.nan, 0)

data = data.drop(columns=['mfc6_residual',
       'mfc7_residual', 'mfc8_residual', 'mfc9_residual', 'mfc10_residual',
       'mfc1_residual', 'mfc2_residual', 'mfc3_residual', 'mfc4_residual',
       'mfc5_residual', 'total flow rate'
       ])

y = data[['x1', 'y1', 'x2', 'y2', "leak_2"]]
x = data.drop(['x1', 'y1', 'x2', 'y2', "leak_2"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1) 


# sort x1, y1 and x2, y2. coordinates with lowest x will take the position of x1
def coords_swap(y1):
    s = y1['x2'] < y1['x1']
    y1.loc[s, ['x1','x2']] = y1.loc[s, ['x2','x1']].values
    y1.loc[s, ['y1','y2']] = y1.loc[s, ['y2','y1']].values
    return y1


y1_data = [y_train, y_val, y_test]
y1_data_types = ['y_train', 'y_val', 'y_test']
for y1_data_types, y1 in zip(y1_data_types, y1_data):
    y1_data_types = coords_swap(y1)

y1_train = y_train[['x1', 'y1']]
y1_test = y_test[['x1', 'y1']]
y1_val = y_val[['x1', 'y1']]

y2_train = y_train[['x2', 'y2']]
y2_test = y_test[['x2', 'y2']]
y2_val = y_val[['x2', 'y2']]

y3_train = y_train[["leak_2"]]
y3_test = y_test[["leak_2"]]
y3_val = y_val[["leak_2"]]

y1_columns = y1_train.columns
y2_columns = y2_train.columns
y3_columns = y3_train.columns
X_columns = X_train.columns

scaler_coords1 = StandardScaler()
y1_train = scaler_coords1.fit_transform(y1_train)
y1_test = scaler_coords1.transform(y1_test)
y1_val = scaler_coords1.transform(y1_val)

y1_train = pd.DataFrame(y1_train, columns=y1_columns)
y1_test = pd.DataFrame(y1_test, columns=y1_columns)
y1_val = pd.DataFrame(y1_val, columns=y1_columns)

scaler_coords2 = StandardScaler()
y2_train = scaler_coords2.fit_transform(y2_train)
y2_test = scaler_coords2.transform(y2_test)
y2_val = scaler_coords2.transform(y2_val)

y2_train = pd.DataFrame(y2_train, columns=y2_columns)
y2_test = pd.DataFrame(y2_test, columns=y2_columns)
y2_val = pd.DataFrame(y2_val, columns=y2_columns)

scaler_flows = StandardScaler()
X_train = scaler_flows.fit_transform(X_train)
X_test = scaler_flows.transform(X_test)
X_val = scaler_flows.transform(X_val)

X_train = pd.DataFrame(X_train, columns=X_columns)
X_test = pd.DataFrame(X_test, columns=X_columns)
X_val = pd.DataFrame(X_val, columns=X_columns)

# y_train = [y1_train, y2_train]
# y_val = [y1_val, y2_val]
# y_test = [y1_test, y2_test]

y3_train = y3_train.reset_index().drop(columns='sample_number')
y3_val = y3_val.reset_index().drop(columns='sample_number')
y3_test = y3_test.reset_index().drop(columns='sample_number')

y_train_all = pd.concat([y1_train, y2_train, y3_train], axis=1)
y_test_all = pd.concat([y1_test, y2_test, y3_test], axis=1)
y_val_all = pd.concat([y1_val, y2_val, y3_val], axis=1)

# %%
X_train_np, y1_train_np, y2_train_np, y3_train_np = X_train.values, y1_train.values, y2_train.values, y3_train.values
X_val_np, y1_val_np, y2_val_np, y3_val_np = X_val.values, y1_val.values, y2_val.values, y3_val.values
X_test_np, y1_test_np, y2_test_np, y3_test_np = X_test.values, y1_test.values, y2_test.values, y3_test.values

# Create TensorFlow datasets from NumPy arrays.
batch_size = 32
buffer_size = len(X_train)  # Set the buffer size to the number of training examples for full shuffling.

train_dataset = tf.data.Dataset.from_tensor_slices((X_train_np, y1_train_np, y2_train_np , y3_train_np))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val_np, y1_val_np, y2_val_np, y3_val_np))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_np, y1_test_np, y2_test_np, y3_test_np))

# Shuffle, batch, and prefetch the training dataset.
train_dataset_org = train_dataset.batch(batch_size)
train_dataset = train_dataset.shuffle(buffer_size).batch(batch_size).prefetch(tf.data.AUTOTUNE)

# Batch the validation and test datasets.
val_dataset = val_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)

# %%
def masked_mse(y_true, y_pred):
    mask = tf.keras.backend.cast(tf.keras.backend.not_equal(y_true, 0), tf.keras.backend.floatx())
    mse = tf.keras.backend.mean(tf.keras.backend.square(y_true - y_pred) * mask)
    return mse

losses = {
	"y1": "mse",
	"y2": masked_mse,
    "y3": 'mse'
    }

metrics = {
    "y1": 'mae',
    "y2": 'mae',
    "y3": 'mae'
    }

# %%
EPOCHS = 1000

# Define custom loss function


# Define model builder function for Keras Tuner
def model_builder(hp):
    tf.keras.backend.clear_session()
    # Tune the number of units in the first Dense layer
    # Define model
    inputs = tf.keras.Input(shape=(10,))
    shared_layer = inputs
    for i in range(hp.Int('num_layers', 1, 15)):
        shared_layer = layers.Dense(
            units=hp.Int("units_" + str(i), min_value=32, max_value=512, step=32),
            activation='relu',
            # add elu
            kernel_initializer='he_uniform'
        )(shared_layer)

    task_layer1 = shared_layer
    for j in range(hp.Int(f'task_{i}_num_layers', 0, 10)):
        task_layer1 = layers.Dense(units=hp.Int(f'task_{i}_layer_{j}_neurons', min_value=8, max_value=256, step=8), 
                                    activation='relu',
                                    kernel_initializer='he_uniform')(task_layer1)
    out1 = layers.Dense(2, name='y1', activation = 'linear', kernel_initializer='he_uniform')(task_layer1)
    out2 = layers.Dense(2, name='y2', activation = 'linear', kernel_initializer='he_uniform')(task_layer1)

    task_layer2 = shared_layer
    for j in range(hp.Int(f'task_{i}_num_layers', 0, 10)):
        task_layer2 = layers.Dense(units=hp.Int(f'task_{i}_layer_{j}_neurons', min_value=2, max_value=64, step=2),
                                    activation='relu',
                                    kernel_initializer='he_uniform')(task_layer2)
    out3 = layers.Dense(1, name='y3', activation = 'sigmoid', kernel_initializer='he_uniform')(task_layer2)

    model = tf.keras.Model(inputs=inputs, outputs=[out1, out2, out3])

    # loss1_weight = hp.Choice('loss1_weight', values=[0.6, 0.7, 0.8, 0.9])
    # loss2_weight = 1 - loss1_weight
    loss1_weight = 0.95
    loss2_weight = 0.05

    lossWeights = {"y1": loss1_weight, "y2": loss1_weight, "y3": loss2_weight}

    # Tune the learning rate for the optimizer
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-1, sampling="log")

    # model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss=['mse', masked_mse])
    model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
                    loss=losses, 
                    loss_weights=lossWeights,
                    metrics = metrics)
    
    return model

tuner = Hyperband(
    model_builder,
    objective =  kt.Objective("val_loss", direction="min"),
    max_epochs=EPOCHS+100,
    factor=2,
    directory="../../tensorflow_log_files/studienarbeit/",
    project_name=project_name,
    seed = 0
)

tuner.search_space_summary()
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Perform hyperparameter search
tuner.search(train_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})),
            #  X_train, y_train, 
            #  validation_data = (X_val, y_val), 
            validation_data = val_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})), 
             verbose = 1, callbacks=[stop_early],
             epochs=EPOCHS, shuffle = True)

best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print("Best Hyperparameters:", best_hps)

# Build the best model with the best hyperparameters
best_model = tuner.hypermodel.build(best_hps)

# Train the best model on the full dataset
history = best_model.fit(train_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})),
            #  X_train, y_train,
            #  validation_data = (X_val, y_val), 
            validation_data = val_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})), 
            # callbacks=[stop_early],
            verbose = 1, epochs=EPOCHS, shuffle = True)

print(f"""
    The hyperparameter search is complete. The optimal learning rate for the optimizer
    is {best_model.optimizer.lr.numpy()}.
    """)
# Out:
# INFO:tensorflow:Reloading Tuner from ../../tensorflow_log_files/studienarbeit/Multi_leak_experiment5_Mask_MTL_withSwap_sameloss/tuner0.json
# Search space summary
# Default search space size: 182
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 15, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# task_0_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.1, 'step': None, 'sampling': 'log'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# task_14_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_12_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_7_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_5_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_5_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_8_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_13_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_6_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_1_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_10_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_2_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_1_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_4_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_7_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 0, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# task_3_layer_0_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_1_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_2_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_8_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_3_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_4_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_9_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_6_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_5_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_7_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_6_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_7_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_3_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_2_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_0_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_13_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_5_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_12_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_10_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_8_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_4_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_14_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_1_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# task_11_layer_9_neurons (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 256, 'step': 8, 'sampling': 'linear'}
# INFO:tensorflow:Oracle triggered exit
# Best Hyperparameters: <keras_tuner.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7f3684bd4070>
# Epoch 1/1000
# 17/17 [==============================] - 8s 28ms/step - loss: 1.5300 - y1_loss: 1.0199 - y2_loss: 0.6707 - y3_loss: 0.0849 - y1_mae: 0.6963 - y2_mae: 0.5997 - y3_mae: 0.1791 - val_loss: 0.5347 - val_y1_loss: 0.3840 - val_y2_loss: 0.2079 - val_y3_loss: 0.0200 - val_y1_mae: 0.4575 - val_y2_mae: 0.3519 - val_y3_mae: 0.0304
# Epoch 2/1000
# 17/17 [==============================] - 0s 10ms/step - loss: 0.2516 - y1_loss: 0.1497 - y2_loss: 0.1294 - y3_loss: 0.0034 - y1_mae: 0.2707 - y2_mae: 0.2619 - y3_mae: 0.0093 - val_loss: 0.2065 - val_y1_loss: 0.1197 - val_y2_loss: 0.1098 - val_y3_loss: 1.1884e-05 - val_y1_mae: 0.2442 - val_y2_mae: 0.2433 - val_y3_mae: 0.0014
# Epoch 3/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.1428 - y1_loss: 0.0745 - y2_loss: 0.0841 - y3_loss: 2.3430e-05 - y1_mae: 0.1912 - y2_mae: 0.2068 - y3_mae: 0.0012 - val_loss: 0.1433 - val_y1_loss: 0.0686 - val_y2_loss: 0.0906 - val_y3_loss: 1.6438e-06 - val_y1_mae: 0.1828 - val_y2_mae: 0.2179 - val_y3_mae: 5.6361e-04
# Epoch 4/1000
# 17/17 [==============================] - 0s 9ms/step - loss: 0.1012 - y1_loss: 0.0509 - y2_loss: 0.0616 - y3_loss: 5.6879e-06 - y1_mae: 0.1574 - y2_mae: 0.1765 - y3_mae: 6.7824e-04 - val_loss: 0.1280 - val_y1_loss: 0.0749 - val_y2_loss: 0.0674 - val_y3_loss: 3.1525e-06 - val_y1_mae: 0.1898 - val_y2_mae: 0.1858 - val_y3_mae: 5.7198e-04
# Epoch 5/1000
# 17/17 [==============================] - 0s 11ms/step - loss: 0.
1000
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0375 - y1_loss: 0.0155 - y2_loss: 0.0261 - y3_loss: 7.3304e-07 - y1_mae: 0.0868 - y2_mae: 0.1084 - y3_mae: 3.7427e-04 - val_loss: 0.0889 - val_y1_loss: 0.0497 - val_y2_loss: 0.0490 - val_y3_loss: 2.7427e-06 - val_y1_mae: 0.1458 - val_y2_mae: 0.1518 - val_y3_mae: 5.4287e-04
#
#     The hyperparameter search is complete. The optimal learning rate for the optimizer
#     is 0.0020342168863862753.

# %%
best_model.save(model_path)
# best_model = tf.keras.models.load_model(model_path)
best_model.summary()
# Out:
# INFO:tensorflow:Assets written to: saved_model/Multi_leak/experiment5/Mask_MTL_sameLoss/assets
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10)]         0           []
#
#  dense (Dense)                  (None, 160)          1760        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 512)          82432       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 416)          213408      ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 416)          173472      ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 160)          66720       ['dense_3[0][0]']
#
#  dense_8 (Dense)                (None, 160)          66720       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 168)          27048       ['dense_4[0][0]']
#
#  dense_9 (Dense)                (None, 168)          27048       ['dense_8[0][0]']
#
#  dense_6 (Dense)                (None, 88)           14872       ['dense_5[0][0]']
#
#  dense_10 (Dense)               (None, 88)           14872       ['dense_9[0][0]']
#
#  dense_7 (Dense)                (None, 72)           6408        ['dense_6[0][0]']
#
#  dense_11 (Dense)               (None, 72)           6408        ['dense_10[0][0]']
#
#  y1 (Dense)                     (None, 2)            146         ['dense_7[0][0]']
#
#  y2 (Dense)                     (None, 2)            146         ['dense_7[0][0]']
#
#  y3 (Dense)                     (None, 1)            73          ['dense_11[0][0]']
#
# ==================================================================================================
# Total params: 701,533
# Trainable params: 701,533
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ../../tensorflow_log_files/studienarbeit/Multi_leak_experiment5_Mask_MTL_withSwap_sameloss
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 3381 summary
# Hyperparameters:
# num_layers: 4
# units_0: 160
# task_0_num_layers: 3
# lr: 0.0020342169845676858
# units_1: 512
# units_2: 416
# units_3: 416
# units_4: 96
# units_5: 448
# units_6: 256
# units_7: 416
# units_8: 448
# units_9: 480
# units_10: 96
# units_11: 352
# units_12: 288
# units_13: 512
# units_14: 256
# task_14_num_layers: 3
# task_12_num_layers: 9
# task_7_num_layers: 6
# task_5_num_layers: 4
# task_5_layer_0_neurons: 72
# task_11_num_layers: 7
# task_8_num_layers: 8
# task_13_num_layers: 4
# task_6_num_layers: 0
# task_1_num_layers: 4
# task_10_num_layers: 1
# task_2_num_layers: 5
# task_1_layer_0_neurons: 136
# task_1_layer_1_neurons: 208
# task_1_layer_2_neurons: 144
# task_1_layer_3_neurons: 176
# task_1_layer_4_neurons: 64
# task_6_layer_0_neurons: 16
# task_6_layer_1_neurons: 152
# task_6_layer_2_neurons: 40
# task_2_layer_0_neurons: 200
# task_12_layer_0_neurons: 208
# task_12_layer_1_neurons: 208
# task_12_layer_2_neurons: 96
# task_12_layer_3_neurons: 40
# task_12_layer_4_neurons: 216
# task_12_layer_5_neurons: 112
# task_12_layer_6_neurons: 96
# task_12_layer_7_neurons: 216
# task_10_layer_6_neurons: 152
# task_10_layer_7_neurons: 80
# task_10_layer_8_neurons: 256
# task_9_layer_3_neurons: 136
# task_9_layer_4_neurons: 96
# task_9_layer_5_neurons: 216
# task_4_layer_5_neurons: 128
# task_4_layer_6_neurons: 176
# task_6_layer_6_neurons: 48
# task_6_layer_7_neurons: 40
# task_6_layer_8_neurons: 32
# task_9_layer_6_neurons: 104
# task_9_layer_7_neurons: 176
# task_9_layer_8_neurons: 80
# task_9_layer_9_neurons: 48
# task_4_layer_7_neurons: 48
# task_11_layer_7_neurons: 248
# task_6_layer_9_neurons: 208
# task_2_layer_5_neurons: 192
# task_2_layer_6_neurons: 168
# task_2_layer_7_neurons: 144
# task_2_layer_8_neurons: 72
# task_5_layer_6_neurons: 248
# task_5_layer_7_neurons: 24
# task_5_layer_8_neurons: 8
# task_7_layer_9_neurons: 24
# task_3_layer_6_neurons: 192
# task_3_layer_7_neurons: 248
# task_3_layer_8_neurons: 24
# task_3_layer_9_neurons: 240
# task_2_layer_9_neurons: 176
# task_0_layer_9_neurons: 40
# task_13_layer_9_neurons: 168
# task_11_layer_8_neurons: 104
# task_5_layer_9_neurons: 8
# task_12_layer_9_neurons: 232
# task_10_layer_9_neurons: 80
# task_4_layer_8_neurons: 120
# task_4_layer_9_neurons: 216
# task_14_layer_9_neurons: 128
# task_1_layer_9_neurons: 24
# task_11_layer_9_neurons: 16
# tuner/epochs: 1100
# tuner/initial_epoch: 550
# tuner/bracket: 7
# tuner/round: 7
# tuner/trial_id: 4459
# Score: 0.06419830024242401
#
# Trial 4060 summary
# Hyperparameters:
# num_layers: 4
# units_0: 512
# task_0_num_layers: 1
# lr: 0.0026105548902648095
# units_1: 512
# units_2: 384
# units_3: 480
# units_4: 512
# units_5: 352
# units_6: 32
# units_7: 224
# units_8: 288
# units_9: 320
# units_10: 480
# units_11: 64
# units_12: 256
# units_13: 512
# units_14: 448
# task_14_num_layers: 6
# task_12_num_layers: 7
# task_7_num_layers: 2
# task_5_num_layers: 5
# task_5_layer_0_neurons: 232
# task_11_num_layers: 5
# task_8_num_layers: 5
# task_13_num_layers: 3
# task_6_num_layers: 6
# task_1_num_layers: 5
# task_10_num_layers: 10
# task_2_num_layers: 6
# task_1_layer_0_neurons: 160
# task_1_layer_1_neurons: 56
# task_1_layer_2_neurons: 120
# task_1_layer_3_neurons: 72
# task_1_layer_4_neurons: 184
# task_6_layer_0_neurons: 152
# task_6_layer_1_neurons: 160
# task_6_layer_2_neurons: 112
# task_2_layer_0_neurons: 104
# task_12_layer_0_neurons: 56
# task_12_layer_1_neurons: 88
# task_12_layer_2_neurons: 192
# task_12_layer_3_neurons: 128
# task_12_layer_4_neurons: 256
# task_12_layer_5_neurons: 224
# task_12_layer_6_neurons: 128
# task_12_layer_7_neurons: 200
# task_10_layer_0_neurons: 224
# task_10_layer_1_neurons: 192
# task_10_layer_2_neurons: 152
# task_10_layer_3_neurons: 16
# task_8_layer_0_neurons: 24
# task_8_layer_1_neurons: 88
# task_9_layer_4_neurons: 24
# task_9_layer_5_neurons: 48
# task_4_layer_5_neurons: 136
# task_4_layer_6_neurons: 120
# task_6_layer_6_neurons: 192
# task_6_layer_7_neurons: 120
# task_6_layer_8_neurons: 240
# task_9_layer_6_neurons: 32
# task_9_layer_7_neurons: 120
# task_9_layer_8_neurons: 40
# task_9_layer_9_neurons: 192
# task_4_layer_7_neurons: 80
# task_11_layer_7_neurons: 56
# task_6_layer_9_neurons: 112
# task_2_layer_5_neurons: 136
# task_2_layer_6_neurons: 72
# task_2_layer_7_neurons: 152
# task_2_layer_8_neurons: 120
# task_5_layer_6_neurons: 144
# task_5_layer_7_neurons: 64
# task_5_layer_8_neurons: 32
# task_7_layer_9_neurons: 184
# task_3_layer_6_neurons: 104
# task_3_layer_7_neurons: 40
# task_3_layer_8_neurons: 40
# task_3_layer_9_neurons: 24
# task_2_layer_9_neurons: 232
# task_0_layer_9_neurons: 152
# task_13_layer_9_neurons: 200
# task_11_layer_8_neurons: 40
# task_5_layer_9_neurons: 176
# task_12_layer_9_neurons: 8
# task_10_layer_9_neurons: 40
# task_4_layer_8_neurons: 136
# task_4_layer_9_neurons: 248
# task_14_layer_9_neurons: 248
# task_1_layer_9_neurons: 104
# task_11_layer_9_neurons: 48
# tuner/epochs: 138
# tuner/initial_epoch: 69
# tuner/bracket: 8
# tuner/round: 5
# tuner/trial_id: 4038
# Score: 0.06454166769981384
#
# Trial 4064 summary
# Hyperparameters:
# num_layers: 4
# units_0: 160
# task_0_num_layers: 2
# lr: 0.004119437670262593
# units_1: 384
# units_2: 288
# units_3: 448
# units_4: 224
# units_5: 192
# units_6: 448
# units_7: 448
# units_8: 512
# units_9: 416
# units_10: 64
# units_11: 448
# units_12: 160
# units_13: 448
# units_14: 96
# task_14_num_layers: 9
# task_12_num_layers: 5
# task_7_num_layers: 3
# task_5_num_layers: 1
# task_5_layer_0_neurons: 40
# task_11_num_layers: 1
# task_8_num_layers: 5
# task_13_num_layers: 0
# task_6_num_layers: 5
# task_1_num_layers: 7
# task_10_num_layers: 8
# task_2_num_layers: 8
# task_1_layer_0_neurons: 160
# task_1_layer_1_neurons: 136
# task_1_layer_2_neurons: 88
# task_1_layer_3_neurons: 176
# task_1_layer_4_neurons: 56
# task_6_layer_0_neurons: 224
# task_6_layer_1_neurons: 216
# task_6_layer_2_neurons: 112
# task_2_layer_0_neurons: 64
# task_12_layer_0_neurons: 16
# task_12_layer_1_neurons: 224
# task_12_layer_2_neurons: 224
# task_12_layer_3_neurons: 128
# task_12_layer_4_neurons: 64
# task_12_layer_5_neurons: 80
# task_12_layer_6_neurons: 72
# task_12_layer_7_neurons: 208
# task_10_layer_0_neurons: 248
# task_10_layer_1_neurons: 88
# task_10_layer_2_neurons: 184
# task_10_layer_3_neurons: 64
# task_8_layer_0_neurons: 232
# task_8_layer_1_neurons: 184
# task_8_layer_2_neurons: 136
# task_8_layer_3_neurons: 24
# task_8_layer_4_neurons: 32
# task_8_layer_5_neurons: 96
# task_4_layer_6_neurons: 32
# task_6_layer_6_neurons: 40
# task_6_layer_7_neurons: 112
# task_6_layer_8_neurons: 24
# task_9_layer_6_neurons: 168
# task_9_layer_7_neurons: 72
# task_9_layer_8_neurons: 200
# task_9_layer_9_neurons: 168
# task_4_layer_7_neurons: 240
# task_11_layer_7_neurons: 176
# task_6_layer_9_neurons: 88
# task_2_layer_5_neurons: 184
# task_2_layer_6_neurons: 88
# task_2_layer_7_neurons: 80
# task_2_layer_8_neurons: 104
# task_5_layer_6_neurons: 136
# task_5_layer_7_neurons: 176
# task_5_layer_8_neurons: 152
# task_7_layer_9_neurons: 88
# task_3_layer_6_neurons: 160
# task_3_layer_7_neurons: 56
# task_3_layer_8_neurons: 112
# task_3_layer_9_neurons: 216
# task_2_layer_9_neurons: 128
# task_0_layer_9_neurons: 48
# task_13_layer_9_neurons: 96
# task_11_layer_8_neurons: 240
# task_5_layer_9_neurons: 80
# task_12_layer_9_neurons: 32
# task_10_layer_9_neurons: 240
# task_4_layer_8_neurons: 192
# task_4_layer_9_neurons: 184
# task_14_layer_9_neurons: 240
# task_1_layer_9_neurons: 232
# task_11_layer_9_neurons: 16
# tuner/epochs: 138
# tuner/initial_epoch: 69
# tuner/bracket: 8
# tuner/round: 5
# tuner/trial_id: 4037
# Score: 0.06481123715639114
#
# Trial 4683 summary
# Hyperparameters:
# num_layers: 2
# units_0: 288
# task_0_num_layers: 10
# lr: 0.006606140851761375
# units_1: 512
# units_2: 448
# units_3: 288
# units_4: 64
# units_5: 96
# units_6: 192
# units_7: 288
# units_8: 320
# units_9: 384
# units_10: 64
# units_11: 416
# units_12: 320
# units_13: 480
# units_14: 448
# task_14_num_layers: 6
# task_12_num_layers: 3
# task_7_num_layers: 0
# task_5_num_layers: 3
# task_5_layer_0_neurons: 224
# task_11_num_layers: 0
# task_8_num_layers: 9
# task_13_num_layers: 0
# task_6_num_layers: 7
# task_1_num_layers: 3
# task_10_num_layers: 4
# task_2_num_layers: 5
# task_1_layer_0_neurons: 72
# task_1_layer_1_neurons: 216
# task_1_layer_2_neurons: 40
# task_1_layer_3_neurons: 64
# task_1_layer_4_neurons: 128
# task_6_layer_0_neurons: 232
# task_6_layer_1_neurons: 128
# task_6_layer_2_neurons: 256
# task_2_layer_0_neurons: 160
# task_12_layer_0_neurons: 232
# task_12_layer_1_neurons: 144
# task_12_layer_2_neurons: 88
# task_12_layer_3_neurons: 128
# task_12_layer_4_neurons: 256
# task_12_layer_5_neurons: 208
# task_12_layer_6_neurons: 96
# task_12_layer_7_neurons: 240
# task_10_layer_0_neurons: 136
# task_10_layer_1_neurons: 152
# task_10_layer_2_neurons: 80
# task_10_layer_3_neurons: 136
# task_8_layer_0_neurons: 32
# task_8_layer_1_neurons: 128
# task_8_layer_2_neurons: 80
# task_8_layer_3_neurons: 192
# task_8_layer_4_neurons: 208
# task_8_layer_5_neurons: 112
# task_0_layer_0_neurons: 64
# task_0_layer_1_neurons: 152
# task_0_layer_2_neurons: 120
# task_6_layer_8_neurons: 136
# task_9_layer_6_neurons: 216
# task_9_layer_7_neurons: 64
# task_9_layer_8_neurons: 216
# task_9_layer_9_neurons: 8
# task_4_layer_7_neurons: 120
# task_11_layer_7_neurons: 104
# task_6_layer_9_neurons: 184
# task_2_layer_5_neurons: 232
# task_2_layer_6_neurons: 248
# task_2_layer_7_neurons: 208
# task_2_layer_8_neurons: 8
# task_5_layer_6_neurons: 24
# task_5_layer_7_neurons: 240
# task_5_layer_8_neurons: 200
# task_7_layer_9_neurons: 168
# task_3_layer_6_neurons: 56
# task_3_layer_7_neurons: 224
# task_3_layer_8_neurons: 208
# task_3_layer_9_neurons: 16
# task_2_layer_9_neurons: 208
# task_0_layer_9_neurons: 232
# task_13_layer_9_neurons: 192
# task_11_layer_8_neurons: 144
# task_5_layer_9_neurons: 40
# task_12_layer_9_neurons: 112
# task_10_layer_9_neurons: 40
# task_4_layer_8_neurons: 8
# task_4_layer_9_neurons: 16
# task_14_layer_9_neurons: 128
# task_1_layer_9_neurons: 16
# task_11_layer_9_neurons: 200
# tuner/epochs: 1100
# tuner/initial_epoch: 550
# tuner/bracket: 6
# tuner/round: 6
# tuner/trial_id: 4681
# Score: 0.0654735118150711
#
# Trial 2136 summary
# Hyperparameters:
# num_layers: 3
# units_0: 288
# task_0_num_layers: 0
# lr: 0.0074759568199825495
# units_1: 352
# units_2: 352
# units_3: 384
# units_4: 160
# units_5: 224
# units_6: 448
# units_7: 224
# units_8: 224
# units_9: 64
# units_10: 416
# units_11: 32
# units_12: 448
# units_13: 192
# units_14: 224
# task_14_num_layers: 3
# task_12_num_layers: 8
# task_7_num_layers: 10
# task_5_num_layers: 0
# task_5_layer_0_neurons: 104
# task_11_num_layers: 9
# task_8_num_layers: 10
# task_13_num_layers: 2
# task_6_num_layers: 6
# task_1_num_layers: 2
# task_10_num_layers: 5
# task_2_num_layers: 2
# task_1_layer_0_neurons: 160
# task_1_layer_1_neurons: 144
# task_1_layer_2_neurons: 208
# task_1_layer_3_neurons: 24
# task_1_layer_4_neurons: 16
# task_6_layer_0_neurons: 40
# task_6_layer_1_neurons: 72
# task_6_layer_2_neurons: 16
# task_2_layer_0_neurons: 120
# task_12_layer_0_neurons: 168
# task_12_layer_1_neurons: 248
# task_12_layer_2_neurons: 224
# task_12_layer_3_neurons: 88
# task_12_layer_4_neurons: 64
# task_12_layer_5_neurons: 208
# task_12_layer_6_neurons: 256
# task_12_layer_7_neurons: 128
# task_10_layer_0_neurons: 144
# task_10_layer_1_neurons: 232
# task_10_layer_2_neurons: 16
# task_10_layer_3_neurons: 136
# task_8_layer_0_neurons: 208
# task_8_layer_1_neurons: 144
# task_8_layer_2_neurons: 56
# task_8_layer_3_neurons: 208
# task_8_layer_4_neurons: 88
# task_8_layer_5_neurons: 248
# task_0_layer_0_neurons: 136
# task_0_layer_1_neurons: 56
# task_0_layer_2_neurons: 120
# task_0_layer_3_neurons: 128
# task_5_layer_1_neurons: 168
# task_5_layer_2_neurons: 24
# task_9_layer_9_neurons: 224
# task_4_layer_7_neurons: 72
# task_11_layer_7_neurons: 240
# task_6_layer_9_neurons: 232
# task_2_layer_5_neurons: 72
# task_2_layer_6_neurons: 256
# task_2_layer_7_neurons: 160
# task_2_layer_8_neurons: 32
# task_5_layer_6_neurons: 64
# task_5_layer_7_neurons: 56
# task_5_layer_8_neurons: 152
# task_7_layer_9_neurons: 128
# task_3_layer_6_neurons: 256
# task_3_layer_7_neurons: 256
# task_3_layer_8_neurons: 152
# task_3_layer_9_neurons: 176
# task_2_layer_9_neurons: 32
# task_0_layer_9_neurons: 80
# task_13_layer_9_neurons: 56
# task_11_layer_8_neurons: 128
# task_5_layer_9_neurons: 112
# task_12_layer_9_neurons: 184
# task_10_layer_9_neurons: 152
# task_4_layer_8_neurons: 144
# task_4_layer_9_neurons: 224
# task_14_layer_9_neurons: 216
# task_1_layer_9_neurons: 128
# task_11_layer_9_neurons: 64
# tuner/epochs: 35
# tuner/initial_epoch: 18
# tuner/bracket: 10
# tuner/round: 5
# tuner/trial_id: 2076
# Score: 0.06567980349063873
#
# Trial 4678 summary
# Hyperparameters:
# num_layers: 1
# units_0: 384
# task_0_num_layers: 5
# lr: 0.002037875544408507
# units_1: 160
# units_2: 224
# units_3: 128
# units_4: 480
# units_5: 320
# units_6: 64
# units_7: 64
# units_8: 256
# units_9: 224
# units_10: 96
# units_11: 320
# units_12: 384
# units_13: 352
# units_14: 224
# task_14_num_layers: 4
# task_12_num_layers: 6
# task_7_num_layers: 8
# task_5_num_layers: 7
# task_5_layer_0_neurons: 72
# task_11_num_layers: 0
# task_8_num_layers: 6
# task_13_num_layers: 0
# task_6_num_layers: 10
# task_1_num_layers: 7
# task_10_num_layers: 5
# task_2_num_layers: 8
# task_1_layer_0_neurons: 160
# task_1_layer_1_neurons: 152
# task_1_layer_2_neurons: 240
# task_1_layer_3_neurons: 8
# task_1_layer_4_neurons: 112
# task_6_layer_0_neurons: 40
# task_6_layer_1_neurons: 152
# task_6_layer_2_neurons: 192
# task_2_layer_0_neurons: 80
# task_12_layer_0_neurons: 120
# task_12_layer_1_neurons: 216
# task_12_layer_2_neurons: 152
# task_12_layer_3_neurons: 96
# task_12_layer_4_neurons: 256
# task_12_layer_5_neurons: 16
# task_12_layer_6_neurons: 240
# task_12_layer_7_neurons: 152
# task_10_layer_0_neurons: 176
# task_10_layer_1_neurons: 128
# task_10_layer_2_neurons: 24
# task_10_layer_3_neurons: 136
# task_8_layer_0_neurons: 88
# task_8_layer_1_neurons: 96
# task_8_layer_2_neurons: 152
# task_8_layer_3_neurons: 32
# task_8_layer_4_neurons: 224
# task_8_layer_5_neurons: 80
# task_0_layer_0_neurons: 136
# task_0_layer_1_neurons: 216
# task_0_layer_2_neurons: 96
# task_0_layer_3_neurons: 80
# task_5_layer_1_neurons: 216
# task_5_layer_2_neurons: 40
# task_13_layer_0_neurons: 208
# task_13_layer_1_neurons: 48
# task_13_layer_2_neurons: 88
# task_13_layer_3_neurons: 160
# task_13_layer_4_neurons: 64
# task_9_num_layers: 6
# task_4_num_layers: 0
# task_7_layer_0_neurons: 112
# task_7_layer_1_neurons: 64
# task_7_layer_2_neurons: 64
# task_7_layer_3_neurons: 96
# task_7_layer_4_neurons: 224
# task_4_layer_0_neurons: 240
# task_4_layer_1_neurons: 232
# task_4_layer_2_neurons: 104
# task_4_layer_3_neurons: 32
# task_4_layer_4_neurons: 192
# task_11_layer_0_neurons: 216
# task_11_layer_1_neurons: 152
# task_11_layer_2_neurons: 128
# task_11_layer_3_neurons: 128
# task_11_layer_4_neurons: 24
# task_11_layer_5_neurons: 120
# task_11_layer_6_neurons: 168
# task_2_layer_1_neurons: 120
# task_2_layer_2_neurons: 32
# task_2_layer_3_neurons: 104
# task_2_layer_4_neurons: 160
# task_7_layer_5_neurons: 216
# task_5_layer_3_neurons: 56
# task_5_layer_4_neurons: 256
# task_5_layer_5_neurons: 144
# task_1_layer_5_neurons: 16
# task_1_layer_6_neurons: 200
# task_1_layer_7_neurons: 208
# task_9_layer_0_neurons: 128
# task_9_layer_1_neurons: 32
# task_9_layer_2_neurons: 120
# task_7_layer_6_neurons: 160
# task_7_layer_7_neurons: 40
# task_7_layer_8_neurons: 256
# task_14_layer_0_neurons: 40
# task_14_layer_1_neurons: 72
# task_3_num_layers: 7
# task_3_layer_0_neurons: 168
# task_3_layer_1_neurons: 104
# task_3_layer_2_neurons: 192
# task_3_layer_3_neurons: 248
# task_3_layer_4_neurons: 232
# task_3_layer_5_neurons: 8
# task_0_layer_4_neurons: 48
# task_0_layer_5_neurons: 32
# task_8_layer_6_neurons: 256
# task_8_layer_7_neurons: 208
# task_13_layer_5_neurons: 232
# task_14_layer_2_neurons: 16
# task_14_layer_3_neurons: 32
# task_14_layer_4_neurons: 240
# task_14_layer_5_neurons: 24
# task_14_layer_6_neurons: 120
# task_14_layer_7_neurons: 184
# task_14_layer_8_neurons: 64
# task_13_layer_6_neurons: 120
# task_13_layer_7_neurons: 192
# task_13_layer_8_neurons: 96
# task_8_layer_8_neurons: 96
# task_8_layer_9_neurons: 112
# task_12_layer_8_neurons: 256
# task_0_layer_6_neurons: 8
# task_0_layer_7_neurons: 40
# task_0_layer_8_neurons: 176
# task_6_layer_3_neurons: 104
# task_6_layer_4_neurons: 184
# task_6_layer_5_neurons: 256
# task_1_layer_8_neurons: 160
# task_10_layer_4_neurons: 16
# task_10_layer_5_neurons: 184
# task_10_layer_6_neurons: 160
# task_10_layer_7_neurons: 160
# task_10_layer_8_neurons: 96
# task_9_layer_3_neurons: 96
# task_9_layer_4_neurons: 120
# task_9_layer_5_neurons: 16
# task_4_layer_5_neurons: 96
# task_4_layer_6_neurons: 184
# task_6_layer_6_neurons: 144
# task_6_layer_7_neurons: 256
# task_6_layer_8_neurons: 240
# task_9_layer_6_neurons: 248
# task_9_layer_7_neurons: 192
# task_9_layer_8_neurons: 192
# task_9_layer_9_neurons: 184
# task_4_layer_7_neurons: 16
# task_11_layer_7_neurons: 8
# task_6_layer_9_neurons: 168
# task_2_layer_5_neurons: 136
# task_2_layer_6_neurons: 72
# task_2_layer_7_neurons: 96
# task_2_layer_8_neurons: 136
# task_5_layer_6_neurons: 24
# task_5_layer_7_neurons: 240
# task_5_layer_8_neurons: 144
# task_7_layer_9_neurons: 24
# task_3_layer_6_neurons: 96
# task_3_layer_7_neurons: 224
# task_3_layer_8_neurons: 176
# task_3_layer_9_neurons: 200
# task_2_layer_9_neurons: 104
# task_0_layer_9_neurons: 240
# task_13_layer_9_neurons: 24
# task_11_layer_8_neurons: 112
# task_5_layer_9_neurons: 104
# task_12_layer_9_neurons: 72
# task_10_layer_9_neurons: 216
# task_4_layer_8_neurons: 56
# task_4_layer_9_neurons: 112
# task_14_layer_9_neurons: 136
# task_1_layer_9_neurons: 104
# task_11_layer_9_neurons: 216
# tuner/epochs: 550
# tuner/initial_epoch: 275
# tuner/bracket: 6
# tuner/round: 5
# tuner/trial_id: 4672
# Score: 0.06573927402496338
#
# Trial 3382 summary
# Hyperparameters:
# num_layers: 3
# units_0: 192
# task_0_num_layers: 3
# lr: 0.007244411668783633
# units_1: 256
# units_2: 320
# units_3: 160
# units_4: 96
# units_5: 384
# units_6: 512
# units_7: 384
# units_8: 256
# units_9: 192
# units_10: 512
# units_11: 448
# units_12: 288
# units_13: 416
# units_14: 160
# task_14_num_layers: 8
# task_12_num_layers: 6
# task_7_num_layers: 2
# task_5_num_layers: 2
# task_5_layer_0_neurons: 176
# task_11_num_layers: 0
# task_8_num_layers: 5
# task_13_num_layers: 2
# task_6_num_layers: 9
# task_1_num_layers: 2
# task_10_num_layers: 8
# task_2_num_layers: 3
# task_1_layer_0_neurons: 72
# task_1_layer_1_neurons: 56
# task_1_layer_2_neurons: 160
# task_1_layer_3_neurons: 208
# task_1_layer_4_neurons: 208
# task_6_layer_0_neurons: 88
# task_6_layer_1_neurons: 72
# task_6_layer_2_neurons: 216
# task_2_layer_0_neurons: 200
# task_12_layer_0_neurons: 256
# task_12_layer_1_neurons: 200
# task_12_layer_2_neurons: 112
# task_12_layer_3_neurons: 80
# task_12_layer_4_neurons: 152
# task_12_layer_5_neurons: 248
# task_12_layer_6_neurons: 8
# task_12_layer_7_neurons: 80
# task_10_layer_0_neurons: 144
# task_10_layer_1_neurons: 160
# task_10_layer_2_neurons: 216
# task_10_layer_3_neurons: 72
# task_8_layer_0_neurons: 208
# task_8_layer_1_neurons: 256
# task_8_layer_2_neurons: 40
# task_8_layer_3_neurons: 192
# task_8_layer_4_neurons: 128
# task_8_layer_5_neurons: 32
# task_0_layer_0_neurons: 208
# task_0_layer_1_neurons: 248
# task_0_layer_2_neurons: 96
# task_0_layer_3_neurons: 136
# task_5_layer_1_neurons: 24
# task_5_layer_2_neurons: 152
# task_13_layer_0_neurons: 112
# task_13_layer_1_neurons: 192
# task_13_layer_2_neurons: 176
# task_13_layer_3_neurons: 16
# task_13_layer_4_neurons: 96
# task_9_num_layers: 3
# task_4_num_layers: 8
# task_7_layer_0_neurons: 240
# task_2_layer_8_neurons: 216
# task_5_layer_6_neurons: 240
# task_5_layer_7_neurons: 88
# task_5_layer_8_neurons: 152
# task_7_layer_9_neurons: 80
# task_3_layer_6_neurons: 40
# task_3_layer_7_neurons: 248
# task_3_layer_8_neurons: 240
# task_3_layer_9_neurons: 192
# task_2_layer_9_neurons: 192
# task_0_layer_9_neurons: 128
# task_13_layer_9_neurons: 176
# task_11_layer_8_neurons: 256
# task_5_layer_9_neurons: 232
# task_12_layer_9_neurons: 208
# task_10_layer_9_neurons: 256
# task_4_layer_8_neurons: 96
# task_4_layer_9_neurons: 112
# task_14_layer_9_neurons: 80
# task_1_layer_9_neurons: 16
# task_11_layer_9_neurons: 144
# tuner/epochs: 138
# tuner/initial_epoch: 69
# tuner/bracket: 9
# tuner/round: 6
# tuner/trial_id: 3365
# Score: 0.06608469039201736
#
# Trial 4926 summary
# Hyperparameters:
# num_layers: 1
# units_0: 416
# task_0_num_layers: 6
# lr: 0.006469639545718548
# units_1: 384
# units_2: 512
# units_3: 288
# units_4: 352
# units_5: 288
# units_6: 480
# units_7: 96
# units_8: 224
# units_9: 224
# units_10: 96
# units_11: 32
# units_12: 416
# units_13: 416
# units_14: 416
# task_14_num_layers: 1
# task_12_num_layers: 10
# task_7_num_layers: 0
# task_5_num_layers: 9
# task_5_layer_0_neurons: 40
# task_11_num_layers: 2
# task_8_num_layers: 8
# task_13_num_layers: 3
# task_6_num_layers: 7
# task_1_num_layers: 9
# task_10_num_layers: 6
# task_2_num_layers: 0
# task_1_layer_0_neurons: 216
# task_1_layer_1_neurons: 64
# task_1_layer_2_neurons: 80
# task_1_layer_3_neurons: 24
# task_1_layer_4_neurons: 8
# task_6_layer_0_neurons: 248
# task_6_layer_1_neurons: 248
# task_6_layer_2_neurons: 8
# task_2_layer_0_neurons: 224
# task_12_layer_0_neurons: 96
# task_12_layer_1_neurons: 208
# task_12_layer_2_neurons: 240
# task_12_layer_3_neurons: 32
# task_12_layer_4_neurons: 32
# task_12_layer_5_neurons: 176
# task_12_layer_6_neurons: 88
# task_12_layer_7_neurons: 88
# task_10_layer_0_neurons: 216
# task_10_layer_1_neurons: 96
# task_10_layer_2_neurons: 232
# task_10_layer_3_neurons: 88
# task_8_layer_0_neurons: 104
# task_8_layer_1_neurons: 144
# task_8_layer_2_neurons: 200
# task_8_layer_3_neurons: 112
# task_8_layer_4_neurons: 184
# task_8_layer_5_neurons: 176
# task_0_layer_0_neurons: 208
# task_0_layer_1_neurons: 64
# task_0_layer_2_neurons: 224
# task_0_layer_3_neurons: 248
# task_5_layer_1_neurons: 200
# task_5_layer_2_neurons: 144
# task_13_layer_0_neurons: 248
# task_13_layer_1_neurons: 208
# task_13_layer_2_neurons: 64
# task_13_layer_3_neurons: 144
# task_13_layer_4_neurons: 232
# task_9_num_layers: 0
# task_4_num_layers: 8
# task_7_layer_0_neurons: 72
# task_7_layer_1_neurons: 136
# task_7_layer_2_neurons: 256
# task_7_layer_3_neurons: 168
# task_7_layer_4_neurons: 88
# task_4_layer_0_neurons: 184
# task_4_layer_1_neurons: 208
# task_4_layer_2_neurons: 32
# task_4_layer_3_neurons: 152
# task_4_layer_4_neurons: 256
# task_11_layer_0_neurons: 80
# task_11_layer_1_neurons: 72
# task_11_layer_2_neurons: 16
# task_11_layer_3_neurons: 232
# task_11_layer_4_neurons: 120
# task_11_layer_5_neurons: 144
# task_11_layer_6_neurons: 224
# task_2_layer_1_neurons: 40
# task_2_layer_2_neurons: 80
# task_2_layer_3_neurons: 128
# task_2_layer_4_neurons: 176
# task_7_layer_5_neurons: 176
# task_5_layer_3_neurons: 56
# task_5_layer_4_neurons: 248
# task_5_layer_5_neurons: 136
# task_1_layer_5_neurons: 152
# task_1_layer_6_neurons: 8
# task_1_layer_7_neurons: 176
# task_9_layer_0_neurons: 112
# task_9_layer_1_neurons: 96
# task_9_layer_2_neurons: 24
# task_7_layer_6_neurons: 104
# task_7_layer_7_neurons: 224
# task_7_layer_8_neurons: 64
# task_14_layer_0_neurons: 128
# task_14_layer_1_neurons: 152
# task_3_num_layers: 10
# task_3_layer_0_neurons: 168
# task_3_layer_1_neurons: 104
# task_3_layer_2_neurons: 200
# task_3_layer_3_neurons: 24
# task_3_layer_4_neurons: 24
# task_3_layer_5_neurons: 216
# task_0_layer_4_neurons: 184
# task_0_layer_5_neurons: 216
# task_8_layer_6_neurons: 192
# task_8_layer_7_neurons: 248
# task_13_layer_5_neurons: 136
# task_14_layer_2_neurons: 184
# task_14_layer_3_neurons: 224
# task_14_layer_4_neurons: 112
# task_14_layer_5_neurons: 72
# task_14_layer_6_neurons: 128
# task_14_layer_7_neurons: 208
# task_14_layer_8_neurons: 248
# task_13_layer_6_neurons: 112
# task_13_layer_7_neurons: 112
# task_13_layer_8_neurons: 232
# task_8_layer_8_neurons: 192
# task_8_layer_9_neurons: 120
# task_12_layer_8_neurons: 56
# task_0_layer_6_neurons: 64
# task_0_layer_7_neurons: 160
# task_0_layer_8_neurons: 144
# task_6_layer_3_neurons: 240
# task_6_layer_4_neurons: 232
# task_6_layer_5_neurons: 232
# task_1_layer_8_neurons: 56
# task_10_layer_4_neurons: 88
# task_10_layer_5_neurons: 64
# task_10_layer_6_neurons: 40
# task_10_layer_7_neurons: 16
# task_10_layer_8_neurons: 48
# task_9_layer_3_neurons: 64
# task_9_layer_4_neurons: 40
# task_9_layer_5_neurons: 32
# task_4_layer_5_neurons: 256
# task_4_layer_6_neurons: 136
# task_6_layer_6_neurons: 176
# task_6_layer_7_neurons: 96
# task_6_layer_8_neurons: 96
# task_9_layer_6_neurons: 40
# task_9_layer_7_neurons: 240
# task_9_layer_8_neurons: 136
# task_9_layer_9_neurons: 216
# task_4_layer_7_neurons: 88
# task_11_layer_7_neurons: 8
# task_6_layer_9_neurons: 56
# task_2_layer_5_neurons: 96
# task_2_layer_6_neurons: 16
# task_2_layer_7_neurons: 184
# task_2_layer_8_neurons: 168
# task_5_layer_6_neurons: 144
# task_5_layer_7_neurons: 168
# task_5_layer_8_neurons: 232
# task_7_layer_9_neurons: 128
# task_3_layer_6_neurons: 48
# task_3_layer_7_neurons: 48
# task_3_layer_8_neurons: 88
# task_3_layer_9_neurons: 32
# task_2_layer_9_neurons: 168
# task_0_layer_9_neurons: 128
# task_13_layer_9_neurons: 8
# task_11_layer_8_neurons: 168
# task_5_layer_9_neurons: 184
# task_12_layer_9_neurons: 48
# task_10_layer_9_neurons: 256
# task_4_layer_8_neurons: 240
# task_4_layer_9_neurons: 256
# task_14_layer_9_neurons: 104
# task_1_layer_9_neurons: 192
# task_11_layer_9_neurons: 256
# tuner/epochs: 1100
# tuner/initial_epoch: 550
# tuner/bracket: 3
# tuner/round: 3
# tuner/trial_id: 4921
# Score: 0.06618192046880722
#
# Trial 3391 summary
# Hyperparameters:
# num_layers: 2
# units_0: 96
# task_0_num_layers: 6
# lr: 0.01089949215106594
# units_1: 512
# units_2: 96
# units_3: 384
# units_4: 192
# units_5: 512
# units_6: 160
# units_7: 128
# units_8: 64
# units_9: 128
# units_10: 512
# units_11: 448
# units_12: 448
# units_13: 192
# units_14: 224
# task_14_num_layers: 2
# task_12_num_layers: 8
# task_7_num_layers: 8
# task_5_num_layers: 0
# task_5_layer_0_neurons: 240
# task_11_num_layers: 4
# task_8_num_layers: 10
# task_13_num_layers: 4
# task_6_num_layers: 1
# task_1_num_layers: 1
# task_10_num_layers: 10
# task_2_num_layers: 8
# task_1_layer_0_neurons: 240
# task_1_layer_1_neurons: 200
# task_1_layer_2_neurons: 208
# task_1_layer_3_neurons: 80
# task_1_layer_4_neurons: 72
# task_6_layer_0_neurons: 176
# task_6_layer_1_neurons: 72
# task_6_layer_2_neurons: 80
# task_2_layer_0_neurons: 96
# task_12_layer_0_neurons: 48
# task_12_layer_1_neurons: 184
# task_12_layer_2_neurons: 96
# task_12_layer_3_neurons: 40
# task_12_layer_4_neurons: 120
# task_12_layer_5_neurons: 232
# task_12_layer_6_neurons: 16
# task_12_layer_7_neurons: 200
# task_10_layer_0_neurons: 56
# task_10_layer_1_neurons: 24
# task_10_layer_2_neurons: 240
# task_10_layer_3_neurons: 24
# task_8_layer_0_neurons: 240
# task_8_layer_1_neurons: 72
# task_8_layer_2_neurons: 224
# task_8_layer_3_neurons: 40
# task_8_layer_4_neurons: 24
# task_8_layer_5_neurons: 80
# task_0_layer_0_neurons: 176
# task_0_layer_1_neurons: 232
# task_0_layer_2_neurons: 240
# task_0_layer_3_neurons: 168
# task_5_layer_1_neurons: 144
# task_5_layer_2_neurons: 8
# task_13_layer_0_neurons: 120
# task_13_layer_1_neurons: 32
# task_13_layer_2_neurons: 200
# task_13_layer_3_neurons: 240
# task_13_layer_4_neurons: 248
# task_9_num_layers: 8
# task_4_num_layers: 10
# task_7_layer_0_neurons: 40
# task_7_layer_1_neurons: 248
# task_7_layer_2_neurons: 248
# task_7_layer_3_neurons: 192
# task_7_layer_4_neurons: 88
# task_4_layer_0_neurons: 64
# task_4_layer_1_neurons: 88
# task_4_layer_2_neurons: 8
# task_4_layer_3_neurons: 112
# task_4_layer_4_neurons: 184
# task_11_layer_0_neurons: 160
# task_11_layer_1_neurons: 80
# task_11_layer_2_neurons: 40
# task_11_layer_3_neurons: 256
# task_11_layer_4_neurons: 120
# task_11_layer_5_neurons: 152
# task_11_layer_6_neurons: 8
# task_2_layer_1_neurons: 168
# task_2_layer_2_neurons: 256
# task_2_layer_3_neurons: 112
# task_2_layer_4_neurons: 72
# task_7_layer_5_neurons: 192
# task_5_layer_3_neurons: 136
# task_5_layer_4_neurons: 88
# task_5_layer_5_neurons: 160
# task_1_layer_5_neurons: 112
# task_1_layer_6_neurons: 160
# task_1_layer_7_neurons: 176
# task_9_layer_0_neurons: 200
# task_9_layer_1_neurons: 192
# task_9_layer_2_neurons: 184
# task_7_layer_6_neurons: 160
# task_7_layer_7_neurons: 136
# task_7_layer_8_neurons: 176
# task_14_layer_0_neurons: 56
# task_14_layer_1_neurons: 96
# task_3_num_layers: 4
# task_3_layer_0_neurons: 72
# task_3_layer_1_neurons: 80
# task_3_layer_2_neurons: 160
# task_3_layer_3_neurons: 192
# task_3_layer_4_neurons: 56
# task_3_layer_5_neurons: 128
# task_0_layer_4_neurons: 8
# task_0_layer_5_neurons: 56
# task_8_layer_6_neurons: 136
# task_8_layer_7_neurons: 120
# task_13_layer_5_neurons: 88
# task_14_layer_2_neurons: 256
# task_14_layer_3_neurons: 24
# task_14_layer_4_neurons: 152
# task_14_layer_5_neurons: 144
# task_14_layer_6_neurons: 64
# task_14_layer_7_neurons: 152
# task_14_layer_8_neurons: 24
# task_13_layer_6_neurons: 64
# task_13_layer_7_neurons: 216
# task_13_layer_8_neurons: 96
# task_8_layer_8_neurons: 16
# task_8_layer_9_neurons: 32
# task_12_layer_8_neurons: 88
# task_0_layer_6_neurons: 256
# task_0_layer_7_neurons: 8
# task_0_layer_8_neurons: 80
# task_6_layer_3_neurons: 176
# task_6_layer_4_neurons: 88
# task_6_layer_5_neurons: 208
# task_1_layer_8_neurons: 216
# task_10_layer_4_neurons: 248
# task_10_layer_5_neurons: 104
# task_10_layer_6_neurons: 192
# task_10_layer_7_neurons: 224
# task_10_layer_8_neurons: 24
# task_9_layer_3_neurons: 80
# task_9_layer_4_neurons: 224
# task_9_layer_5_neurons: 40
# task_4_layer_5_neurons: 32
# task_4_layer_6_neurons: 200
# task_6_layer_6_neurons: 256
# task_6_layer_7_neurons: 224
# task_6_layer_8_neurons: 192
# task_9_layer_6_neurons: 160
# task_9_layer_7_neurons: 248
# task_9_layer_8_neurons: 72
# task_9_layer_9_neurons: 48
# task_4_layer_7_neurons: 144
# task_11_layer_7_neurons: 24
# task_6_layer_9_neurons: 48
# task_2_layer_5_neurons: 136
# task_2_layer_6_neurons: 96
# task_2_layer_7_neurons: 16
# task_2_layer_8_neurons: 104
# task_5_layer_6_neurons: 24
# task_5_layer_7_neurons: 136
# task_5_layer_8_neurons: 144
# task_7_layer_9_neurons: 192
# task_3_layer_6_neurons: 88
# task_3_layer_7_neurons: 168
# task_3_layer_8_neurons: 152
# task_3_layer_9_neurons: 152
# task_2_layer_9_neurons: 40
# task_0_layer_9_neurons: 232
# task_13_layer_9_neurons: 48
# task_11_layer_8_neurons: 32
# task_5_layer_9_neurons: 8
# task_12_layer_9_neurons: 152
# task_10_layer_9_neurons: 176
# task_4_layer_8_neurons: 32
# task_4_layer_9_neurons: 240
# task_14_layer_9_neurons: 64
# task_1_layer_9_neurons: 88
# task_11_layer_9_neurons: 256
# tuner/epochs: 275
# tuner/initial_epoch: 138
# tuner/bracket: 9
# tuner/round: 7
# tuner/trial_id: 3386
# Score: 0.06635242700576782

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
y_predictions_train = best_model.predict(train_dataset_org.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})))
# print("train", "{:10.4f}".format(mean_squared_error(y_train, y_predictions, squared=True)))
y_predictions_val = best_model.predict(val_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})))
# print("val", "{:10.4f}".format(mean_squared_error(y_val, y_predictions, squared=True)))
y_predictions = best_model.predict(test_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})))

y_predictions_train = np.concatenate((y_predictions_train[0], y_predictions_train[1], y_predictions_train[2]), axis=1)
y_predictions_val = np.concatenate((y_predictions_val[0], y_predictions_val[1], y_predictions_val[2]), axis=1)
y_predictions = np.concatenate((y_predictions[0], y_predictions[1], y_predictions[2]), axis=1)

y_predictions_train[:,-1][np.abs(y_predictions_train[:,-1]) < 0.5] = 0
y_predictions_train[:,-1][np.abs(y_predictions_train[:,-1]) > 0.5] = 1

y_predictions_val[:,-1][np.abs(y_predictions_val[:,-1]) < 0.5] = 0
y_predictions_val[:,-1][np.abs(y_predictions_val[:,-1]) > 0.5] = 1

y_predictions[:,-1][np.abs(y_predictions[:,-1]) < 0.5] = 0
y_predictions[:,-1][np.abs(y_predictions[:,-1]) > 0.5] = 1

loss_test = "{:10.4f}".format(mean_squared_error(y_test_all, y_predictions, squared=True))
metric_test = "{:10.4f}".format(mean_absolute_error(y_test_all, y_predictions))

loss_val = "{:10.4f}".format(mean_squared_error(y_val_all, y_predictions_val, squared=True))
metric_val = "{:10.4f}".format(mean_absolute_error(y_val_all, y_predictions_val))

loss_train = "{:10.4f}".format(mean_squared_error(y_train_all, y_predictions_train, squared=True))
metric_train = "{:10.4f}".format(mean_absolute_error(y_train_all, y_predictions_train))

print(metric_test, metric_val, metric_train)
# Out:
# 17/17 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 2ms/step
# 4/4 [==============================] - 0s 3ms/step
#     0.1075     0.1171     0.0690

# %%
results_train = best_model.evaluate(train_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})), verbose=1)
results_val = best_model.evaluate(val_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})), verbose=1)
results_test = best_model.evaluate(test_dataset.map(lambda x, y1, y2, y3: (x, {'y1': y1, 'y2': y2, 'y3': y3})), verbose=1)
# Out:
# 17/17 [==============================] - 0s 3ms/step - loss: 0.0278 - y1_loss: 0.0128 - y2_loss: 0.0182 - y3_loss: 9.1078e-07 - y1_mae: 0.0773 - y2_mae: 0.0953 - y3_mae: 4.2924e-04
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0835 - y1_loss: 0.0448 - y2_loss: 0.0479 - y3_loss: 6.0778e-05 - y1_mae: 0.1382 - y2_mae: 0.1546 - y3_mae: 0.0014
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0577 - y1_loss: 0.0295 - y2_loss: 0.0347 - y3_loss: 1.8876e-06 - y1_mae: 0.1281 - y2_mae: 0.1406 - y3_mae: 5.9628e-04
